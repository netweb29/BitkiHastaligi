# %%
import pandas as pd
import matplotlib.pyplot as plt

VERI_DOSYASI = r'C:/Users/samsu/Downloads/proje/archive/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/egitim_icin_hazir.csv'

df = pd.read_csv(VERI_DOSYASI)

sinif_sayilari = df['class'].value_counts()

plt.figure(figsize=(15, 8))
plt.bar(sinif_sayilari.index, sinif_sayilari.values, color='teal')


plt.xticks(rotation=90) 
plt.title(f"Veri Seti Sınıf Dağılımı (Toplam {len(df)} Resim)", fontsize=16)
plt.xlabel("Hastalık Sınıfları", fontsize=12)
plt.ylabel("Görüntü Sayısı", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %%
import os
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms
from PIL import Image
import random
from sklearn.metrics import f1_score
import time

# --- EKLEME: DirectML ve EfficientNet kütüphaneleri ---
import torch_directml
from torchvision.models import efficientnet_b0, EfficientNet_B0_Weights

# --- DEĞİŞİKLİK: Cihazı DirectML (AMD GPU) olarak ayarla ---
device = torch_directml.device()
print(f"Kullanılan Cihaz: {device}")

CSV_DOSYASI = "C:/Users/samsu/Downloads/proje/archive/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/egitim_icin_hazir.csv"
ANA_KLASOR = r"C:/Users/samsu/Downloads/proje/archive/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train"
BATCH_SIZE = 16 
LEARNING_RATE = 0.001
EPOCHS = 15
RESIM_BOYUTU = 128


class TankVeriSeti(Dataset):
    def __init__(self, csv_file, root_dir, transform=None):
        self.veriler = pd.read_csv(csv_file)
        self.root_dir = root_dir
        self.transform = transform
        self.sinif_isimleri = sorted(self.veriler['class'].unique())
        self.sinif_sozlugu = {isim: i for i, isim in enumerate(self.sinif_isimleri)}

    def __len__(self): return len(self.veriler)

    def __getitem__(self, idx):
        try:
            dosya_adi = str(self.veriler.iloc[idx, 0])
            sinif_ismi = str(self.veriler.iloc[idx, 1])
            if "?" in dosya_adi: dosya_adi = dosya_adi.split('?')[0]
            
            yollar = [os.path.join(self.root_dir, sinif_ismi, dosya_adi),
                      os.path.join(self.root_dir, dosya_adi),
                      os.path.join(self.root_dir, sinif_ismi, dosya_adi[:-4] + ".jpg")]
            
            hedef_yol = None
            for yol in yollar:
                if os.path.exists(yol):
                    hedef_yol = yol
                    break
            
            if hedef_yol is None: raise FileNotFoundError()

            image = Image.open(hedef_yol).convert("RGB")
            label = self.sinif_sozlugu[sinif_ismi]
            if self.transform: image = self.transform(image)
            return image, label
        except:
            yeni_idx = random.randint(0, len(self.veriler) - 1)
            return self.__getitem__(yeni_idx)


# --- SafCNN sınıfı kaldırıldı, yerine aşağıda EfficientNet çağrılacak ---

if __name__ == '__main__':
    transform = transforms.Compose([
        transforms.Resize((RESIM_BOYUTU, RESIM_BOYUTU)),
        transforms.ToTensor(),
        transforms.Normalize((0.5,), (0.5,))
    ])

    print("Veriler Hazırlanıyor...")
    dataset = TankVeriSeti(csv_file=CSV_DOSYASI, root_dir=ANA_KLASOR, transform=transform)
    
    train_size = int(0.8 * len(dataset))
    val_size = len(dataset) - train_size
    train_dataset, val_dataset = random_split(dataset, [train_size, val_size])
    

    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0)
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=0)
    
    print(f"Train: {len(train_dataset)} | Val: {len(val_dataset)}")
    
    # --- DEĞİŞİKLİK: EfficientNet B0 Modelinin Yüklenmesi ---
    print("EfficientNet_B0 modeli yükleniyor...")
    # Transfer learning için varsayılan ağırlıkları yüklüyoruz
    model = efficientnet_b0(weights=EfficientNet_B0_Weights.DEFAULT)
    
    # EfficientNet'in çıkış katmanını (classifier) veri setindeki sınıf sayısına göre güncelleme
    num_classes = len(dataset.sinif_isimleri)
    in_features = model.classifier[1].in_features
    model.classifier[1] = nn.Linear(in_features, num_classes)
    
    model = model.to(device) # Modeli DirectML cihazına gönder

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)

    print("\nEĞİTİM BAŞLIYOR... (Her 50 adımda bir bilgi verecek)")
    print("-" * 60)

    for epoch in range(EPOCHS):
        model.train()
        train_loss = 0
        correct = 0
        total = 0
        

        start_time = time.time()
        
        for i, (images, labels) in enumerate(train_loader):
            images, labels = images.to(device), labels.to(device)
            
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            train_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            

            if (i+1) % 50 == 0:
                print(f"Epoch [{epoch+1}] | Adım [{i+1}/{len(train_loader)}] | Anlık Loss: {loss.item():.4f}")
        

        avg_train_loss = train_loss / len(train_loader)
        train_acc = 100 * correct / total
        elapsed_time = time.time() - start_time
        
        print(f"Epoch {epoch+1} Bitti ({elapsed_time:.1f} sn) | Train Acc: %{train_acc:.2f} | Loss: {avg_train_loss:.4f}")
        print("Doğrulama (Validation) yapılıyor...")
        
        model.eval()
        val_correct = 0
        val_total = 0
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                _, predicted = torch.max(outputs.data, 1)
                val_total += labels.size(0)
                val_correct += (predicted == labels).sum().item()
        
        val_acc = 100 * val_correct / val_total
        print(f"VAL ACC: %{val_acc:.2f}")
        print("-" * 60)

    torch.save(model.state_dict(), 'amd_model_final.pth')
    print("Model Kaydedildi.")
# Out:
# Kullanılan Cihaz: privateuseone:0
# Veriler Hazırlanıyor...
# Train: 63011 | Val: 15753
# EfficientNet_B0 modeli yükleniyor...
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-3dd342df.pth" to C:\Users\samsu/.cache\torch\hub\checkpoints\efficientnet_b0_rwightman-3dd342df.pth
# 100.0%
# EĞİTİM BAŞLIYOR... (Her 50 adımda bir bilgi verecek)
# ------------------------------------------------------------
# Epoch [1] | Adım [50/3939] | Anlık Loss: 1.3109
# Epoch [1] | Adım [100/3939] | Anlık Loss: 1.0924
# Epoch [1] | Adım [150/3939] | Anlık Loss: 0.8339
# Epoch [1] | Adım [200/3939] | Anlık Loss: 1.0762
# Epoch [1] | Adım [250/3939] | Anlık Loss: 0.9022
# Epoch [1] | Adım [300/3939] | Anlık Loss: 0.7614
# Epoch [1] | Adım [350/3939] | Anlık Loss: 0.2292
# Epoch [1] | Adım [400/3939] | Anlık Loss: 0.4633
# Epoch [1] | Adım [450/3939] | Anlık Loss: 0.3154
# Epoch [1] | Adım [500/3939] | Anlık Loss: 1.2470
# Epoch [1] | Adım [550/3939] | Anlık Loss: 0.8936
# Epoch [1] | Adım [600/3939] | Anlık Loss: 0.3639
# Epoch [1] | Adım [650/3939] | Anlık Loss: 0.5854
# Epoch [1] | Adım [700/3939] | Anlık Loss: 1.5321
# Epoch [1] | Adım [750/3939] | Anlık Loss: 0.3868
# Epoch [1] | Adım [800/3939] | Anlık Loss: 0.3749
# Epoch [1] | Adım [850/3939] | Anlık Loss: 0.7179
# Epoch [1] | Adım [900/3939] | Anlık Loss: 0.3387
# Epoch [1] | Adım [950/3939] | Anlık Loss: 0.1419
# Epoch [1] | Adım [1000/3939] | Anlık Loss: 0.3936
# Epoch [1] | Adım [1050/3939] | Anlık Loss: 0.2561
# Epoch [1] | Adım [1100/3939] | Anlık Loss: 0.3029
# Epoch [1] | Adım [1150/3939] | Anlık Loss: 0.2192
# Epoch [1] | Adım [1200/3939] | Anlık Loss: 0.2359
# Epoch [1] | Adım [1250/3939] | Anlık Loss: 0.3711
# Epoch [1] | Adım [1300/3939] | Anlık Loss: 0.4187
# Epoch [1] | Adım [1350/3939] | Anlık Loss: 0.1004
# Epoch [1] | Adım [1400/3939] | Anlık Loss: 0.9554
# Epoch [1] | Adım [1450/3939] | Anlık Loss: 0.7058
# Epoch [1] | Adım [1500/3939] | Anlık Loss: 0.3584
# Epoch [1] | Adım [1550/3939] | Anlık Loss: 0.5248
# Epoch [1] | Adım [1600/3939] | Anlık Loss: 0.1985
# Epoch [1] | Adım [1650/3939] | Anlık Loss: 0.6864
# Epoch [1] | Adım [1700/3939] | Anlık Loss: 0.7929
# Epoch [1] | Adım [1750/3939] | Anlık Loss: 0.4875
# Epoch [1] | Adım [1800/3939] | Anlık Loss: 1.0846
# Epoch [1] | Adım [1850/3939] | Anlık Loss: 0.9372
# Epoch [1] | Adım [1900/3939] | Anlık Loss: 0.2705
# Epoch [1] | Adım [1950/3939] | Anlık Loss: 0.5479
# Epoch [1] | Adım [2000/3939] | Anlık Loss: 0.5663
# Epoch [1] | Adım [2050/3939] | Anlık Loss: 0.6196
# Epoch [1] | Adım [2100/3939] | Anlık Loss: 0.8248
# Epoch [1] | Adım [2150/3939] | Anlık Loss: 0.2817
# Epoch [1] | Adım [2200/3939] | Anlık Loss: 0.3168
# Epoch [1] | Adım [2250/3939] | Anlık Loss: 0.4406
# Epoch [1] | Adım [2300/3939] | Anlık Loss: 0.2588
# Epoch [1] | Adım [2350/3939] | Anlık Loss: 0.5012
# Epoch [1] | Adım [2400/3939] | Anlık Loss: 1.0661
# Epoch [1] | Adım [2450/3939] | Anlık Loss: 0.2748
# Epoch [1] | Adım [2500/3939] | Anlık Loss: 0.1103
# Epoch [1] | Adım [2550/3939] | Anlık Loss: 0.7041
# Epoch [1] | Adım [2600/3939] | Anlık Loss: 0.1453
# Epoch [1] | Adım [2650/3939] | Anlık Loss: 0.3679
# Epoch [1] | Adım [2700/3939] | Anlık Loss: 0.3276
# Epoch [1] | Adım [2750/3939] | Anlık Loss: 0.0305
# Epoch [1] | Adım [2800/3939] | Anlık Loss: 0.0956
# Epoch [1] | Adım [2850/3939] | Anlık Loss: 0.0980
# Epoch [1] | Adım [2900/3939] | Anlık Loss: 0.2290
# Epoch [1] | Adım [2950/3939] | Anlık Loss: 0.1945
# Epoch [1] | Adım [3000/3939] | Anlık Loss: 0.2253
# Epoch [1] | Adım [3050/3939] | Anlık Loss: 0.1117
# Epoch [1] | Adım [3100/3939] | Anlık Loss: 0.2378
# Epoch [1] | Adım [3150/3939] | Anlık Loss: 0.3958
# Epoch [1] | Adım [3200/3939] | Anlık Loss: 0.0995
# Epoch [1] | Adım [3250/3939] | Anlık Loss: 0.6074
# Epoch [1] | Adım [3300/3939] | Anlık Loss: 0.3617
# Epoch [1] | Adım [3350/3939] | Anlık Loss: 0.5062
# Epoch [1] | Adım [3400/3939] | Anlık Loss: 0.6356
# Epoch [1] | Adım [3450/3939] | Anlık Loss: 1.2959
# Epoch [1] | Adım [3500/3939] | Anlık Loss: 0.1594
# Epoch [1] | Adım [3550/3939] | Anlık Loss: 0.4094
# Epoch [1] | Adım [3600/3939] | Anlık Loss: 0.7214
# Epoch [1] | Adım [3650/3939] | Anlık Loss: 0.5746
# Epoch [1] | Adım [3700/3939] | Anlık Loss: 0.1921
# Epoch [1] | Adım [3750/3939] | Anlık Loss: 0.0708
# Epoch [1] | Adım [3800/3939] | Anlık Loss: 0.2345
# Epoch [1] | Adım [3850/3939] | Anlık Loss: 0.3063
# Epoch [1] | Adım [3900/3939] | Anlık Loss: 0.1711
# Epoch 1 Bitti (604.6 sn) | Train Acc: %85.95 | Loss: 0.4841
# Doğrulama (Validation) yapılıyor...
# VAL ACC: %93.65
# ------------------------------------------------------------
# Epoch [2] | Adım [50/3939] | Anlık Loss: 0.2070
# Epoch [2] | Adım [100/3939] | Anlık Loss: 0.1430
# Epoch [2] | Adım [150/3939] | Anlık Loss: 0.5858
# Epoch [2] | Adım [200/3939] | Anlık Loss: 0.1940
# Epoch [2] | Adım [250/3939] | Anlık Loss: 0.4509
# Epoch [2] | Adım [300/3939] | Anlık Loss: 0.2819
# Epoch [2] | Adım [350/3939] | Anlık Loss: 0.3657
# Epoch [2] | Adım [400/3939] | Anlık Loss: 0.2546
# Epoch [2] | Adım [450/3939] | Anlık Loss: 0.1506
# Epoch [2] | Adım [500/3939] | Anlık Loss: 0.0417
# Epoch [2] | Adım [550/3939] | Anlık Loss: 0.5463
# Epoch [2] | Adım [600/3939] | Anlık Loss: 0.2416
# Epoch [2] | Adım [650/3939] | Anlık Loss: 0.0161
# Epoch [2] | Adım [700/3939] | Anlık Loss: 0.2637
# Epoch [2] | Adım [750/3939] | Anlık Loss: 0.2845
# Epoch [2] | Adım [800/3939] | Anlık Loss: 0.0304
# Epoch [2] | Adım [850/3939] | Anlık Loss: 0.7532
# Epoch [2] | Adım [900/3939] | Anlık Loss: 0.3013
# Epoch [2] | Adım [950/3939] | Anlık Loss: 0.1476
# Epoch [2] | Adım [1000/3939] | Anlık Loss: 1.4641
# Epoch [2] | Adım [1050/3939] | Anlık Loss: 0.3567
# Epoch [2] | Adım [1100/3939] | Anlık Loss: 0.3369
# Epoch [2] | Adım [1150/3939] | Anlık Loss: 0.0411
# Epoch [2] | Adım [1200/3939] | Anlık Loss: 0.0312
# Epoch [2] | Adım [1250/3939] | Anlık Loss: 0.0991
# Epoch [2] | Adım [1300/3939] | Anlık Loss: 0.2822
# Epoch [2] | Adım [1350/3939] | Anlık Loss: 0.2126
# Epoch [2] | Adım [1400/3939] | Anlık Loss: 0.5323
# Epoch [2] | Adım [1450/3939] | Anlık Loss: 0.7048
# Epoch [2] | Adım [1500/3939] | Anlık Loss: 0.0383
# Epoch [2] | Adım [1550/3939] | Anlık Loss: 0.1614
# Epoch [2] | Adım [1600/3939] | Anlık Loss: 0.2409
# Epoch [2] | Adım [1650/3939] | Anlık Loss: 0.0771
# Epoch [2] | Adım [1700/3939] | Anlık Loss: 0.0505
# Epoch [2] | Adım [1750/3939] | Anlık Loss: 0.5140
# Epoch [2] | Adım [1800/3939] | Anlık Loss: 0.2590
# Epoch [2] | Adım [1850/3939] | Anlık Loss: 0.4306
# Epoch [2] | Adım [1900/3939] | Anlık Loss: 0.1643
# Epoch [2] | Adım [1950/3939] | Anlık Loss: 0.2451
# Epoch [2] | Adım [2000/3939] | Anlık Loss: 0.0757
# Epoch [2] | Adım [2050/3939] | Anlık Loss: 0.1084
# Epoch [2] | Adım [2100/3939] | Anlık Loss: 0.0204
# Epoch [2] | Adım [2150/3939] | Anlık Loss: 0.0103
# Epoch [2] | Adım [2200/3939] | Anlık Loss: 0.0093
# Epoch [2] | Adım [2250/3939] | Anlık Loss: 0.4317
# Epoch [2] | Adım [2300/3939] | Anlık Loss: 0.0386
# Epoch [2] | Adım [2350/3939] | Anlık Loss: 0.3291
# Epoch [2] | Adım [2400/3939] | Anlık Loss: 0.0186
# Epoch [2] | Adım [2450/3939] | Anlık Loss: 0.2433
# Epoch [2] | Adım [2500/3939] | Anlık Loss: 0.0617
# Epoch [2] | Adım [2550/3939] | Anlık Loss: 0.3349
# Epoch [2] | Adım [2600/3939] | Anlık Loss: 0.3369
# Epoch [2] | Adım [2650/3939] | Anlık Loss: 0.0076
# Epoch [2] | Adım [2700/3939] | Anlık Loss: 0.3107
# Epoch [2] | Adım [2750/3939] | Anlık Loss: 0.2550
# Epoch [2] | Adım [2800/3939] | Anlık Loss: 0.2095
# Epoch [2] | Adım [2850/3939] | Anlık Loss: 0.0475
# Epoch [2] | Adım [2900/3939] | Anlık Loss: 0.3591
# Epoch [2] | Adım [2950/3939] | Anlık Loss: 0.1031
# Epoch [2] | Adım [3000/3939] | Anlık Loss: 0.0755
# Epoch [2] | Adım [3050/3939] | Anlık Loss: 0.7659
# Epoch [2] | Adım [3100/3939] | Anlık Loss: 0.1322
# Epoch [2] | Adım [3150/3939] | Anlık Loss: 0.0774
# Epoch [2] | Adım [3200/3939] | Anlık Loss: 0.0620
# Epoch [2] | Adım [3250/3939] | Anlık Loss: 0.2514
# Epoch [2] | Adım [3300/3939] | Anlık Loss: 0.1363
# Epoch [2] | Adım [3350/3939] | Anlık Loss: 0.1943
# Epoch [2] | Adım [3400/3939] | Anlık Loss: 0.3098
# Epoch [2] | Adım [3450/3939] | Anlık Loss: 0.0099
# Epoch [2] | Adım [3500/3939] | Anlık Loss: 0.0628
# Epoch [2] | Adım [3550/3939] | Anlık Loss: 0.0760
# Epoch [2] | Adım [3600/3939] | Anlık Loss: 0.0068
# Epoch [2] | Adım [3650/3939] | Anlık Loss: 0.1238
# Epoch [2] | Adım [3700/3939] | Anlık Loss: 0.4298
# Epoch [2] | Adım [3750/3939] | Anlık Loss: 0.0652
# Epoch [2] | Adım [3800/3939] | Anlık Loss: 0.1473
# Epoch [2] | Adım [3850/3939] | Anlık Loss: 0.0459
# Epoch [2] | Adım [3900/3939] | Anlık Loss: 0.0365
# Epoch 2 Bitti (603.6 sn) | Train Acc: %92.83 | Loss: 0.2361
# Doğrulama (Validation) yapılıyor...
# VAL ACC: %95.99
# ------------------------------------------------------------
# Epoch [3] | Adım [50/3939] | Anlık Loss: 0.2401
# Epoch [3] | Adım [100/3939] | Anlık Loss: 0.1660
# Epoch [3] | Adım [150/3939] | Anlık Loss: 0.1657
# Epoch [3] | Adım [200/3939] | Anlık Loss: 0.0651
# Epoch [3] | Adım [250/3939] | Anlık Loss: 0.7928
# Epoch [3] | Adım [300/3939] | Anlık Loss: 0.5062
# Epoch [3] | Adım [350/3939] | Anlık Loss: 0.0884
# Epoch [3] | Adım [400/3939] | Anlık Loss: 0.0589
# Epoch [3] | Adım [450/3939] | Anlık Loss: 0.7447
# Epoch [3] | Adım [500/3939] | Anlık Loss: 0.0683
# Epoch [3] | Adım [550/3939] | Anlık Loss: 0.0596
# Epoch [3] | Adım [600/3939] | Anlık Loss: 0.0403
# Epoch [3] | Adım [650/3939] | Anlık Loss: 0.1713
# Epoch [3] | Adım [700/3939] | Anlık Loss: 0.0535
# Epoch [3] | Adım [750/3939] | Anlık Loss: 0.4955
# Epoch [3] | Adım [800/3939] | Anlık Loss: 0.2360
# Epoch [3] | Adım [850/3939] | Anlık Loss: 0.1334
# Epoch [3] | Adım [900/3939] | Anlık Loss: 0.2785
# Epoch [3] | Adım [950/3939] | Anlık Loss: 0.0072
# Epoch [3] | Adım [1000/3939] | Anlık Loss: 0.0288
# Epoch [3] | Adım [1050/3939] | Anlık Loss: 0.3113
# Epoch [3] | Adım [1100/3939] | Anlık Loss: 0.3361
# Epoch [3] | Adım [1150/3939] | Anlık Loss: 0.0664
# Epoch [3] | Adım [1200/3939] | Anlık Loss: 0.0094
# Epoch [3] | Adım [1250/3939] | Anlık Loss: 0.3718
# Epoch [3] | Adım [1300/3939] | Anlık Loss: 0.1287
# Epoch [3] | Adım [1350/3939] | Anlık Loss: 0.0664
# Epoch [3] | Adım [1400/3939] | Anlık Loss: 0.0303
# Epoch [3] | Adım [1450/3939] | Anlık Loss: 0.0476
# Epoch [3] | Adım [1500/3939] | Anlık Loss: 0.1738
# Epoch [3] | Adım [1550/3939] | Anlık Loss: 0.4652
# Epoch [3] | Adım [1600/3939] | Anlık Loss: 0.0751
# Epoch [3] | Adım [1650/3939] | Anlık Loss: 0.1117
# Epoch [3] | Adım [1700/3939] | Anlık Loss: 0.6131
# Epoch [3] | Adım [1750/3939] | Anlık Loss: 0.1490
# Epoch [3] | Adım [1800/3939] | Anlık Loss: 0.0768
# Epoch [3] | Adım [1850/3939] | Anlık Loss: 0.0071
# Epoch [3] | Adım [1900/3939] | Anlık Loss: 0.4432
# Epoch [3] | Adım [1950/3939] | Anlık Loss: 0.0129
# Epoch [3] | Adım [2000/3939] | Anlık Loss: 0.0374
# Epoch [3] | Adım [2050/3939] | Anlık Loss: 0.0897
# Epoch [3] | Adım [2100/3939] | Anlık Loss: 0.0115
# Epoch [3] | Adım [2150/3939] | Anlık Loss: 0.0345
# Epoch [3] | Adım [2200/3939] | Anlık Loss: 0.1237
# Epoch [3] | Adım [2250/3939] | Anlık Loss: 0.0247
# Epoch [3] | Adım [2300/3939] | Anlık Loss: 0.0145
# Epoch [3] | Adım [2350/3939] | Anlık Loss: 0.0417
# Epoch [3] | Adım [2400/3939] | Anlık Loss: 0.0158
# Epoch [3] | Adım [2450/3939] | Anlık Loss: 0.0070
# Epoch [3] | Adım [2500/3939] | Anlık Loss: 0.0801
# Epoch [3] | Adım [2550/3939] | Anlık Loss: 0.3715
# Epoch [3] | Adım [2600/3939] | Anlık Loss: 0.0298
# Epoch [3] | Adım [2650/3939] | Anlık Loss: 0.9633
# Epoch [3] | Adım [2700/3939] | Anlık Loss: 0.0940
# Epoch [3] | Adım [2750/3939] | Anlık Loss: 0.0368
# Epoch [3] | Adım [2800/3939] | Anlık Loss: 0.0812
# Epoch [3] | Adım [2850/3939] | Anlık Loss: 0.0261
# Epoch [3] | Adım [2900/3939] | Anlık Loss: 0.3247
# Epoch [3] | Adım [2950/3939] | Anlık Loss: 0.5978
# Epoch [3] | Adım [3000/3939] | Anlık Loss: 0.2298
# Epoch [3] | Adım [3050/3939] | Anlık Loss: 0.0156
# Epoch [3] | Adım [3100/3939] | Anlık Loss: 0.2822
# Epoch [3] | Adım [3150/3939] | Anlık Loss: 0.1041
# Epoch [3] | Adım [3200/3939] | Anlık Loss: 0.0170
# Epoch [3] | Adım [3250/3939] | Anlık Loss: 0.1136
# Epoch [3] | Adım [3300/3939] | Anlık Loss: 0.1951
# Epoch [3] | Adım [3350/3939] | Anlık Loss: 0.0157
# Epoch [3] | Adım [3400/3939] | Anlık Loss: 0.0246
# Epoch [3] | Adım [3450/3939] | Anlık Loss: 0.1035
# Epoch [3] | Adım [3500/3939] | Anlık Loss: 0.0077
# Epoch [3] | Adım [3550/3939] | Anlık Loss: 0.0005
# Epoch [3] | Adım [3600/3939] | Anlık Loss: 0.0727
# Epoch [3] | Adım [3650/3939] | Anlık Loss: 0.0135
# Epoch [3] | Adım [3700/3939] | Anlık Loss: 0.1424
# Epoch [3] | Adım [3750/3939] | Anlık Loss: 0.2850
# Epoch [3] | Adım [3800/3939] | Anlık Loss: 0.0033
# Epoch [3] | Adım [3850/3939] | Anlık Loss: 0.0062
# Epoch [3] | Adım [3900/3939] | Anlık Loss: 0.0007
# Epoch 3 Bitti (593.7 sn) | Train Acc: %94.63 | Loss: 0.1738
# Doğrulama (Validation) yapılıyor...
# VAL ACC: %95.80
# ------------------------------------------------------------
# Epoch [4] | Adım [50/3939] | Anlık Loss: 0.0220
# Epoch [4] | Adım [100/3939] | Anlık Loss: 0.1185
# Epoch [4] | Adım [150/3939] | Anlık Loss: 0.0843
# Epoch [4] | Adım [200/3939] | Anlık Loss: 0.1265
# Epoch [4] | Adım [250/3939] | Anlık Loss: 0.0077
# Epoch [4] | Adım [300/3939] | Anlık Loss: 0.0572
# Epoch [4] | Adım [350/3939] | Anlık Loss: 0.0287
# Epoch [4] | Adım [400/3939] | Anlık Loss: 0.2011
# Epoch [4] | Adım [450/3939] | Anlık Loss: 0.1214
# Epoch [4] | Adım [500/3939] | Anlık Loss: 0.1746
# Epoch [4] | Adım [550/3939] | Anlık Loss: 0.0994
# Epoch [4] | Adım [600/3939] | Anlık Loss: 0.0113
# Epoch [4] | Adım [650/3939] | Anlık Loss: 0.5308
# Epoch [4] | Adım [700/3939] | Anlık Loss: 0.3650
# Epoch [4] | Adım [750/3939] | Anlık Loss: 0.2656
# Epoch [4] | Adım [800/3939] | Anlık Loss: 0.0477
# Epoch [4] | Adım [850/3939] | Anlık Loss: 0.0159
# Epoch [4] | Adım [900/3939] | Anlık Loss: 0.0031
# Epoch [4] | Adım [950/3939] | Anlık Loss: 0.5877
# Epoch [4] | Adım [1000/3939] | Anlık Loss: 0.0035
# Epoch [4] | Adım [1050/3939] | Anlık Loss: 0.2136
# Epoch [4] | Adım [1100/3939] | Anlık Loss: 0.0464
# Epoch [4] | Adım [1150/3939] | Anlık Loss: 0.0038
# Epoch [4] | Adım [1200/3939] | Anlık Loss: 0.5345
# Epoch [4] | Adım [1250/3939] | Anlık Loss: 0.3087
# Epoch [4] | Adım [1300/3939] | Anlık Loss: 0.0997
# Epoch [4] | Adım [1350/3939] | Anlık Loss: 0.0617
# Epoch [4] | Adım [1400/3939] | Anlık Loss: 0.0026
# Epoch [4] | Adım [1450/3939] | Anlık Loss: 0.0057
# Epoch [4] | Adım [1500/3939] | Anlık Loss: 0.0063
# Epoch [4] | Adım [1550/3939] | Anlık Loss: 0.2065
# Epoch [4] | Adım [1600/3939] | Anlık Loss: 0.0060
# Epoch [4] | Adım [1650/3939] | Anlık Loss: 0.0427
# Epoch [4] | Adım [1700/3939] | Anlık Loss: 0.0120
# Epoch [4] | Adım [1750/3939] | Anlık Loss: 0.0508
# Epoch [4] | Adım [1800/3939] | Anlık Loss: 0.0423
# Epoch [4] | Adım [1850/3939] | Anlık Loss: 0.0212
# Epoch [4] | Adım [1900/3939] | Anlık Loss: 0.0049
# Epoch [4] | Adım [1950/3939] | Anlık Loss: 0.3528
# Epoch [4] | Adım [2000/3939] | Anlık Loss: 0.1161
# Epoch [4] | Adım [2050/3939] | Anlık Loss: 0.7672
# Epoch [4] | Adım [2100/3939] | Anlık Loss: 0.0040
# Epoch [4] | Adım [2150/3939] | Anlık Loss: 0.0244
# Epoch [4] | Adım [2200/3939] | Anlık Loss: 0.1534
# Epoch [4] | Adım [2250/3939] | Anlık Loss: 0.0179
# Epoch [4] | Adım [2300/3939] | Anlık Loss: 0.0299
# Epoch [4] | Adım [2350/3939] | Anlık Loss: 0.0529
# Epoch [4] | Adım [2400/3939] | Anlık Loss: 0.3781
# Epoch [4] | Adım [2450/3939] | Anlık Loss: 0.0116
# Epoch [4] | Adım [2500/3939] | Anlık Loss: 0.0103
# Epoch [4] | Adım [2550/3939] | Anlık Loss: 0.0198
# Epoch [4] | Adım [2600/3939] | Anlık Loss: 0.7317
# Epoch [4] | Adım [2650/3939] | Anlık Loss: 0.3054
# Epoch [4] | Adım [2700/3939] | Anlık Loss: 0.0172
# Epoch [4] | Adım [2750/3939] | Anlık Loss: 0.0227
# Epoch [4] | Adım [2800/3939] | Anlık Loss: 0.0105
# Epoch [4] | Adım [2850/3939] | Anlık Loss: 0.0500
# Epoch [4] | Adım [2900/3939] | Anlık Loss: 0.0102
# Epoch [4] | Adım [2950/3939] | Anlık Loss: 0.1612
# Epoch [4] | Adım [3000/3939] | Anlık Loss: 0.0109
# Epoch [4] | Adım [3050/3939] | Anlık Loss: 0.0002
# Epoch [4] | Adım [3100/3939] | Anlık Loss: 0.0380
# Epoch [4] | Adım [3150/3939] | Anlık Loss: 0.0028
# Epoch [4] | Adım [3200/3939] | Anlık Loss: 0.1139
# Epoch [4] | Adım [3250/3939] | Anlık Loss: 0.4554
# Epoch [4] | Adım [3300/3939] | Anlık Loss: 0.0119
# Epoch [4] | Adım [3350/3939] | Anlık Loss: 1.0214
# Epoch [4] | Adım [3400/3939] | Anlık Loss: 0.0333
# Epoch [4] | Adım [3450/3939] | Anlık Loss: 0.0965
# Epoch [4] | Adım [3500/3939] | Anlık Loss: 0.0005
# Epoch [4] | Adım [3550/3939] | Anlık Loss: 0.1190
# Epoch [4] | Adım [3600/3939] | Anlık Loss: 0.1514
# Epoch [4] | Adım [3650/3939] | Anlık Loss: 0.4460
# Epoch [4] | Adım [3700/3939] | Anlık Loss: 0.1637
# Epoch [4] | Adım [3750/3939] | Anlık Loss: 0.0734
# Epoch [4] | Adım [3800/3939] | Anlık Loss: 0.0027
# Epoch [4] | Adım [3850/3939] | Anlık Loss: 0.1223
# Epoch [4] | Adım [3900/3939] | Anlık Loss: 0.0128
# Epoch 4 Bitti (577.1 sn) | Train Acc: %95.80 | Loss: 0.1365
# Doğrulama (Validation) yapılıyor...
# VAL ACC: %97.10
# ------------------------------------------------------------
# Epoch [5] | Adım [50/3939] | Anlık Loss: 0.2867
# Epoch [5] | Adım [100/3939] | Anlık Loss: 0.2767
# Epoch [5] | Adım [150/3939] | Anlık Loss: 0.0034
# Epoch [5] | Adım [200/3939] | Anlık Loss: 0.0080
# Epoch [5] | Adım [250/3939] | Anlık Loss: 0.0147
# Epoch [5] | Adım [300/3939] | Anlık Loss: 0.1313
# Epoch [5] | Adım [350/3939] | Anlık Loss: 0.1134
# Epoch [5] | Adım [400/3939] | Anlık Loss: 0.0012
# Epoch [5] | Adım [450/3939] | Anlık Loss: 0.0062
# Epoch [5] | Adım [500/3939] | Anlık Loss: 0.0321
# Epoch [5] | Adım [550/3939] | Anlık Loss: 0.4359
# Epoch [5] | Adım [600/3939] | Anlık Loss: 0.0901
# Epoch [5] | Adım [650/3939] | Anlık Loss: 0.0374
# Epoch [5] | Adım [700/3939] | Anlık Loss: 0.4262
# Epoch [5] | Adım [750/3939] | Anlık Loss: 0.0858
# Epoch [5] | Adım [800/3939] | Anlık Loss: 0.1370
# Epoch [5] | Adım [850/3939] | Anlık Loss: 0.0327
# Epoch [5] | Adım [900/3939] | Anlık Loss: 0.0862
# Epoch [5] | Adım [950/3939] | Anlık Loss: 0.1425
# Epoch [5] | Adım [1000/3939] | Anlık Loss: 0.0121
# Epoch [5] | Adım [1050/3939] | Anlık Loss: 0.0791
# Epoch [5] | Adım [1100/3939] | Anlık Loss: 0.0007
# Epoch [5] | Adım [1150/3939] | Anlık Loss: 0.3541
# Epoch [5] | Adım [1200/3939] | Anlık Loss: 0.0493
# Epoch [5] | Adım [1250/3939] | Anlık Loss: 0.0132
# Epoch [5] | Adım [1300/3939] | Anlık Loss: 0.0514
# Epoch [5] | Adım [1350/3939] | Anlık Loss: 0.0316
# Epoch [5] | Adım [1400/3939] | Anlık Loss: 0.1693
# Epoch [5] | Adım [1450/3939] | Anlık Loss: 0.1630
# Epoch [5] | Adım [1500/3939] | Anlık Loss: 0.0190
# Epoch [5] | Adım [1550/3939] | Anlık Loss: 0.0785
# Epoch [5] | Adım [1600/3939] | Anlık Loss: 0.0273
# Epoch [5] | Adım [1650/3939] | Anlık Loss: 0.0219
# Epoch [5] | Adım [1700/3939] | Anlık Loss: 0.4952
# Epoch [5] | Adım [1750/3939] | Anlık Loss: 0.0024
# Epoch [5] | Adım [1800/3939] | Anlık Loss: 0.3945
# Epoch [5] | Adım [1850/3939] | Anlık Loss: 0.2065
# Epoch [5] | Adım [1900/3939] | Anlık Loss: 0.1210
# Epoch [5] | Adım [1950/3939] | Anlık Loss: 0.0108
# Epoch [5] | Adım [2000/3939] | Anlık Loss: 0.0042
# Epoch [5] | Adım [2050/3939] | Anlık Loss: 0.0008
# Epoch [5] | Adım [2100/3939] | Anlık Loss: 0.2707
# Epoch [5] | Adım [2150/3939] | Anlık Loss: 0.1192
# Epoch [5] | Adım [2200/3939] | Anlık Loss: 0.2408
# Epoch [5] | Adım [2250/3939] | Anlık Loss: 0.0045
# Epoch [5] | Adım [2300/3939] | Anlık Loss: 0.0248
# Epoch [5] | Adım [2350/3939] | Anlık Loss: 0.1465
# Epoch [5] | Adım [2400/3939] | Anlık Loss: 0.2768
# Epoch [5] | Adım [2450/3939] | Anlık Loss: 0.2916
# Epoch [5] | Adım [2500/3939] | Anlık Loss: 0.2824
# Epoch [5] | Adım [2550/3939] | Anlık Loss: 0.2613
# Epoch [5] | Adım [2600/3939] | Anlık Loss: 0.3660
# Epoch [5] | Adım [2650/3939] | Anlık Loss: 0.2080
# Epoch [5] | Adım [2700/3939] | Anlık Loss: 0.1530
# Epoch [5] | Adım [2750/3939] | Anlık Loss: 0.4819
# Epoch [5] | Adım [2800/3939] | Anlık Loss: 0.2152
# Epoch [5] | Adım [2850/3939] | Anlık Loss: 0.0233
# Epoch [5] | Adım [2900/3939] | Anlık Loss: 0.0886
# Epoch [5] | Adım [2950/3939] | Anlık Loss: 0.0011
# Epoch [5] | Adım [3000/3939] | Anlık Loss: 0.0326
# Epoch [5] | Adım [3050/3939] | Anlık Loss: 0.0405
# Epoch [5] | Adım [3100/3939] | Anlık Loss: 0.0628
# Epoch [5] | Adım [3150/3939] | Anlık Loss: 0.0196
# Epoch [5] | Adım [3200/3939] | Anlık Loss: 0.0348
# Epoch [5] | Adım [3250/3939] | Anlık Loss: 0.1285
# Epoch [5] | Adım [3300/3939] | Anlık Loss: 0.0639
# Epoch [5] | Adım [3350/3939] | Anlık Loss: 0.0253
# Epoch [5] | Adım [3400/3939] | Anlık Loss: 0.1904
# Epoch [5] | Adım [3450/3939] | Anlık Loss: 0.0011
# Epoch [5] | Adım [3500/3939] | Anlık Loss: 0.0056
# Epoch [5] | Adım [3550/3939] | Anlık Loss: 0.0104
# Epoch [5] | Adım [3600/3939] | Anlık Loss: 0.1847
# Epoch [5] | Adım [3650/3939] | Anlık Loss: 0.0519
# Epoch [5] | Adım [3700/3939] | Anlık Loss: 0.0505
# Epoch [5] | Adım [3750/3939] | Anlık Loss: 0.2301
# Epoch [5] | Adım [3800/3939] | Anlık Loss: 0.0189
# Epoch [5] | Adım [3850/3939] | Anlık Loss: 0.0854
# Epoch [5] | Adım [3900/3939] | Anlık Loss: 0.0111
# Epoch 5 Bitti (551.2 sn) | Train Acc: %96.41 | Loss: 0.1181
# Doğrulama (Validation) yapılıyor...
# VAL ACC: %96.59
# ------------------------------------------------------------
# Epoch [6] | Adım [50/3939] | Anlık Loss: 0.0257
# Epoch [6] | Adım [100/3939] | Anlık Loss: 0.1773
# Epoch [6] | Adım [150/3939] | Anlık Loss: 0.2505
# Epoch [6] | Adım [200/3939] | Anlık Loss: 0.0208
# Epoch [6] | Adım [250/3939] | Anlık Loss: 0.0520
# Epoch [6] | Adım [300/3939] | Anlık Loss: 0.2042
# Epoch [6] | Adım [350/3939] | Anlık Loss: 0.0378
# Epoch [6] | Adım [400/3939] | Anlık Loss: 0.0007
# Epoch [6] | Adım [450/3939] | Anlık Loss: 0.0067
# Epoch [6] | Adım [500/3939] | Anlık Loss: 0.0112
# Epoch [6] | Adım [550/3939] | Anlık Loss: 0.0318
# Epoch [6] | Adım [600/3939] | Anlık Loss: 0.2440
# Epoch [6] | Adım [650/3939] | Anlık Loss: 0.0620
# Epoch [6] | Adım [700/3939] | Anlık Loss: 0.0054
# Epoch [6] | Adım [750/3939] | Anlık Loss: 0.0070
# Epoch [6] | Adım [800/3939] | Anlık Loss: 0.0089
# Epoch [6] | Adım [850/3939] | Anlık Loss: 0.0663
# Epoch [6] | Adım [900/3939] | Anlık Loss: 0.1160
# Epoch [6] | Adım [950/3939] | Anlık Loss: 0.0167
# Epoch [6] | Adım [1000/3939] | Anlık Loss: 0.0553
# Epoch [6] | Adım [1050/3939] | Anlık Loss: 0.0233
# Epoch [6] | Adım [1100/3939] | Anlık Loss: 0.0171
# Epoch [6] | Adım [1150/3939] | Anlık Loss: 0.0617
# Epoch [6] | Adım [1200/3939] | Anlık Loss: 0.0040
# Epoch [6] | Adım [1250/3939] | Anlık Loss: 0.2942
# Epoch [6] | Adım [1300/3939] | Anlık Loss: 0.0301
# Epoch [6] | Adım [1350/3939] | Anlık Loss: 0.1626
# Epoch [6] | Adım [1400/3939] | Anlık Loss: 0.3222
# Epoch [6] | Adım [1450/3939] | Anlık Loss: 0.1362
# Epoch [6] | Adım [1500/3939] | Anlık Loss: 0.0123
# Epoch [6] | Adım [1550/3939] | Anlık Loss: 0.0071
# Epoch [6] | Adım [1600/3939] | Anlık Loss: 0.1420
# Epoch [6] | Adım [1650/3939] | Anlık Loss: 0.0124
# Epoch [6] | Adım [1700/3939] | Anlık Loss: 0.2921
# Epoch [6] | Adım [1750/3939] | Anlık Loss: 0.0152
# Epoch [6] | Adım [1800/3939] | Anlık Loss: 0.0084
# Epoch [6] | Adım [1850/3939] | Anlık Loss: 0.0240
# Epoch [6] | Adım [1900/3939] | Anlık Loss: 0.1991
# Epoch [6] | Adım [1950/3939] | Anlık Loss: 0.0077
# Epoch [6] | Adım [2000/3939] | Anlık Loss: 0.0218
# Epoch [6] | Adım [2050/3939] | Anlık Loss: 0.0002
# Epoch [6] | Adım [2100/3939] | Anlık Loss: 0.0246
# Epoch [6] | Adım [2150/3939] | Anlık Loss: 0.0903
# Epoch [6] | Adım [2200/3939] | Anlık Loss: 0.0699
# Epoch [6] | Adım [2250/3939] | Anlık Loss: 0.0858
# Epoch [6] | Adım [2300/3939] | Anlık Loss: 0.1504
# Epoch [6] | Adım [2350/3939] | Anlık Loss: 0.0998
# Epoch [6] | Adım [2400/3939] | Anlık Loss: 0.0990
# Epoch [6] | Adım [2450/3939] | Anlık Loss: 0.0611
# Epoch [6] | Adım [2500/3939] | Anlık Loss: 0.0820
# Epoch [6] | Adım [2550/3939] | Anlık Loss: 0.0034
# Epoch [6] | Adım [2600/3939] | Anlık Loss: 0.1560
# Epoch [6] | Adım [2650/3939] | Anlık Loss: 0.0157
# Epoch [6] | Adım [2700/3939] | Anlık Loss: 0.0005
# Epoch [6] | Adım [2750/3939] | Anlık Loss: 0.0486
# Epoch [6] | Adım [2800/3939] | Anlık Loss: 0.0273
# Epoch [6] | Adım [2850/3939] | Anlık Loss: 0.2795
# Epoch [6] | Adım [2900/3939] | Anlık Loss: 0.0302
# Epoch [6] | Adım [2950/3939] | Anlık Loss: 0.3964
# Epoch [6] | Adım [3000/3939] | Anlık Loss: 0.3113
# Epoch [6] | Adım [3050/3939] | Anlık Loss: 0.2125
# Epoch [6] | Adım [3100/3939] | Anlık Loss: 0.0030
# Epoch [6] | Adım [3150/3939] | Anlık Loss: 0.2703
# Epoch [6] | Adım [3200/3939] | Anlık Loss: 0.1388
# Epoch [6] | Adım [3250/3939] | Anlık Loss: 0.0173
# Epoch [6] | Adım [3300/3939] | Anlık Loss: 0.5076
# Epoch [6] | Adım [3350/3939] | Anlık Loss: 0.0107
# Epoch [6] | Adım [3400/3939] | Anlık Loss: 0.0029
# Epoch [6] | Adım [3450/3939] | Anlık Loss: 0.1300
# Epoch [6] | Adım [3500/3939] | Anlık Loss: 0.0104
# Epoch [6] | Adım [3550/3939] | Anlık Loss: 0.0894
# Epoch [6] | Adım [3600/3939] | Anlık Loss: 0.1233
# Epoch [6] | Adım [3650/3939] | Anlık Loss: 0.0338
# Epoch [6] | Adım [3700/3939] | Anlık Loss: 0.0631
# Epoch [6] | Adım [3750/3939] | Anlık Loss: 0.0404
# Epoch [6] | Adım [3800/3939] | Anlık Loss: 0.1814
# Epoch [6] | Adım [3850/3939] | Anlık Loss: 0.0041
# Epoch [6] | Adım [3900/3939] | Anlık Loss: 0.0386
# Epoch 6 Bitti (564.0 sn) | Train Acc: %96.89 | Loss: 0.1017
# Doğrulama (Validation) yapılıyor...
# VAL ACC: %97.17
# ------------------------------------------------------------
# Epoch [7] | Adım [50/3939] | Anlık Loss: 0.0295
# Epoch [7] | Adım [100/3939] | Anlık Loss: 0.0852
# Epoch [7] | Adım [150/3939] | Anlık Loss: 0.1095
# Epoch [7] | Adım [200/3939] | Anlık Loss: 0.0045
# Epoch [7] | Adım [250/3939] | Anlık Loss: 0.0087
# Epoch [7] | Adım [300/3939] | Anlık Loss: 0.0160
# Epoch [7] | Adım [350/3939] | Anlık Loss: 0.0132
# Epoch [7] | Adım [400/3939] | Anlık Loss: 0.0010
# Epoch [7] | Adım [450/3939] | Anlık Loss: 0.0383
# Epoch [7] | Adım [500/3939] | Anlık Loss: 0.0006
# Epoch [7] | Adım [550/3939] | Anlık Loss: 0.1891
# Epoch [7] | Adım [600/3939] | Anlık Loss: 0.0053
# Epoch [7] | Adım [650/3939] | Anlık Loss: 0.0077
# Epoch [7] | Adım [700/3939] | Anlık Loss: 0.0005
# Epoch [7] | Adım [750/3939] | Anlık Loss: 0.0010
# Epoch [7] | Adım [800/3939] | Anlık Loss: 0.1563
# Epoch [7] | Adım [850/3939] | Anlık Loss: 0.0182
# Epoch [7] | Adım [900/3939] | Anlık Loss: 0.3692
# Epoch [7] | Adım [950/3939] | Anlık Loss: 0.0094
# Epoch [7] | Adım [1000/3939] | Anlık Loss: 0.1567
# Epoch [7] | Adım [1050/3939] | Anlık Loss: 0.0233
# Epoch [7] | Adım [1100/3939] | Anlık Loss: 0.0482
# Epoch [7] | Adım [1150/3939] | Anlık Loss: 0.5210
# Epoch [7] | Adım [1200/3939] | Anlık Loss: 0.0041
# Epoch [7] | Adım [1250/3939] | Anlık Loss: 0.0296
# Epoch [7] | Adım [1300/3939] | Anlık Loss: 0.0014
# Epoch [7] | Adım [1350/3939] | Anlık Loss: 0.0163
# Epoch [7] | Adım [1400/3939] | Anlık Loss: 0.0235
# Epoch [7] | Adım [1450/3939] | Anlık Loss: 0.0033
# Epoch [7] | Adım [1500/3939] | Anlık Loss: 0.0136
# Epoch [7] | Adım [1550/3939] | Anlık Loss: 0.3258
# Epoch [7] | Adım [1600/3939] | Anlık Loss: 0.0145
# Epoch [7] | Adım [1650/3939] | Anlık Loss: 0.0156
# Epoch [7] | Adım [1700/3939] | Anlık Loss: 0.2097
# Epoch [7] | Adım [1750/3939] | Anlık Loss: 0.0190
# Epoch [7] | Adım [1800/3939] | Anlık Loss: 0.0429
# Epoch [7] | Adım [1850/3939] | Anlık Loss: 0.1195
# Epoch [7] | Adım [1900/3939] | Anlık Loss: 0.3069
# Epoch [7] | Adım [1950/3939] | Anlık Loss: 0.4676
# Epoch [7] | Adım [2000/3939] | Anlık Loss: 0.0104
# Epoch [7] | Adım [2050/3939] | Anlık Loss: 0.0456
# Epoch [7] | Adım [2100/3939] | Anlık Loss: 0.0003
# Epoch [7] | Adım [2150/3939] | Anlık Loss: 0.0017
# Epoch [7] | Adım [2200/3939] | Anlık Loss: 0.0236
# Epoch [7] | Adım [2250/3939] | Anlık Loss: 0.0823
# Epoch [7] | Adım [2300/3939] | Anlık Loss: 0.0563
# Epoch [7] | Adım [2350/3939] | Anlık Loss: 0.0013
# Epoch [7] | Adım [2400/3939] | Anlık Loss: 0.1046
# Epoch [7] | Adım [2450/3939] | Anlık Loss: 0.0027
# Epoch [7] | Adım [2500/3939] | Anlık Loss: 0.0630
# Epoch [7] | Adım [2550/3939] | Anlık Loss: 0.0046
# Epoch [7] | Adım [2600/3939] | Anlık Loss: 0.5288
# Epoch [7] | Adım [2650/3939] | Anlık Loss: 0.3100
# Epoch [7] | Adım [2700/3939] | Anlık Loss: 0.3455
# Epoch [7] | Adım [2750/3939] | Anlık Loss: 0.1484
# Epoch [7] | Adım [2800/3939] | Anlık Loss: 0.0065
# Epoch [7] | Adım [2850/3939] | Anlık Loss: 0.0033
# Epoch [7] | Adım [2900/3939] | Anlık Loss: 0.0011
# Epoch [7] | Adım [2950/3939] | Anlık Loss: 0.0376
# Epoch [7] | Adım [3000/3939] | Anlık Loss: 0.0488
# Epoch [7] | Adım [3050/3939] | Anlık Loss: 0.2502
# Epoch [7] | Adım [3100/3939] | Anlık Loss: 0.0054
# Epoch [7] | Adım [3150/3939] | Anlık Loss: 0.0026
# Epoch [7] | Adım [3200/3939] | Anlık Loss: 0.0007
# Epoch [7] | Adım [3250/3939] | Anlık Loss: 0.1686
# Epoch [7] | Adım [3300/3939] | Anlık Loss: 0.1937
# Epoch [7] | Adım [3350/3939] | Anlık Loss: 0.0002
# Epoch [7] | Adım [3400/3939] | Anlık Loss: 0.0580
# Epoch [7] | Adım [3450/3939] | Anlık Loss: 0.0515
# Epoch [7] | Adım [3500/3939] | Anlık Loss: 0.2296
# Epoch [7] | Adım [3550/3939] | Anlık Loss: 0.0148
# Epoch [7] | Adım [3600/3939] | Anlık Loss: 0.1176
# Epoch [7] | Adım [3650/3939] | Anlık Loss: 0.0009
# Epoch [7] | Adım [3700/3939] | Anlık Loss: 0.0480
# Epoch [7] | Adım [3750/3939] | Anlık Loss: 0.2821
# Epoch [7] | Adım [3800/3939] | Anlık Loss: 0.1018
# Epoch [7] | Adım [3850/3939] | Anlık Loss: 0.0169
# Epoch [7] | Adım [3900/3939] | Anlık Loss: 0.3636
# Epoch 7 Bitti (573.1 sn) | Train Acc: %97.31 | Loss: 0.0863
# Doğrulama (Validation) yapılıyor...
# VAL ACC: %97.13
# ------------------------------------------------------------
# Epoch [8] | Adım [50/3939] | Anlık Loss: 0.0280
# Epoch [8] | Adım [100/3939] | Anlık Loss: 0.0462
# Epoch [8] | Adım [150/3939] | Anlık Loss: 0.0011
# Epoch [8] | Adım [200/3939] | Anlık Loss: 0.0121
# Epoch [8] | Adım [250/3939] | Anlık Loss: 0.0535
# Epoch [8] | Adım [300/3939] | Anlık Loss: 0.3746
# Epoch [8] | Adım [350/3939] | Anlık Loss: 0.1865
# Epoch [8] | Adım [400/3939] | Anlık Loss: 0.0023
# Epoch [8] | Adım [450/3939] | Anlık Loss: 0.0030
# Epoch [8] | Adım [500/3939] | Anlık Loss: 0.0016
# Epoch [8] | Adım [550/3939] | Anlık Loss: 0.0003
# Epoch [8] | Adım [600/3939] | Anlık Loss: 0.0289
# Epoch [8] | Adım [650/3939] | Anlık Loss: 0.0357
# Epoch [8] | Adım [700/3939] | Anlık Loss: 0.0073
# Epoch [8] | Adım [750/3939] | Anlık Loss: 0.0093
# Epoch [8] | Adım [800/3939] | Anlık Loss: 0.0315
# Epoch [8] | Adım [850/3939] | Anlık Loss: 0.0130
# Epoch [8] | Adım [900/3939] | Anlık Loss: 0.0004
# Epoch [8] | Adım [950/3939] | Anlık Loss: 0.0100
# Epoch [8] | Adım [1000/3939] | Anlık Loss: 0.5532
# Epoch [8] | Adım [1050/3939] | Anlık Loss: 0.0074
# Epoch [8] | Adım [1100/3939] | Anlık Loss: 0.0037
# Epoch [8] | Adım [1150/3939] | Anlık Loss: 0.0692
# Epoch [8] | Adım [1200/3939] | Anlık Loss: 0.3081
# Epoch [8] | Adım [1250/3939] | Anlık Loss: 0.0004
# Epoch [8] | Adım [1300/3939] | Anlık Loss: 0.0564
# Epoch [8] | Adım [1350/3939] | Anlık Loss: 0.0014
# Epoch [8] | Adım [1400/3939] | Anlık Loss: 0.0539
# Epoch [8] | Adım [1450/3939] | Anlık Loss: 0.1736
# Epoch [8] | Adım [1500/3939] | Anlık Loss: 0.1448
# Epoch [8] | Adım [1550/3939] | Anlık Loss: 0.0842
# Epoch [8] | Adım [1600/3939] | Anlık Loss: 0.0244
# Epoch [8] | Adım [1650/3939] | Anlık Loss: 0.2143
# Epoch [8] | Adım [1700/3939] | Anlık Loss: 0.5438
# Epoch [8] | Adım [1750/3939] | Anlık Loss: 0.0514
# Epoch [8] | Adım [1800/3939] | Anlık Loss: 0.0277
# Epoch [8] | Adım [1850/3939] | Anlık Loss: 0.0792
# Epoch [8] | Adım [1900/3939] | Anlık Loss: 0.0093
# Epoch [8] | Adım [1950/3939] | Anlık Loss: 0.0170
# Epoch [8] | Adım [2000/3939] | Anlık Loss: 0.0003
# Epoch [8] | Adım [2050/3939] | Anlık Loss: 0.0104
# Epoch [8] | Adım [2100/3939] | Anlık Loss: 0.0774
# Epoch [8] | Adım [2150/3939] | Anlık Loss: 0.0005
# Epoch [8] | Adım [2200/3939] | Anlık Loss: 0.0043
# Epoch [8] | Adım [2250/3939] | Anlık Loss: 0.0268
# Epoch [8] | Adım [2300/3939] | Anlık Loss: 0.0114
# Epoch [8] | Adım [2350/3939] | Anlık Loss: 0.0030
# Epoch [8] | Adım [2400/3939] | Anlık Loss: 0.0157
# Epoch [8] | Adım [2450/3939] | Anlık Loss: 0.2153
# Epoch [8] | Adım [2500/3939] | Anlık Loss: 0.0028
# Epoch [8] | Adım [2550/3939] | Anlık Loss: 0.1089
# Epoch [8] | Adım [2600/3939] | Anlık Loss: 0.1394
# Epoch [8] | Adım [2650/3939] | Anlık Loss: 0.1497
# Epoch [8] | Adım [2700/3939] | Anlık Loss: 0.2882
# Epoch [8] | Adım [2750/3939] | Anlık Loss: 0.0051
# Epoch [8] | Adım [2800/3939] | Anlık Loss: 0.1940
# Epoch [8] | Adım [2850/3939] | Anlık Loss: 0.0509
# Epoch [8] | Adım [2900/3939] | Anlık Loss: 0.0010
# Epoch [8] | Adım [2950/3939] | Anlık Loss: 0.0448
# Epoch [8] | Adım [3000/3939] | Anlık Loss: 0.0233
# Epoch [8] | Adım [3050/3939] | Anlık Loss: 0.0046
# Epoch [8] | Adım [3100/3939] | Anlık Loss: 0.0001
# Epoch [8] | Adım [3150/3939] | Anlık Loss: 0.0251
# Epoch [8] | Adım [3200/3939] | Anlık Loss: 0.2183
# Epoch [8] | Adım [3250/3939] | Anlık Loss: 0.2941
# Epoch [8] | Adım [3300/3939] | Anlık Loss: 0.1466
# Epoch [8] | Adım [3350/3939] | Anlık Loss: 0.1722
# Epoch [8] | Adım [3400/3939] | Anlık Loss: 0.0005
# Epoch [8] | Adım [3450/3939] | Anlık Loss: 0.0066
# Epoch [8] | Adım [3500/3939] | Anlık Loss: 0.1443
# Epoch [8] | Adım [3550/3939] | Anlık Loss: 0.0170
# Epoch [8] | Adım [3600/3939] | Anlık Loss: 0.0102
# Epoch [8] | Adım [3650/3939] | Anlık Loss: 0.0004
# Epoch [8] | Adım [3700/3939] | Anlık Loss: 0.2786
# Epoch [8] | Adım [3750/3939] | Anlık Loss: 0.0016
# Epoch [8] | Adım [3800/3939] | Anlık Loss: 0.0030
# Epoch [8] | Adım [3850/3939] | Anlık Loss: 0.0258
# Epoch [8] | Adım [3900/3939] | Anlık Loss: 0.0902
# Epoch 8 Bitti (570.5 sn) | Train Acc: %97.46 | Loss: 0.0806
# Doğrulama (Validation) yapılıyor...
# VAL ACC: %97.26
# ------------------------------------------------------------
# Epoch [9] | Adım [50/3939] | Anlık Loss: 0.0173
# Epoch [9] | Adım [100/3939] | Anlık Loss: 0.0018
# Epoch [9] | Adım [150/3939] | Anlık Loss: 0.0255
# Epoch [9] | Adım [200/3939] | Anlık Loss: 0.0123
# Epoch [9] | Adım [250/3939] | Anlık Loss: 0.2339
# Epoch [9] | Adım [300/3939] | Anlık Loss: 0.0332
# Epoch [9] | Adım [350/3939] | Anlık Loss: 0.1386
# Epoch [9] | Adım [400/3939] | Anlık Loss: 0.1162
# Epoch [9] | Adım [450/3939] | Anlık Loss: 0.0340
# Epoch [9] | Adım [500/3939] | Anlık Loss: 0.1794
# Epoch [9] | Adım [550/3939] | Anlık Loss: 0.2426
# Epoch [9] | Adım [600/3939] | Anlık Loss: 0.0176
# Epoch [9] | Adım [650/3939] | Anlık Loss: 0.2249
# Epoch [9] | Adım [700/3939] | Anlık Loss: 0.0035
# Epoch [9] | Adım [750/3939] | Anlık Loss: 0.1113
# Epoch [9] | Adım [800/3939] | Anlık Loss: 0.0292
# Epoch [9] | Adım [850/3939] | Anlık Loss: 0.4139
# Epoch [9] | Adım [900/3939] | Anlık Loss: 0.0467
# Epoch [9] | Adım [950/3939] | Anlık Loss: 0.0677
# Epoch [9] | Adım [1000/3939] | Anlık Loss: 0.0419
# Epoch [9] | Adım [1050/3939] | Anlık Loss: 0.4099
# Epoch [9] | Adım [1100/3939] | Anlık Loss: 0.0211
# Epoch [9] | Adım [1150/3939] | Anlık Loss: 0.0820
# Epoch [9] | Adım [1200/3939] | Anlık Loss: 0.0126
# Epoch [9] | Adım [1250/3939] | Anlık Loss: 0.0176
# Epoch [9] | Adım [1300/3939] | Anlık Loss: 0.2253
# Epoch [9] | Adım [1350/3939] | Anlık Loss: 0.1476
# Epoch [9] | Adım [1400/3939] | Anlık Loss: 0.3362
# Epoch [9] | Adım [1450/3939] | Anlık Loss: 0.0226
# Epoch [9] | Adım [1500/3939] | Anlık Loss: 0.0634
# Epoch [9] | Adım [1550/3939] | Anlık Loss: 0.0117
# Epoch [9] | Adım [1600/3939] | Anlık Loss: 0.0029
# Epoch [9] | Adım [1650/3939] | Anlık Loss: 0.1110
# Epoch [9] | Adım [1700/3939] | Anlık Loss: 0.0013
# Epoch [9] | Adım [1750/3939] | Anlık Loss: 0.2087
# Epoch [9] | Adım [1800/3939] | Anlık Loss: 0.0217
# Epoch [9] | Adım [1850/3939] | Anlık Loss: 0.0027
# Epoch [9] | Adım [1900/3939] | Anlık Loss: 0.0006
# Epoch [9] | Adım [1950/3939] | Anlık Loss: 0.0011
# Epoch [9] | Adım [2000/3939] | Anlık Loss: 0.0085
# Epoch [9] | Adım [2050/3939] | Anlık Loss: 0.0429
# Epoch [9] | Adım [2100/3939] | Anlık Loss: 0.0077
# Epoch [9] | Adım [2150/3939] | Anlık Loss: 0.0152
# Epoch [9] | Adım [2200/3939] | Anlık Loss: 0.0941
# Epoch [9] | Adım [2250/3939] | Anlık Loss: 0.0126
# Epoch [9] | Adım [2300/3939] | Anlık Loss: 0.0382
# Epoch [9] | Adım [2350/3939] | Anlık Loss: 0.0020
# Epoch [9] | Adım [2400/3939] | Anlık Loss: 0.0242
# Epoch [9] | Adım [2450/3939] | Anlık Loss: 0.0028
# Epoch [9] | Adım [2500/3939] | Anlık Loss: 0.0024
# Epoch [9] | Adım [2550/3939] | Anlık Loss: 0.1534
# Epoch [9] | Adım [2600/3939] | Anlık Loss: 0.2870
# Epoch [9] | Adım [2650/3939] | Anlık Loss: 0.0131
# Epoch [9] | Adım [2700/3939] | Anlık Loss: 0.0000
# Epoch [9] | Adım [2750/3939] | Anlık Loss: 0.0113
# Epoch [9] | Adım [2800/3939] | Anlık Loss: 0.0023
# Epoch [9] | Adım [2850/3939] | Anlık Loss: 0.0238
# Epoch [9] | Adım [2900/3939] | Anlık Loss: 0.0522
# Epoch [9] | Adım [2950/3939] | Anlık Loss: 0.0994
# Epoch [9] | Adım [3000/3939] | Anlık Loss: 0.1487
# Epoch [9] | Adım [3050/3939] | Anlık Loss: 0.0001
# Epoch [9] | Adım [3100/3939] | Anlık Loss: 0.0752
# Epoch [9] | Adım [3150/3939] | Anlık Loss: 0.1706
# Epoch [9] | Adım [3200/3939] | Anlık Loss: 0.0023
# Epoch [9] | Adım [3250/3939] | Anlık Loss: 0.0055
# Epoch [9] | Adım [3300/3939] | Anlık Loss: 0.2045
# Epoch [9] | Adım [3350/3939] | Anlık Loss: 0.1087
# Epoch [9] | Adım [3400/3939] | Anlık Loss: 0.0354
# Epoch [9] | Adım [3450/3939] | Anlık Loss: 0.0076
# Epoch [9] | Adım [3500/3939] | Anlık Loss: 0.0258
# Epoch [9] | Adım [3550/3939] | Anlık Loss: 0.0532
# Epoch [9] | Adım [3600/3939] | Anlık Loss: 0.0144
# Epoch [9] | Adım [3650/3939] | Anlık Loss: 0.0187
# Epoch [9] | Adım [3700/3939] | Anlık Loss: 0.0006
# Epoch [9] | Adım [3750/3939] | Anlık Loss: 0.0113
# Epoch [9] | Adım [3800/3939] | Anlık Loss: 0.0044
# Epoch [9] | Adım [3850/3939] | Anlık Loss: 0.0387
# Epoch [9] | Adım [3900/3939] | Anlık Loss: 0.0005
# Epoch 9 Bitti (568.9 sn) | Train Acc: %97.80 | Loss: 0.0728
# Doğrulama (Validation) yapılıyor...
# VAL ACC: %97.82
# ------------------------------------------------------------
# Epoch [10] | Adım [50/3939] | Anlık Loss: 0.0250
# Epoch [10] | Adım [100/3939] | Anlık Loss: 0.6497
# Epoch [10] | Adım [150/3939] | Anlık Loss: 0.0082
# Epoch [10] | Adım [200/3939] | Anlık Loss: 0.0031
# Epoch [10] | Adım [250/3939] | Anlık Loss: 0.0054
# Epoch [10] | Adım [300/3939] | Anlık Loss: 0.0235
# Epoch [10] | Adım [350/3939] | Anlık Loss: 0.0065
# Epoch [10] | Adım [400/3939] | Anlık Loss: 0.0006
# Epoch [10] | Adım [450/3939] | Anlık Loss: 0.1305
# Epoch [10] | Adım [500/3939] | Anlık Loss: 0.0009
# Epoch [10] | Adım [550/3939] | Anlık Loss: 0.0003
# Epoch [10] | Adım [600/3939] | Anlık Loss: 0.0470
# Epoch [10] | Adım [650/3939] | Anlık Loss: 0.0025
# Epoch [10] | Adım [700/3939] | Anlık Loss: 0.0036
# Epoch [10] | Adım [750/3939] | Anlık Loss: 0.0049
# Epoch [10] | Adım [800/3939] | Anlık Loss: 0.0062
# Epoch [10] | Adım [850/3939] | Anlık Loss: 0.0020
# Epoch [10] | Adım [900/3939] | Anlık Loss: 0.2954
# Epoch [10] | Adım [950/3939] | Anlık Loss: 0.0610
# Epoch [10] | Adım [1000/3939] | Anlık Loss: 0.3286
# Epoch [10] | Adım [1050/3939] | Anlık Loss: 0.0655
# Epoch [10] | Adım [1100/3939] | Anlık Loss: 0.0089
# Epoch [10] | Adım [1150/3939] | Anlık Loss: 0.0387
# Epoch [10] | Adım [1200/3939] | Anlık Loss: 0.2695
# Epoch [10] | Adım [1250/3939] | Anlık Loss: 0.0214
# Epoch [10] | Adım [1300/3939] | Anlık Loss: 0.0031
# Epoch [10] | Adım [1350/3939] | Anlık Loss: 0.0092
# Epoch [10] | Adım [1400/3939] | Anlık Loss: 0.0126
# Epoch [10] | Adım [1450/3939] | Anlık Loss: 0.0128
# Epoch [10] | Adım [1500/3939] | Anlık Loss: 0.0084
# Epoch [10] | Adım [1550/3939] | Anlık Loss: 0.0019
# Epoch [10] | Adım [1600/3939] | Anlık Loss: 0.0033
# Epoch [10] | Adım [1650/3939] | Anlık Loss: 0.0093
# Epoch [10] | Adım [1700/3939] | Anlık Loss: 0.0725
# Epoch [10] | Adım [1750/3939] | Anlık Loss: 0.0064
# Epoch [10] | Adım [1800/3939] | Anlık Loss: 0.0471
# Epoch [10] | Adım [1850/3939] | Anlık Loss: 0.0343
# Epoch [10] | Adım [1900/3939] | Anlık Loss: 0.0060
# Epoch [10] | Adım [1950/3939] | Anlık Loss: 0.0243
# Epoch [10] | Adım [2000/3939] | Anlık Loss: 0.0048
# Epoch [10] | Adım [2050/3939] | Anlık Loss: 0.0556
# Epoch [10] | Adım [2100/3939] | Anlık Loss: 0.0023
# Epoch [10] | Adım [2150/3939] | Anlık Loss: 0.0608
# Epoch [10] | Adım [2200/3939] | Anlık Loss: 0.0320
# Epoch [10] | Adım [2250/3939] | Anlık Loss: 0.0008
# Epoch [10] | Adım [2300/3939] | Anlık Loss: 0.3033
# Epoch [10] | Adım [2350/3939] | Anlık Loss: 0.0025
# Epoch [10] | Adım [2400/3939] | Anlık Loss: 0.0122
# Epoch [10] | Adım [2450/3939] | Anlık Loss: 0.0003
# Epoch [10] | Adım [2500/3939] | Anlık Loss: 0.0094
# Epoch [10] | Adım [2550/3939] | Anlık Loss: 0.0027
# Epoch [10] | Adım [2600/3939] | Anlık Loss: 0.3042
# Epoch [10] | Adım [2650/3939] | Anlık Loss: 0.0275
# Epoch [10] | Adım [2700/3939] | Anlık Loss: 0.0130
# Epoch [10] | Adım [2750/3939] | Anlık Loss: 0.1918
# Epoch [10] | Adım [2800/3939] | Anlık Loss: 0.0019
# Epoch [10] | Adım [2850/3939] | Anlık Loss: 0.0017
# Epoch [10] | Adım [2900/3939] | Anlık Loss: 0.0339
# Epoch [10] | Adım [2950/3939] | Anlık Loss: 0.0445
# Epoch [10] | Adım [3000/3939] | Anlık Loss: 0.0023
# Epoch [10] | Adım [3050/3939] | Anlık Loss: 0.0273
# Epoch [10] | Adım [3100/3939] | Anlık Loss: 0.0033
# Epoch [10] | Adım [3150/3939] | Anlık Loss: 0.0051
# Epoch [10] | Adım [3200/3939] | Anlık Loss: 0.0017
# Epoch [10] | Adım [3250/3939] | Anlık Loss: 0.1390
# Epoch [10] | Adım [3300/3939] | Anlık Loss: 0.0153
# Epoch [10] | Adım [3350/3939] | Anlık Loss: 0.0110
# Epoch [10] | Adım [3400/3939] | Anlık Loss: 0.0019
# Epoch [10] | Adım [3450/3939] | Anlık Loss: 0.0051
# Epoch [10] | Adım [3500/3939] | Anlık Loss: 0.0001
# Epoch [10] | Adım [3550/3939] | Anlık Loss: 0.0070
# Epoch [10] | Adım [3600/3939] | Anlık Loss: 0.0009
# Epoch [10] | Adım [3650/3939] | Anlık Loss: 0.2085
# Epoch [10] | Adım [3700/3939] | Anlık Loss: 0.0225
# Epoch [10] | Adım [3750/3939] | Anlık Loss: 0.1170
# Epoch [10] | Adım [3800/3939] | Anlık Loss: 0.0086
# Epoch [10] | Adım [3850/3939] | Anlık Loss: 0.0021
# Epoch [10] | Adım [3900/3939] | Anlık Loss: 0.1182
# Epoch 10 Bitti (568.1 sn) | Train Acc: %97.93 | Loss: 0.0673
# Doğrulama (Validation) yapılıyor...
# VAL ACC: %98.30
# ------------------------------------------------------------
# Epoch [11] | Adım [50/3939] | Anlık Loss: 0.0003
# Epoch [11] | Adım [100/3939] | Anlık Loss: 0.0322
# Epoch [11] | Adım [150/3939] | Anlık Loss: 0.0019
# Epoch [11] | Adım [200/3939] | Anlık Loss: 0.0051
# Epoch [11] | Adım [250/3939] | Anlık Loss: 0.0062
# Epoch [11] | Adım [300/3939] | Anlık Loss: 0.4095
# Epoch [11] | Adım [350/3939] | Anlık Loss: 0.0048
# Epoch [11] | Adım [400/3939] | Anlık Loss: 0.0010
# Epoch [11] | Adım [450/3939] | Anlık Loss: 0.0033
# Epoch [11] | Adım [500/3939] | Anlık Loss: 0.0002
# Epoch [11] | Adım [550/3939] | Anlık Loss: 0.0000
# Epoch [11] | Adım [600/3939] | Anlık Loss: 0.1617
# Epoch [11] | Adım [650/3939] | Anlık Loss: 0.0002
# Epoch [11] | Adım [700/3939] | Anlık Loss: 0.0042
# Epoch [11] | Adım [750/3939] | Anlık Loss: 0.0005
# Epoch [11] | Adım [800/3939] | Anlık Loss: 0.0040
# Epoch [11] | Adım [850/3939] | Anlık Loss: 0.2132
# Epoch [11] | Adım [900/3939] | Anlık Loss: 0.0120
# Epoch [11] | Adım [950/3939] | Anlık Loss: 0.0833
# Epoch [11] | Adım [1000/3939] | Anlık Loss: 0.2612
# Epoch [11] | Adım [1050/3939] | Anlık Loss: 0.0004
# Epoch [11] | Adım [1100/3939] | Anlık Loss: 0.0199
# Epoch [11] | Adım [1150/3939] | Anlık Loss: 0.0001
# Epoch [11] | Adım [1200/3939] | Anlık Loss: 0.0598
# Epoch [11] | Adım [1250/3939] | Anlık Loss: 0.0010
# Epoch [11] | Adım [1300/3939] | Anlık Loss: 0.2428
# Epoch [11] | Adım [1350/3939] | Anlık Loss: 0.0459
# Epoch [11] | Adım [1400/3939] | Anlık Loss: 0.0018
# Epoch [11] | Adım [1450/3939] | Anlık Loss: 0.0168
# Epoch [11] | Adım [1500/3939] | Anlık Loss: 0.0404
# Epoch [11] | Adım [1550/3939] | Anlık Loss: 0.0012
# Epoch [11] | Adım [1600/3939] | Anlık Loss: 0.0684
# Epoch [11] | Adım [1650/3939] | Anlık Loss: 0.0173
# Epoch [11] | Adım [1700/3939] | Anlık Loss: 0.1513
# Epoch [11] | Adım [1750/3939] | Anlık Loss: 0.1354
# Epoch [11] | Adım [1800/3939] | Anlık Loss: 0.0162
# Epoch [11] | Adım [1850/3939] | Anlık Loss: 0.0612
# Epoch [11] | Adım [1900/3939] | Anlık Loss: 0.0759
# Epoch [11] | Adım [1950/3939] | Anlık Loss: 0.1986
# Epoch [11] | Adım [2000/3939] | Anlık Loss: 0.0585
# Epoch [11] | Adım [2050/3939] | Anlık Loss: 0.0685
# Epoch [11] | Adım [2100/3939] | Anlık Loss: 0.0693
# Epoch [11] | Adım [2150/3939] | Anlık Loss: 0.0158
# Epoch [11] | Adım [2200/3939] | Anlık Loss: 0.1733
# Epoch [11] | Adım [2250/3939] | Anlık Loss: 0.3067
# Epoch [11] | Adım [2300/3939] | Anlık Loss: 0.0008
# Epoch [11] | Adım [2350/3939] | Anlık Loss: 0.0025
# Epoch [11] | Adım [2400/3939] | Anlık Loss: 0.0508
# Epoch [11] | Adım [2450/3939] | Anlık Loss: 0.6524
# Epoch [11] | Adım [2500/3939] | Anlık Loss: 0.0014
# Epoch [11] | Adım [2550/3939] | Anlık Loss: 0.2765
# Epoch [11] | Adım [2600/3939] | Anlık Loss: 0.0698
# Epoch [11] | Adım [2650/3939] | Anlık Loss: 0.0343
# Epoch [11] | Adım [2700/3939] | Anlık Loss: 0.0023
# Epoch [11] | Adım [2750/3939] | Anlık Loss: 0.0063
# Epoch [11] | Adım [2800/3939] | Anlık Loss: 0.1160
# Epoch [11] | Adım [2850/3939] | Anlık Loss: 0.0026
# Epoch [11] | Adım [2900/3939] | Anlık Loss: 0.0277
# Epoch [11] | Adım [2950/3939] | Anlık Loss: 0.0017
# Epoch [11] | Adım [3000/3939] | Anlık Loss: 0.0702
# Epoch [11] | Adım [3050/3939] | Anlık Loss: 0.1354
# Epoch [11] | Adım [3100/3939] | Anlık Loss: 0.0890
# Epoch [11] | Adım [3150/3939] | Anlık Loss: 0.0055
# Epoch [11] | Adım [3200/3939] | Anlık Loss: 0.0924
# Epoch [11] | Adım [3250/3939] | Anlık Loss: 0.0036
# Epoch [11] | Adım [3300/3939] | Anlık Loss: 0.1958
# Epoch [11] | Adım [3350/3939] | Anlık Loss: 0.0260
# Epoch [11] | Adım [3400/3939] | Anlık Loss: 0.0028
# Epoch [11] | Adım [3450/3939] | Anlık Loss: 0.0117
# Epoch [11] | Adım [3500/3939] | Anlık Loss: 0.0173
# Epoch [11] | Adım [3550/3939] | Anlık Loss: 0.1612
# Epoch [11] | Adım [3600/3939] | Anlık Loss: 0.0058
# Epoch [11] | Adım [3650/3939] | Anlık Loss: 0.0008
# Epoch [11] | Adım [3700/3939] | Anlık Loss: 0.0250
# Epoch [11] | Adım [3750/3939] | Anlık Loss: 0.0014
# Epoch [11] | Adım [3800/3939] | Anlık Loss: 0.0003
# Epoch [11] | Adım [3850/3939] | Anlık Loss: 0.0002
# Epoch [11] | Adım [3900/3939] | Anlık Loss: 0.0091
# Epoch 11 Bitti (569.2 sn) | Train Acc: %98.02 | Loss: 0.0629
# Doğrulama (Validation) yapılıyor...
# VAL ACC: %98.13
# ------------------------------------------------------------
# Epoch [12] | Adım [50/3939] | Anlık Loss: 0.0004
# Epoch [12] | Adım [100/3939] | Anlık Loss: 0.0084
# Epoch [12] | Adım [150/3939] | Anlık Loss: 0.2124
# Epoch [12] | Adım [200/3939] | Anlık Loss: 0.0152
# Epoch [12] | Adım [250/3939] | Anlık Loss: 0.0040
# Epoch [12] | Adım [300/3939] | Anlık Loss: 0.3159
# Epoch [12] | Adım [350/3939] | Anlık Loss: 0.0042
# Epoch [12] | Adım [400/3939] | Anlık Loss: 0.2259
# Epoch [12] | Adım [450/3939] | Anlık Loss: 0.0117
# Epoch [12] | Adım [500/3939] | Anlık Loss: 0.0434
# Epoch [12] | Adım [550/3939] | Anlık Loss: 0.0007
# Epoch [12] | Adım [600/3939] | Anlık Loss: 0.0141
# Epoch [12] | Adım [650/3939] | Anlık Loss: 0.0107
# Epoch [12] | Adım [700/3939] | Anlık Loss: 0.0098
# Epoch [12] | Adım [750/3939] | Anlık Loss: 0.0093
# Epoch [12] | Adım [800/3939] | Anlık Loss: 0.0646
# Epoch [12] | Adım [850/3939] | Anlık Loss: 0.3032
# Epoch [12] | Adım [900/3939] | Anlık Loss: 0.0204
# Epoch [12] | Adım [950/3939] | Anlık Loss: 0.0135
# Epoch [12] | Adım [1000/3939] | Anlık Loss: 0.0279
# Epoch [12] | Adım [1050/3939] | Anlık Loss: 0.0017
# Epoch [12] | Adım [1100/3939] | Anlık Loss: 0.0749
# Epoch [12] | Adım [1150/3939] | Anlık Loss: 0.0009
# Epoch [12] | Adım [1200/3939] | Anlık Loss: 0.0003
# Epoch [12] | Adım [1250/3939] | Anlık Loss: 0.0001
# Epoch [12] | Adım [1300/3939] | Anlık Loss: 0.0750
# Epoch [12] | Adım [1350/3939] | Anlık Loss: 0.0119
# Epoch [12] | Adım [1400/3939] | Anlık Loss: 0.2510
# Epoch [12] | Adım [1450/3939] | Anlık Loss: 0.0020
# Epoch [12] | Adım [1500/3939] | Anlık Loss: 0.0133
# Epoch [12] | Adım [1550/3939] | Anlık Loss: 0.0032
# Epoch [12] | Adım [1600/3939] | Anlık Loss: 0.1473
# Epoch [12] | Adım [1650/3939] | Anlık Loss: 0.0050
# Epoch [12] | Adım [1700/3939] | Anlık Loss: 0.2097
# Epoch [12] | Adım [1750/3939] | Anlık Loss: 0.0003
# Epoch [12] | Adım [1800/3939] | Anlık Loss: 0.0026
# Epoch [12] | Adım [1850/3939] | Anlık Loss: 0.1485
# Epoch [12] | Adım [1900/3939] | Anlık Loss: 0.0141
# Epoch [12] | Adım [1950/3939] | Anlık Loss: 0.1415
# Epoch [12] | Adım [2000/3939] | Anlık Loss: 0.3250
# Epoch [12] | Adım [2050/3939] | Anlık Loss: 0.0984
# Epoch [12] | Adım [2100/3939] | Anlık Loss: 0.0056
# Epoch [12] | Adım [2150/3939] | Anlık Loss: 0.1261
# Epoch [12] | Adım [2200/3939] | Anlık Loss: 0.0098
# Epoch [12] | Adım [2250/3939] | Anlık Loss: 0.0248
# Epoch [12] | Adım [2300/3939] | Anlık Loss: 0.0004
# Epoch [12] | Adım [2350/3939] | Anlık Loss: 0.0028
# Epoch [12] | Adım [2400/3939] | Anlık Loss: 0.0325
# Epoch [12] | Adım [2450/3939] | Anlık Loss: 0.1807
# Epoch [12] | Adım [2500/3939] | Anlık Loss: 0.0115
# Epoch [12] | Adım [2550/3939] | Anlık Loss: 0.0014
# Epoch [12] | Adım [2600/3939] | Anlık Loss: 0.0006
# Epoch [12] | Adım [2650/3939] | Anlık Loss: 0.1310
# Epoch [12] | Adım [2700/3939] | Anlık Loss: 0.0009
# Epoch [12] | Adım [2750/3939] | Anlık Loss: 0.0052
# Epoch [12] | Adım [2800/3939] | Anlık Loss: 0.0049
# Epoch [12] | Adım [2850/3939] | Anlık Loss: 0.0130
# Epoch [12] | Adım [2900/3939] | Anlık Loss: 0.1056
# Epoch [12] | Adım [2950/3939] | Anlık Loss: 0.0819
# Epoch [12] | Adım [3000/3939] | Anlık Loss: 0.1404
# Epoch [12] | Adım [3050/3939] | Anlık Loss: 0.0030
# Epoch [12] | Adım [3100/3939] | Anlık Loss: 0.3970
# Epoch [12] | Adım [3150/3939] | Anlık Loss: 0.6461
# Epoch [12] | Adım [3200/3939] | Anlık Loss: 0.1441
# Epoch [12] | Adım [3250/3939] | Anlık Loss: 0.0525
# Epoch [12] | Adım [3300/3939] | Anlık Loss: 0.0295
# Epoch [12] | Adım [3350/3939] | Anlık Loss: 0.0005
# Epoch [12] | Adım [3400/3939] | Anlık Loss: 0.0160
# Epoch [12] | Adım [3450/3939] | Anlık Loss: 0.0259
# Epoch [12] | Adım [3500/3939] | Anlık Loss: 0.0368
# Epoch [12] | Adım [3550/3939] | Anlık Loss: 0.0001
# Epoch [12] | Adım [3600/3939] | Anlık Loss: 0.0490
# Epoch [12] | Adım [3650/3939] | Anlık Loss: 0.0181
# Epoch [12] | Adım [3700/3939] | Anlık Loss: 0.0135
# Epoch [12] | Adım [3750/3939] | Anlık Loss: 0.0393
# Epoch [12] | Adım [3800/3939] | Anlık Loss: 0.0132
# Epoch [12] | Adım [3850/3939] | Anlık Loss: 0.0001
# Epoch [12] | Adım [3900/3939] | Anlık Loss: 0.0336
# Epoch 12 Bitti (569.1 sn) | Train Acc: %98.17 | Loss: 0.0573
# Doğrulama (Validation) yapılıyor...
# VAL ACC: %97.66
# ------------------------------------------------------------
# Epoch [13] | Adım [50/3939] | Anlık Loss: 0.0082
# Epoch [13] | Adım [100/3939] | Anlık Loss: 0.0005
# Epoch [13] | Adım [150/3939] | Anlık Loss: 0.0057
# Epoch [13] | Adım [200/3939] | Anlık Loss: 0.0022
# Epoch [13] | Adım [250/3939] | Anlık Loss: 0.0011
# Epoch [13] | Adım [300/3939] | Anlık Loss: 0.0007
# Epoch [13] | Adım [350/3939] | Anlık Loss: 0.0035
# Epoch [13] | Adım [400/3939] | Anlık Loss: 0.1274
# Epoch [13] | Adım [450/3939] | Anlık Loss: 0.0116
# Epoch [13] | Adım [500/3939] | Anlık Loss: 0.0020
# Epoch [13] | Adım [550/3939] | Anlık Loss: 0.0007
# Epoch [13] | Adım [600/3939] | Anlık Loss: 0.0095
# Epoch [13] | Adım [650/3939] | Anlık Loss: 0.0011
# Epoch [13] | Adım [700/3939] | Anlık Loss: 0.0022
# Epoch [13] | Adım [750/3939] | Anlık Loss: 0.0001
# Epoch [13] | Adım [800/3939] | Anlık Loss: 0.0037
# Epoch [13] | Adım [850/3939] | Anlık Loss: 0.0037
# Epoch [13] | Adım [900/3939] | Anlık Loss: 0.0002
# Epoch [13] | Adım [950/3939] | Anlık Loss: 0.0509
# Epoch [13] | Adım [1000/3939] | Anlık Loss: 0.0271
# Epoch [13] | Adım [1050/3939] | Anlık Loss: 0.0023
# Epoch [13] | Adım [1100/3939] | Anlık Loss: 0.0133
# Epoch [13] | Adım [1150/3939] | Anlık Loss: 0.0049
# Epoch [13] | Adım [1200/3939] | Anlık Loss: 0.0437
# Epoch [13] | Adım [1250/3939] | Anlık Loss: 0.0773
# Epoch [13] | Adım [1300/3939] | Anlık Loss: 0.0846
# Epoch [13] | Adım [1350/3939] | Anlık Loss: 0.0452
# Epoch [13] | Adım [1400/3939] | Anlık Loss: 0.0005
# Epoch [13] | Adım [1450/3939] | Anlık Loss: 0.0014
# Epoch [13] | Adım [1500/3939] | Anlık Loss: 0.0040
# Epoch [13] | Adım [1550/3939] | Anlık Loss: 0.0531
# Epoch [13] | Adım [1600/3939] | Anlık Loss: 0.0005
# Epoch [13] | Adım [1650/3939] | Anlık Loss: 0.0043
# Epoch [13] | Adım [1700/3939] | Anlık Loss: 0.0706
# Epoch [13] | Adım [1750/3939] | Anlık Loss: 0.0033
# Epoch [13] | Adım [1800/3939] | Anlık Loss: 0.0408
# Epoch [13] | Adım [1850/3939] | Anlık Loss: 0.0894
# Epoch [13] | Adım [1900/3939] | Anlık Loss: 0.0364
# Epoch [13] | Adım [1950/3939] | Anlık Loss: 0.0110
# Epoch [13] | Adım [2000/3939] | Anlık Loss: 0.2447
# Epoch [13] | Adım [2050/3939] | Anlık Loss: 0.0019
# Epoch [13] | Adım [2100/3939] | Anlık Loss: 0.0000
# Epoch [13] | Adım [2150/3939] | Anlık Loss: 0.0141
# Epoch [13] | Adım [2200/3939] | Anlık Loss: 0.0002
# Epoch [13] | Adım [2250/3939] | Anlık Loss: 0.0090
# Epoch [13] | Adım [2300/3939] | Anlık Loss: 0.2079
# Epoch [13] | Adım [2350/3939] | Anlık Loss: 0.0001
# Epoch [13] | Adım [2400/3939] | Anlık Loss: 0.0968
# Epoch [13] | Adım [2450/3939] | Anlık Loss: 0.0007
# Epoch [13] | Adım [2500/3939] | Anlık Loss: 0.0342
# Epoch [13] | Adım [2550/3939] | Anlık Loss: 0.1956
# Epoch [13] | Adım [2600/3939] | Anlık Loss: 0.0015
# Epoch [13] | Adım [2650/3939] | Anlık Loss: 0.0032
# Epoch [13] | Adım [2700/3939] | Anlık Loss: 0.0031
# Epoch [13] | Adım [2750/3939] | Anlık Loss: 0.2493
# Epoch [13] | Adım [2800/3939] | Anlık Loss: 0.0257
# Epoch [13] | Adım [2850/3939] | Anlık Loss: 0.0709
# Epoch [13] | Adım [2900/3939] | Anlık Loss: 0.0008
# Epoch [13] | Adım [2950/3939] | Anlık Loss: 0.0049
# Epoch [13] | Adım [3000/3939] | Anlık Loss: 0.0009
# Epoch [13] | Adım [3050/3939] | Anlık Loss: 0.0063
# Epoch [13] | Adım [3100/3939] | Anlık Loss: 0.0016
# Epoch [13] | Adım [3150/3939] | Anlık Loss: 0.0798
# Epoch [13] | Adım [3200/3939] | Anlık Loss: 0.0108
# Epoch [13] | Adım [3250/3939] | Anlık Loss: 0.0013
# Epoch [13] | Adım [3300/3939] | Anlık Loss: 0.0117
# Epoch [13] | Adım [3350/3939] | Anlık Loss: 0.0027
# Epoch [13] | Adım [3400/3939] | Anlık Loss: 0.0005
# Epoch [13] | Adım [3450/3939] | Anlık Loss: 0.2521
# Epoch [13] | Adım [3500/3939] | Anlık Loss: 0.0095
# Epoch [13] | Adım [3550/3939] | Anlık Loss: 0.0098
# Epoch [13] | Adım [3600/3939] | Anlık Loss: 0.0054
# Epoch [13] | Adım [3650/3939] | Anlık Loss: 0.0003
# Epoch [13] | Adım [3700/3939] | Anlık Loss: 0.2743
# Epoch [13] | Adım [3750/3939] | Anlık Loss: 0.0014
# Epoch [13] | Adım [3800/3939] | Anlık Loss: 0.3245
# Epoch [13] | Adım [3850/3939] | Anlık Loss: 0.0029
# Epoch [13] | Adım [3900/3939] | Anlık Loss: 0.0037
# Epoch 13 Bitti (569.9 sn) | Train Acc: %98.31 | Loss: 0.0549
# Doğrulama (Validation) yapılıyor...
# VAL ACC: %98.31
# ------------------------------------------------------------
# Epoch [14] | Adım [50/3939] | Anlık Loss: 0.0015
# Epoch [14] | Adım [100/3939] | Anlık Loss: 0.0001
# Epoch [14] | Adım [150/3939] | Anlık Loss: 0.0013
# Epoch [14] | Adım [200/3939] | Anlık Loss: 0.0968
# Epoch [14] | Adım [250/3939] | Anlık Loss: 0.0009
# Epoch [14] | Adım [300/3939] | Anlık Loss: 0.0217
# Epoch [14] | Adım [350/3939] | Anlık Loss: 0.0205
# Epoch [14] | Adım [400/3939] | Anlık Loss: 0.5134
# Epoch [14] | Adım [450/3939] | Anlık Loss: 0.0001
# Epoch [14] | Adım [500/3939] | Anlık Loss: 0.0001
# Epoch [14] | Adım [550/3939] | Anlık Loss: 0.0146
# Epoch [14] | Adım [600/3939] | Anlık Loss: 0.0007
# Epoch [14] | Adım [650/3939] | Anlık Loss: 0.0009
# Epoch [14] | Adım [700/3939] | Anlık Loss: 0.0008
# Epoch [14] | Adım [750/3939] | Anlık Loss: 0.0026
# Epoch [14] | Adım [800/3939] | Anlık Loss: 0.0074
# Epoch [14] | Adım [850/3939] | Anlık Loss: 0.0632
# Epoch [14] | Adım [900/3939] | Anlık Loss: 0.0003
# Epoch [14] | Adım [950/3939] | Anlık Loss: 0.0025
# Epoch [14] | Adım [1000/3939] | Anlık Loss: 0.8379
# Epoch [14] | Adım [1050/3939] | Anlık Loss: 0.1633
# Epoch [14] | Adım [1100/3939] | Anlık Loss: 0.1763
# Epoch [14] | Adım [1150/3939] | Anlık Loss: 0.3639
# Epoch [14] | Adım [1200/3939] | Anlık Loss: 0.0008
# Epoch [14] | Adım [1250/3939] | Anlık Loss: 0.0003
# Epoch [14] | Adım [1300/3939] | Anlık Loss: 0.2190
# Epoch [14] | Adım [1350/3939] | Anlık Loss: 0.1428
# Epoch [14] | Adım [1400/3939] | Anlık Loss: 0.7555
# Epoch [14] | Adım [1450/3939] | Anlık Loss: 0.1431
# Epoch [14] | Adım [1500/3939] | Anlık Loss: 0.0001
# Epoch [14] | Adım [1550/3939] | Anlık Loss: 0.0001
# Epoch [14] | Adım [1600/3939] | Anlık Loss: 0.0012
# Epoch [14] | Adım [1650/3939] | Anlık Loss: 0.0003
# Epoch [14] | Adım [1700/3939] | Anlık Loss: 0.0004
# Epoch [14] | Adım [1750/3939] | Anlık Loss: 0.0004
# Epoch [14] | Adım [1800/3939] | Anlık Loss: 0.0009
# Epoch [14] | Adım [1850/3939] | Anlık Loss: 0.3684
# Epoch [14] | Adım [1900/3939] | Anlık Loss: 0.1206
# Epoch [14] | Adım [1950/3939] | Anlık Loss: 0.0033
# Epoch [14] | Adım [2000/3939] | Anlık Loss: 0.0006
# Epoch [14] | Adım [2050/3939] | Anlık Loss: 0.0004
# Epoch [14] | Adım [2100/3939] | Anlık Loss: 0.0061
# Epoch [14] | Adım [2150/3939] | Anlık Loss: 0.0000
# Epoch [14] | Adım [2200/3939] | Anlık Loss: 0.0502
# Epoch [14] | Adım [2250/3939] | Anlık Loss: 0.1285
# Epoch [14] | Adım [2300/3939] | Anlık Loss: 0.0032
# Epoch [14] | Adım [2350/3939] | Anlık Loss: 0.0239
# Epoch [14] | Adım [2400/3939] | Anlık Loss: 0.0142
# Epoch [14] | Adım [2450/3939] | Anlık Loss: 0.0004
# Epoch [14] | Adım [2500/3939] | Anlık Loss: 0.1952
# Epoch [14] | Adım [2550/3939] | Anlık Loss: 0.0529
# Epoch [14] | Adım [2600/3939] | Anlık Loss: 0.0189
# Epoch [14] | Adım [2650/3939] | Anlık Loss: 0.0396
# Epoch [14] | Adım [2700/3939] | Anlık Loss: 0.0005
# Epoch [14] | Adım [2750/3939] | Anlık Loss: 0.0053
# Epoch [14] | Adım [2800/3939] | Anlık Loss: 0.0023
# Epoch [14] | Adım [2850/3939] | Anlık Loss: 0.0261
# Epoch [14] | Adım [2900/3939] | Anlık Loss: 0.0017
# Epoch [14] | Adım [2950/3939] | Anlık Loss: 0.0001
# Epoch [14] | Adım [3000/3939] | Anlık Loss: 0.0025
# Epoch [14] | Adım [3050/3939] | Anlık Loss: 0.0018
# Epoch [14] | Adım [3100/3939] | Anlık Loss: 0.0001
# Epoch [14] | Adım [3150/3939] | Anlık Loss: 0.0043
# Epoch [14] | Adım [3200/3939] | Anlık Loss: 0.1165
# Epoch [14] | Adım [3250/3939] | Anlık Loss: 0.0046
# Epoch [14] | Adım [3300/3939] | Anlık Loss: 0.0016
# Epoch [14] | Adım [3350/3939] | Anlık Loss: 0.3327
# Epoch [14] | Adım [3400/3939] | Anlık Loss: 0.0005
# Epoch [14] | Adım [3450/3939] | Anlık Loss: 0.0067
# Epoch [14] | Adım [3500/3939] | Anlık Loss: 0.0370
# Epoch [14] | Adım [3550/3939] | Anlık Loss: 0.0044
# Epoch [14] | Adım [3600/3939] | Anlık Loss: 0.0077
# Epoch [14] | Adım [3650/3939] | Anlık Loss: 0.0564
# Epoch [14] | Adım [3700/3939] | Anlık Loss: 0.0081
# Epoch [14] | Adım [3750/3939] | Anlık Loss: 0.0425
# Epoch [14] | Adım [3800/3939] | Anlık Loss: 0.0017
# Epoch [14] | Adım [3850/3939] | Anlık Loss: 0.0002
# Epoch [14] | Adım [3900/3939] | Anlık Loss: 0.0244
# Epoch 14 Bitti (570.8 sn) | Train Acc: %98.46 | Loss: 0.0508
# Doğrulama (Validation) yapılıyor...
# VAL ACC: %98.08
# ------------------------------------------------------------
# Epoch [15] | Adım [50/3939] | Anlık Loss: 0.0115
# Epoch [15] | Adım [100/3939] | Anlık Loss: 0.0081
# Epoch [15] | Adım [150/3939] | Anlık Loss: 0.1112
# Epoch [15] | Adım [200/3939] | Anlık Loss: 0.2737
# Epoch [15] | Adım [250/3939] | Anlık Loss: 0.0699
# Epoch [15] | Adım [300/3939] | Anlık Loss: 0.0264
# Epoch [15] | Adım [350/3939] | Anlık Loss: 0.0825
# Epoch [15] | Adım [400/3939] | Anlık Loss: 0.0007
# Epoch [15] | Adım [450/3939] | Anlık Loss: 0.2937
# Epoch [15] | Adım [500/3939] | Anlık Loss: 0.0004
# Epoch [15] | Adım [550/3939] | Anlık Loss: 0.0005
# Epoch [15] | Adım [600/3939] | Anlık Loss: 0.0004
# Epoch [15] | Adım [650/3939] | Anlık Loss: 0.0986
# Epoch [15] | Adım [700/3939] | Anlık Loss: 0.1548
# Epoch [15] | Adım [750/3939] | Anlık Loss: 0.0012
# Epoch [15] | Adım [800/3939] | Anlık Loss: 0.0317
# Epoch [15] | Adım [850/3939] | Anlık Loss: 0.0534
# Epoch [15] | Adım [900/3939] | Anlık Loss: 0.0049
# Epoch [15] | Adım [950/3939] | Anlık Loss: 0.0211
# Epoch [15] | Adım [1000/3939] | Anlık Loss: 0.3619
# Epoch [15] | Adım [1050/3939] | Anlık Loss: 0.0615
# Epoch [15] | Adım [1100/3939] | Anlık Loss: 0.0095
# Epoch [15] | Adım [1150/3939] | Anlık Loss: 0.0003
# Epoch [15] | Adım [1200/3939] | Anlık Loss: 0.0048
# Epoch [15] | Adım [1250/3939] | Anlık Loss: 0.1033
# Epoch [15] | Adım [1300/3939] | Anlık Loss: 0.0002
# Epoch [15] | Adım [1350/3939] | Anlık Loss: 0.0007
# Epoch [15] | Adım [1400/3939] | Anlık Loss: 0.0001
# Epoch [15] | Adım [1450/3939] | Anlık Loss: 0.3026
# Epoch [15] | Adım [1500/3939] | Anlık Loss: 0.0002
# Epoch [15] | Adım [1550/3939] | Anlık Loss: 0.0053
# Epoch [15] | Adım [1600/3939] | Anlık Loss: 0.0078
# Epoch [15] | Adım [1650/3939] | Anlık Loss: 0.4099
# Epoch [15] | Adım [1700/3939] | Anlık Loss: 0.0429
# Epoch [15] | Adım [1750/3939] | Anlık Loss: 0.0015
# Epoch [15] | Adım [1800/3939] | Anlık Loss: 0.0002
# Epoch [15] | Adım [1850/3939] | Anlık Loss: 0.0305
# Epoch [15] | Adım [1900/3939] | Anlık Loss: 0.0002
# Epoch [15] | Adım [1950/3939] | Anlık Loss: 0.0422
# Epoch [15] | Adım [2000/3939] | Anlık Loss: 0.0002
# Epoch [15] | Adım [2050/3939] | Anlık Loss: 0.0042
# Epoch [15] | Adım [2100/3939] | Anlık Loss: 0.0851
# Epoch [15] | Adım [2150/3939] | Anlık Loss: 0.0003
# Epoch [15] | Adım [2200/3939] | Anlık Loss: 0.0492
# Epoch [15] | Adım [2250/3939] | Anlık Loss: 0.0031
# Epoch [15] | Adım [2300/3939] | Anlık Loss: 0.0037
# Epoch [15] | Adım [2350/3939] | Anlık Loss: 0.0397
# Epoch [15] | Adım [2400/3939] | Anlık Loss: 0.0119
# Epoch [15] | Adım [2450/3939] | Anlık Loss: 0.0087
# Epoch [15] | Adım [2500/3939] | Anlık Loss: 0.0003
# Epoch [15] | Adım [2550/3939] | Anlık Loss: 0.1510
# Epoch [15] | Adım [2600/3939] | Anlık Loss: 0.0013
# Epoch [15] | Adım [2650/3939] | Anlık Loss: 0.0010
# Epoch [15] | Adım [2700/3939] | Anlık Loss: 0.0441
# Epoch [15] | Adım [2750/3939] | Anlık Loss: 0.0673
# Epoch [15] | Adım [2800/3939] | Anlık Loss: 0.0201
# Epoch [15] | Adım [2850/3939] | Anlık Loss: 0.0002
# Epoch [15] | Adım [2900/3939] | Anlık Loss: 0.3056
# Epoch [15] | Adım [2950/3939] | Anlık Loss: 0.0003
# Epoch [15] | Adım [3000/3939] | Anlık Loss: 0.0014
# Epoch [15] | Adım [3050/3939] | Anlık Loss: 0.0197
# Epoch [15] | Adım [3100/3939] | Anlık Loss: 0.3702
# Epoch [15] | Adım [3150/3939] | Anlık Loss: 0.2581
# Epoch [15] | Adım [3200/3939] | Anlık Loss: 0.2624
# Epoch [15] | Adım [3250/3939] | Anlık Loss: 0.0017
# Epoch [15] | Adım [3300/3939] | Anlık Loss: 0.2810
# Epoch [15] | Adım [3350/3939] | Anlık Loss: 0.0167
# Epoch [15] | Adım [3400/3939] | Anlık Loss: 0.0029
# Epoch [15] | Adım [3450/3939] | Anlık Loss: 0.0009
# Epoch [15] | Adım [3500/3939] | Anlık Loss: 0.0009
# Epoch [15] | Adım [3550/3939] | Anlık Loss: 0.0022
# Epoch [15] | Adım [3600/3939] | Anlık Loss: 0.0008
# Epoch [15] | Adım [3650/3939] | Anlık Loss: 0.0281
# Epoch [15] | Adım [3700/3939] | Anlık Loss: 0.0000
# Epoch [15] | Adım [3750/3939] | Anlık Loss: 0.0020
# Epoch [15] | Adım [3800/3939] | Anlık Loss: 0.0635
# Epoch [15] | Adım [3850/3939] | Anlık Loss: 0.0003
# Epoch [15] | Adım [3900/3939] | Anlık Loss: 0.0294
# Epoch 15 Bitti (569.7 sn) | Train Acc: %98.48 | Loss: 0.0493
# Doğrulama (Validation) yapılıyor...
# VAL ACC: %98.16
# ------------------------------------------------------------
# Model Kaydedildi.

# %%
import os
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms
from PIL import Image
import random
from sklearn.metrics import f1_score, accuracy_score, classification_report
from torchvision.models import efficientnet_b0  # EfficientNet eklendi

# --- EKLENDI: DirectML Kütüphanesi ---
import torch_directml

CSV_DOSYASI = "C:/Users/samsu/Downloads/proje/archive/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/egitim_icin_hazir.csv"
ANA_KLASOR = r"C:/Users/samsu/Downloads/proje/archive/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train"
MODEL_PATH = "amd_model_final.pth" 
BATCH_SIZE = 16 
RESIM_BOYUTU = 128

# --- GÜNCELLENDİ: Cihaz DirectML (AMD GPU) olarak ayarlandı ---
device = torch_directml.device()
print(f"Test işlemi için Cihaz: {device} (AMD GPU Devrede)")

class TankVeriSeti(Dataset):
    def __init__(self, csv_file, root_dir, transform=None):
        self.veriler = pd.read_csv(csv_file)
        self.root_dir = root_dir
        self.transform = transform
        self.sinif_isimleri = sorted(self.veriler['class'].unique())
        self.sinif_sozlugu = {isim: i for i, isim in enumerate(self.sinif_isimleri)}

    def __len__(self): return len(self.veriler)

    def __getitem__(self, idx):
        try:
            dosya_adi = str(self.veriler.iloc[idx, 0])
            sinif_ismi = str(self.veriler.iloc[idx, 1])
            if "?" in dosya_adi: dosya_adi = dosya_adi.split('?')[0]
            
            yollar = [os.path.join(self.root_dir, sinif_ismi, dosya_adi),
                      os.path.join(self.root_dir, dosya_adi),
                      os.path.join(self.root_dir, sinif_ismi, dosya_adi[:-4] + ".jpg")]
            
            hedef_yol = None
            for yol in yollar:
                if os.path.exists(yol):
                    hedef_yol = yol
                    break
            
            if hedef_yol is None: raise FileNotFoundError()

            image = Image.open(hedef_yol).convert("RGB")
            label = self.sinif_sozlugu[sinif_ismi]
            if self.transform: image = self.transform(image)
            return image, label
        except:
            yeni_idx = random.randint(0, len(self.veriler) - 1)
            return self.__getitem__(yeni_idx)

if __name__ == '__main__':
    print("Test Verileri Hazırlanıyor...")
    
    transform = transforms.Compose([
        transforms.Resize((RESIM_BOYUTU, RESIM_BOYUTU)),
        transforms.ToTensor(),
        transforms.Normalize((0.5,), (0.5,))
    ])

    dataset = TankVeriSeti(csv_file=CSV_DOSYASI, root_dir=ANA_KLASOR, transform=transform)
    
    train_size = int(0.8 * len(dataset))
    val_size = len(dataset) - train_size
    _, val_dataset = random_split(dataset, [train_size, val_size])
    
    test_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
    
    print(f"Test Edilecek Görüntü Sayısı: {len(val_dataset)}")
    
    # --- MODEL MİMARİSİ: EfficientNet-B0 ---
    num_classes = len(dataset.sinif_isimleri)
    
    # Modeli boş ağırlıklarla oluşturuyoruz (Training'deki mimariyle aynı olmalı)
    model = efficientnet_b0(weights=None) 
    
    # Çıkış katmanını güncelle
    in_features = model.classifier[1].in_features
    model.classifier[1] = nn.Linear(in_features, num_classes)
    
    # --- Modeli Yükleme ve GPU'ya Atma ---
    if os.path.exists(MODEL_PATH):
        print(f"Model yükleniyor: {MODEL_PATH}")
        # Önce CPU'ya yükleyip sonra DirectML cihazına gönderiyoruz (En güvenli yöntem)
        state_dict = torch.load(MODEL_PATH, map_location=torch.device('cpu'))
        model.load_state_dict(state_dict)
        model.to(device) # Modeli AMD GPU'ya gönder
        model.eval() 
    else:
        print(f"HATA: '{MODEL_PATH}' bulunamadı! Dosya adını kontrol et.")
        exit()

    print("\nTEST BAŞLIYOR... (DirectML ile hızlandırıldı)")
    
    all_preds = []
    all_labels = []
    
    with torch.no_grad():
        for i, (images, labels) in enumerate(test_loader):
            # Verileri GPU'ya gönder
            images, labels = images.to(device), labels.to(device)
            
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            
            # --- ÖNEMLİ: Sonuçları CPU'ya geri çek (sklearn GPU tanımaz) ---
            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            
            if (i+1) % 50 == 0:
                print(f"   İşlenen paket: {i+1}...")

    acc = accuracy_score(all_labels, all_preds)
    f1_weighted = f1_score(all_labels, all_preds, average='weighted')
    f1_macro = f1_score(all_labels, all_preds, average='macro')
    
    print("\n" + "="*50)
    print("MODEL PERFORMANS RAPORU")
    print("="*50)
    print(f"Genel Doğruluk (Accuracy): %{acc*100:.2f}")
    print(f"Genel F1 Skoru (Weighted): {f1_weighted:.4f}")
    print(f"Genel F1 Skoru (Macro)   : {f1_macro:.4f}")
    print("-" * 50)
    
    print("\nHASTALIK BAZLI DETAYLI RAPOR:")
    print(classification_report(all_labels, all_preds, target_names=dataset.sinif_isimleri))
# Out:
# Test işlemi için Cihaz: privateuseone:0 (AMD GPU Devrede)
# Test Verileri Hazırlanıyor...
# Test Edilecek Görüntü Sayısı: 15753
# Model yükleniyor: amd_model_final.pth
#
# TEST BAŞLIYOR... (DirectML ile hızlandırıldı)
#    İşlenen paket: 50...
#    İşlenen paket: 100...
#    İşlenen paket: 150...
#    İşlenen paket: 200...
#    İşlenen paket: 250...
#    İşlenen paket: 300...
#    İşlenen paket: 350...
#    İşlenen paket: 400...
#    İşlenen paket: 450...
#    İşlenen paket: 500...
#    İşlenen paket: 550...
#    İşlenen paket: 600...
#    İşlenen paket: 650...
#    İşlenen paket: 700...
#    İşlenen paket: 750...
#    İşlenen paket: 800...
#    İşlenen paket: 850...
#    İşlenen paket: 900...
#    İşlenen paket: 950...
#
# ==================================================
# MODEL PERFORMANS RAPORU
# ==================================================
# Genel Doğruluk (Accuracy): %99.38
# Genel F1 Skoru (Weighted): 0.9938
# Genel F1 Skoru (Macro)   : 0.9905
# --------------------------------------------------
#
# HASTALIK BAZLI DETAYLI RAPOR:
#                                             precision    recall  f1-score   support
#
#                            Apple Scab Leaf       0.97      0.80      0.88        35
#                            Apple Scab leaf       1.00      1.00      1.00       431
#                                 Apple leaf       1.00      0.99      0.99       443
#                            Apple rust leaf       0.99      1.00      0.99       373
#                          Apple___Black_rot       1.00      1.00      1.00       394
#                           Bell_pepper leaf       0.99      0.99      0.99       481
#                      Bell_pepper leaf spot       1.00      0.99      1.00       432
#                             Blueberry leaf       1.00      1.00      1.00       510
#                                Cherry leaf       1.00      1.00      1.00       409
#   Cherry_(including_sour)___Powdery_mildew       1.00      1.00      1.00       328
#                        Corn Gray leaf spot       0.99      0.98      0.99       368
#                           Corn leaf blight       0.97      1.00      0.99       444
#                             Corn rust leaf       1.00      0.99      0.99       423
#                     Corn_(maize)___healthy       1.00      1.00      1.00       402
#                                 Grape leaf       1.00      1.00      1.00       355
#               Grape___Esca_(Black_Measles)       1.00      0.99      0.99       379
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot)       1.00      1.00      1.00       353
#   Orange___Haunglongbing_(Citrus_greening)       1.00      1.00      1.00       410
#                                 Peach leaf       1.00      1.00      1.00       494
#                     Peach___Bacterial_spot       1.00      1.00      1.00       370
#                                Potato leaf       0.99      0.99      0.99       340
#                   Potato leaf early blight       0.99      1.00      0.99       473
#                    Potato leaf late blight       0.99      1.00      0.99       424
#                              Rasberry leaf       1.00      1.00      1.00       353
#                             Raspberry leaf       0.98      0.98      0.98       123
#                              Soyabean leaf       1.00      1.00      1.00        43
#                               Soybean leaf       0.99      1.00      0.99       387
#                 Squash Powdery mildew leaf       1.00      1.00      1.00       387
#                            Strawberry leaf       1.00      1.00      1.00       452
#                   Strawberry___Leaf_scorch       1.00      1.00      1.00       352
#                   Tomato Early blight leaf       0.98      0.99      0.99       402
#                  Tomato Septoria leaf spot       0.96      0.93      0.95        86
#                  Tomato Septroia leaf spot       1.00      0.99      0.99       340
#                                Tomato leaf       0.99      0.99      0.99       471
#                 Tomato leaf bacterial spot       0.99      0.98      0.99       387
#                    Tomato leaf late blight       0.99      0.98      0.99       427
#                   Tomato leaf mosaic virus       1.00      1.00      1.00       379
#                   Tomato leaf yellow virus       1.00      0.99      1.00       545
#                           Tomato mold leaf       0.98      1.00      0.99       418
#       Tomato two spotted spider mites leaf       0.99      0.99      0.99       346
#                       Tomato___Target_Spot       0.99      0.99      0.99       365
#                                 grape leaf       1.00      1.00      1.00        34
#                       grape leaf black rot       0.99      1.00      0.99       385
#
#                                   accuracy                           0.99     15753
#                                  macro avg       0.99      0.99      0.99     15753
#                               weighted avg       0.99      0.99      0.99     15753

# %%
import matplotlib.pyplot as plt

USER_INFO = "Nevzat Eren TUĞ ( Efficientnet_B0 )"

epochs = list(range(1, 16))
val_losses = [0.4841,0.2361,0.1738,0.1365,0.1181,0.1017,0.0863,0.0806,0.0728,0.0673,0.0629, 0.0573, 0.0549, 0.0508, 0.0493]
accuracies =  [93.65, 95.99, 95.80, 97.10, 96.59, 97.17, 97.13, 97.26, 97.82, 98.30, 98.13, 97.66, 98.31, 98.08, 98.16]

plt.figure(figsize=(15, 6))

plt.subplot(1, 2, 1)
plt.plot(epochs, val_losses, 'r-o', label='Doğrulama Kaybı (Validation)')

plt.title(f'{USER_INFO}\nEğitim ve Doğrulama Kayıp Eğrileri', fontsize=14)

plt.xlabel('Epoch Sayısı')
plt.ylabel('Kayıp Değeri (Loss)')
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs, accuracies, 'g-s', linewidth=2, label='Doğrulama Başarısı (Accuracy)')

plt.title(f'{USER_INFO}\nModel Doğruluk Oranı', fontsize=14)

plt.xlabel('Epoch Sayısı')
plt.ylabel('Doğruluk (%)')
plt.yticks(range(90, 100, 1))
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

USER_INFO = "Nevzat Eren TUĞ"

epochs = list(range(1, 16))

# --- EFFICIENTNET B0 VERİLERİ ---
eff_losses = [0.4841, 0.2361, 0.1738, 0.1365, 0.1181, 0.1017, 0.0863, 0.0806, 0.0728, 0.0673, 0.0629, 0.0573, 0.0549, 0.0508, 0.0493]
eff_accs =   [93.65, 95.99, 95.80, 97.10, 96.59, 97.17, 97.13, 97.26, 97.82, 98.30, 98.13, 97.66, 98.31, 98.08, 98.16]

# --- SHUFFLENET V2 VERİLERİ ---
shuf_losses = [0.5239, 0.2310, 0.1753, 0.1428, 0.1166, 0.1050, 0.0926, 0.0836, 0.0780, 0.0685, 0.0674, 0.0587, 0.0599, 0.0531, 0.0486]
shuf_accs =   [93.63, 95.00, 96.12, 97.05, 96.92, 97.28, 96.93, 97.30, 97.14, 97.94, 97.71, 97.89, 98.01, 97.86, 98.08]

plt.figure(figsize=(16, 7))

# -----------------------------
# 1. GRAFİK: LOSS KARŞILAŞTIRMA
# -----------------------------
plt.subplot(1, 2, 1)

# EfficientNet: 'bo' -> Blue, Circle (Mavi Yuvarlak)
plt.plot(epochs, eff_losses, 'bo-', linewidth=2, label='EfficientNet B0 Loss')

# ShuffleNet: 'rs' -> Red, Square (Kırmızı Kare) + Kesik Çizgi
# Düzeltme: 'r-s' yerine 'rs' yazıldı, böylece linestyle ile çakışma kalktı.
plt.plot(epochs, shuf_losses, 'rs', linewidth=2, linestyle='--', label='ShuffleNet V2 Loss')

plt.title(f'{USER_INFO}\nModel Karşılaştırması: Kayıp (Loss)', fontsize=14)
plt.xlabel('Epoch Sayısı')
plt.ylabel('Kayıp Değeri (Loss)')
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()

# -----------------------------
# 2. GRAFİK: ACCURACY KARŞILAŞTIRMA
# -----------------------------
plt.subplot(1, 2, 2)

# EfficientNet
plt.plot(epochs, eff_accs, 'bo-', linewidth=2, label='EfficientNet B0 Acc')

# ShuffleNet
# Düzeltme: Burada da 'r-s' yerine 'rs' kullanıldı.
plt.plot(epochs, shuf_accs, 'rs', linewidth=2, linestyle='--', label='ShuffleNet V2 Acc')

plt.title(f'{USER_INFO}\nModel Karşılaştırması: Doğruluk (Accuracy)', fontsize=14)
plt.xlabel('Epoch Sayısı')
plt.ylabel('Doğruluk (%)')

plt.ylim(90, 100) 
plt.yticks(range(90, 101, 1))

plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()

plt.tight_layout()
plt.show()
