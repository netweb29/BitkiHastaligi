# %%
import pandas as pd
import matplotlib.pyplot as plt

VERI_DOSYASI = r'C:/Users/samsu/Downloads/proje/archive/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/egitim_icin_hazir.csv'

df = pd.read_csv(VERI_DOSYASI)

sinif_sayilari = df['class'].value_counts()

plt.figure(figsize=(15, 8))
plt.bar(sinif_sayilari.index, sinif_sayilari.values, color='teal')


plt.xticks(rotation=90) 
plt.title(f"Veri Seti Sınıf Dağılımı (Toplam {len(df)} Resim)", fontsize=16)
plt.xlabel("Hastalık Sınıfları", fontsize=12)
plt.ylabel("Görüntü Sayısı", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %%
import os
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
# DirectML kütüphanesini ekliyoruz
import torch_directml 
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms, models # models modülünü ekledik
from PIL import Image
import random
from sklearn.metrics import f1_score
import time

# Cihazı DirectML olarak ayarlıyoruz (AMD GPU hızlandırması için)
device = torch_directml.device()
print(f"Kullanılan Cihaz: {device}")

CSV_DOSYASI = "C:/Users/samsu/Downloads/proje/archive/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/egitim_icin_hazir.csv"
ANA_KLASOR = r"C:/Users/samsu/Downloads/proje/archive/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train"
BATCH_SIZE = 16 
LEARNING_RATE = 0.001
EPOCHS = 15
RESIM_BOYUTU = 128

class TankVeriSeti(Dataset):
    def __init__(self, csv_file, root_dir, transform=None):
        self.veriler = pd.read_csv(csv_file)
        self.root_dir = root_dir
        self.transform = transform
        self.sinif_isimleri = sorted(self.veriler['class'].unique())
        self.sinif_sozlugu = {isim: i for i, isim in enumerate(self.sinif_isimleri)}

    def __len__(self): return len(self.veriler)

    def __getitem__(self, idx):
        try:
            dosya_adi = str(self.veriler.iloc[idx, 0])
            sinif_ismi = str(self.veriler.iloc[idx, 1])
            if "?" in dosya_adi: dosya_adi = dosya_adi.split('?')[0]
            
            yollar = [os.path.join(self.root_dir, sinif_ismi, dosya_adi),
                      os.path.join(self.root_dir, dosya_adi),
                      os.path.join(self.root_dir, sinif_ismi, dosya_adi[:-4] + ".jpg")]
            
            hedef_yol = None
            for yol in yollar:
                if os.path.exists(yol):
                    hedef_yol = yol
                    break
            
            if hedef_yol is None: raise FileNotFoundError()

            image = Image.open(hedef_yol).convert("RGB")
            label = self.sinif_sozlugu[sinif_ismi]
            if self.transform: image = self.transform(image)
            return image, label
        except:
            yeni_idx = random.randint(0, len(self.veriler) - 1)
            return self.__getitem__(yeni_idx)

# SafCNN sınıfı kaldırıldı, yerine aşağıda hazır model kullanılacak.

if __name__ == '__main__':
    transform = transforms.Compose([
        transforms.Resize((RESIM_BOYUTU, RESIM_BOYUTU)),
        transforms.ToTensor(),
        transforms.Normalize((0.5,), (0.5,))
    ])

    print("Veriler Hazırlanıyor...")
    dataset = TankVeriSeti(csv_file=CSV_DOSYASI, root_dir=ANA_KLASOR, transform=transform)
    
    train_size = int(0.8 * len(dataset))
    val_size = len(dataset) - train_size
    train_dataset, val_dataset = random_split(dataset, [train_size, val_size])
    

    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0)
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=0)
    
    print(f"Train: {len(train_dataset)} | Val: {len(val_dataset)}")
    
    # --- MODEL GÜNCELLEMESİ: ShuffleNet V2 ---
    # Hazır ShuffleNet V2 modelini yüklüyoruz.
    # weights='DEFAULT' ile daha iyi sonuç için önceden eğitilmiş ağırlıkları kullanıyoruz.
    model = models.shufflenet_v2_x1_0(weights='DEFAULT')
    
    # Modelin son katmanını (classifier) kendi sınıf sayımıza göre değiştiriyoruz
    # ShuffleNet'in son katmanının adı 'fc'dir.
    num_ftrs = model.fc.in_features
    model.fc = nn.Linear(num_ftrs, len(dataset.sinif_isimleri))
    
    model = model.to(device)
    # ------------------------------------------

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)

    print("\nEĞİTİM BAŞLIYOR... (Her 50 adımda bir bilgi verecek)")
    print("-" * 60)

    for epoch in range(EPOCHS):
        model.train()
        train_loss = 0
        correct = 0
        total = 0
        

        start_time = time.time()
        
        for i, (images, labels) in enumerate(train_loader):
            # DirectML cihazına gönderiliyor
            images, labels = images.to(device), labels.to(device)
            
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            train_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            

            if (i+1) % 50 == 0:
                print(f"Epoch [{epoch+1}] | Adım [{i+1}/{len(train_loader)}] | Anlık Loss: {loss.item():.4f}")
        

        avg_train_loss = train_loss / len(train_loader)
        train_acc = 100 * correct / total
        elapsed_time = time.time() - start_time
        
        print(f"Epoch {epoch+1} Bitti ({elapsed_time:.1f} sn) | Train Acc: %{train_acc:.2f} | Loss: {avg_train_loss:.4f}")
        print("Doğrulama (Validation) yapılıyor...")
        
        model.eval()
        val_correct = 0
        val_total = 0
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                _, predicted = torch.max(outputs.data, 1)
                val_total += labels.size(0)
                val_correct += (predicted == labels).sum().item()
        
        val_acc = 100 * val_correct / val_total
        print(f"VAL ACC: %{val_acc:.2f}")
        print("-" * 60)

    torch.save(model.state_dict(), 'amd_model_finalv2.pth')
    print("Model Kaydedildi.")
# Out:
# Kullanılan Cihaz: privateuseone:0
# Veriler Hazırlanıyor...
# Train: 63011 | Val: 15753
# Downloading: "https://download.pytorch.org/models/shufflenetv2_x1-5666bf0f80.pth" to C:\Users\samsu/.cache\torch\hub\checkpoints\shufflenetv2_x1-5666bf0f80.pth
# 100.0%
# EĞİTİM BAŞLIYOR... (Her 50 adımda bir bilgi verecek)
# ------------------------------------------------------------
# Epoch [1] | Adım [50/3939] | Anlık Loss: 3.2204
# Epoch [1] | Adım [100/3939] | Anlık Loss: 2.2533
# Epoch [1] | Adım [150/3939] | Anlık Loss: 1.4102
# Epoch [1] | Adım [200/3939] | Anlık Loss: 1.1868
# Epoch [1] | Adım [250/3939] | Anlık Loss: 0.6865
# Epoch [1] | Adım [300/3939] | Anlık Loss: 0.5978
# Epoch [1] | Adım [350/3939] | Anlık Loss: 0.8408
# Epoch [1] | Adım [400/3939] | Anlık Loss: 0.5489
# Epoch [1] | Adım [450/3939] | Anlık Loss: 0.9496
# Epoch [1] | Adım [500/3939] | Anlık Loss: 0.9555
# Epoch [1] | Adım [550/3939] | Anlık Loss: 0.3387
# Epoch [1] | Adım [600/3939] | Anlık Loss: 0.6475
# Epoch [1] | Adım [650/3939] | Anlık Loss: 1.0125
# Epoch [1] | Adım [700/3939] | Anlık Loss: 0.3504
# Epoch [1] | Adım [750/3939] | Anlık Loss: 0.5215
# Epoch [1] | Adım [800/3939] | Anlık Loss: 0.4345
# Epoch [1] | Adım [850/3939] | Anlık Loss: 0.2294
# Epoch [1] | Adım [900/3939] | Anlık Loss: 0.2077
# Epoch [1] | Adım [950/3939] | Anlık Loss: 0.3959
# Epoch [1] | Adım [1000/3939] | Anlık Loss: 0.2475
# Epoch [1] | Adım [1050/3939] | Anlık Loss: 0.6198
# Epoch [1] | Adım [1100/3939] | Anlık Loss: 1.0643
# Epoch [1] | Adım [1150/3939] | Anlık Loss: 0.9961
# Epoch [1] | Adım [1200/3939] | Anlık Loss: 0.2157
# Epoch [1] | Adım [1250/3939] | Anlık Loss: 0.3392
# Epoch [1] | Adım [1300/3939] | Anlık Loss: 0.3050
# Epoch [1] | Adım [1350/3939] | Anlık Loss: 0.4308
# Epoch [1] | Adım [1400/3939] | Anlık Loss: 0.5025
# Epoch [1] | Adım [1450/3939] | Anlık Loss: 0.3721
# Epoch [1] | Adım [1500/3939] | Anlık Loss: 0.2980
# Epoch [1] | Adım [1550/3939] | Anlık Loss: 1.1215
# Epoch [1] | Adım [1600/3939] | Anlık Loss: 0.7227
# Epoch [1] | Adım [1650/3939] | Anlık Loss: 0.7523
# Epoch [1] | Adım [1700/3939] | Anlık Loss: 0.4646
# Epoch [1] | Adım [1750/3939] | Anlık Loss: 0.4197
# Epoch [1] | Adım [1800/3939] | Anlık Loss: 0.5707
# Epoch [1] | Adım [1850/3939] | Anlık Loss: 0.1553
# Epoch [1] | Adım [1900/3939] | Anlık Loss: 0.2326
# Epoch [1] | Adım [1950/3939] | Anlık Loss: 1.2027
# Epoch [1] | Adım [2000/3939] | Anlık Loss: 0.2645
# Epoch [1] | Adım [2050/3939] | Anlık Loss: 0.1685
# Epoch [1] | Adım [2100/3939] | Anlık Loss: 0.5724
# Epoch [1] | Adım [2150/3939] | Anlık Loss: 0.2049
# Epoch [1] | Adım [2200/3939] | Anlık Loss: 0.8355
# Epoch [1] | Adım [2250/3939] | Anlık Loss: 0.6482
# Epoch [1] | Adım [2300/3939] | Anlık Loss: 0.5905
# Epoch [1] | Adım [2350/3939] | Anlık Loss: 0.5179
# Epoch [1] | Adım [2400/3939] | Anlık Loss: 0.5286
# Epoch [1] | Adım [2450/3939] | Anlık Loss: 0.1836
# Epoch [1] | Adım [2500/3939] | Anlık Loss: 0.9829
# Epoch [1] | Adım [2550/3939] | Anlık Loss: 0.2239
# Epoch [1] | Adım [2600/3939] | Anlık Loss: 0.3139
# Epoch [1] | Adım [2650/3939] | Anlık Loss: 0.1611
# Epoch [1] | Adım [2700/3939] | Anlık Loss: 0.3039
# Epoch [1] | Adım [2750/3939] | Anlık Loss: 0.0994
# Epoch [1] | Adım [2800/3939] | Anlık Loss: 0.2115
# Epoch [1] | Adım [2850/3939] | Anlık Loss: 0.4164
# Epoch [1] | Adım [2900/3939] | Anlık Loss: 0.1226
# Epoch [1] | Adım [2950/3939] | Anlık Loss: 0.0362
# Epoch [1] | Adım [3000/3939] | Anlık Loss: 0.3893
# Epoch [1] | Adım [3050/3939] | Anlık Loss: 0.7706
# Epoch [1] | Adım [3100/3939] | Anlık Loss: 0.3316
# Epoch [1] | Adım [3150/3939] | Anlık Loss: 0.1026
# Epoch [1] | Adım [3200/3939] | Anlık Loss: 0.1045
# Epoch [1] | Adım [3250/3939] | Anlık Loss: 0.3536
# Epoch [1] | Adım [3300/3939] | Anlık Loss: 0.5748
# Epoch [1] | Adım [3350/3939] | Anlık Loss: 0.0592
# Epoch [1] | Adım [3400/3939] | Anlık Loss: 0.6005
# Epoch [1] | Adım [3450/3939] | Anlık Loss: 0.0574
# Epoch [1] | Adım [3500/3939] | Anlık Loss: 0.0869
# Epoch [1] | Adım [3550/3939] | Anlık Loss: 0.0851
# Epoch [1] | Adım [3600/3939] | Anlık Loss: 0.6603
# Epoch [1] | Adım [3650/3939] | Anlık Loss: 0.9053
# Epoch [1] | Adım [3700/3939] | Anlık Loss: 0.2448
# Epoch [1] | Adım [3750/3939] | Anlık Loss: 0.0424
# Epoch [1] | Adım [3800/3939] | Anlık Loss: 0.3532
# Epoch [1] | Adım [3850/3939] | Anlık Loss: 0.0937
# Epoch [1] | Adım [3900/3939] | Anlık Loss: 0.4425
# Epoch 1 Bitti (459.2 sn) | Train Acc: %85.00 | Loss: 0.5239
# Doğrulama (Validation) yapılıyor...
# VAL ACC: %93.63
# ------------------------------------------------------------
# Epoch [2] | Adım [50/3939] | Anlık Loss: 0.5955
# Epoch [2] | Adım [100/3939] | Anlık Loss: 0.2708
# Epoch [2] | Adım [150/3939] | Anlık Loss: 0.2183
# Epoch [2] | Adım [200/3939] | Anlık Loss: 0.2651
# Epoch [2] | Adım [250/3939] | Anlık Loss: 0.1560
# Epoch [2] | Adım [300/3939] | Anlık Loss: 0.1328
# Epoch [2] | Adım [350/3939] | Anlık Loss: 0.4073
# Epoch [2] | Adım [400/3939] | Anlık Loss: 0.2162
# Epoch [2] | Adım [450/3939] | Anlık Loss: 0.7591
# Epoch [2] | Adım [500/3939] | Anlık Loss: 0.2269
# Epoch [2] | Adım [550/3939] | Anlık Loss: 0.1967
# Epoch [2] | Adım [600/3939] | Anlık Loss: 0.0402
# Epoch [2] | Adım [650/3939] | Anlık Loss: 0.2398
# Epoch [2] | Adım [700/3939] | Anlık Loss: 0.3608
# Epoch [2] | Adım [750/3939] | Anlık Loss: 0.1000
# Epoch [2] | Adım [800/3939] | Anlık Loss: 0.0658
# Epoch [2] | Adım [850/3939] | Anlık Loss: 0.1097
# Epoch [2] | Adım [900/3939] | Anlık Loss: 0.2732
# Epoch [2] | Adım [950/3939] | Anlık Loss: 0.0541
# Epoch [2] | Adım [1000/3939] | Anlık Loss: 0.1019
# Epoch [2] | Adım [1050/3939] | Anlık Loss: 0.2500
# Epoch [2] | Adım [1100/3939] | Anlık Loss: 0.0805
# Epoch [2] | Adım [1150/3939] | Anlık Loss: 0.2111
# Epoch [2] | Adım [1200/3939] | Anlık Loss: 0.3241
# Epoch [2] | Adım [1250/3939] | Anlık Loss: 0.0456
# Epoch [2] | Adım [1300/3939] | Anlık Loss: 0.2149
# Epoch [2] | Adım [1350/3939] | Anlık Loss: 0.3610
# Epoch [2] | Adım [1400/3939] | Anlık Loss: 0.1427
# Epoch [2] | Adım [1450/3939] | Anlık Loss: 0.0422
# Epoch [2] | Adım [1500/3939] | Anlık Loss: 0.3257
# Epoch [2] | Adım [1550/3939] | Anlık Loss: 0.1238
# Epoch [2] | Adım [1600/3939] | Anlık Loss: 0.1028
# Epoch [2] | Adım [1650/3939] | Anlık Loss: 0.4750
# Epoch [2] | Adım [1700/3939] | Anlık Loss: 0.1567
# Epoch [2] | Adım [1750/3939] | Anlık Loss: 0.0314
# Epoch [2] | Adım [1800/3939] | Anlık Loss: 0.1059
# Epoch [2] | Adım [1850/3939] | Anlık Loss: 0.0238
# Epoch [2] | Adım [1900/3939] | Anlık Loss: 0.4234
# Epoch [2] | Adım [1950/3939] | Anlık Loss: 0.2670
# Epoch [2] | Adım [2000/3939] | Anlık Loss: 0.0365
# Epoch [2] | Adım [2050/3939] | Anlık Loss: 0.0940
# Epoch [2] | Adım [2100/3939] | Anlık Loss: 0.0055
# Epoch [2] | Adım [2150/3939] | Anlık Loss: 0.3477
# Epoch [2] | Adım [2200/3939] | Anlık Loss: 0.1182
# Epoch [2] | Adım [2250/3939] | Anlık Loss: 0.3948
# Epoch [2] | Adım [2300/3939] | Anlık Loss: 0.6107
# Epoch [2] | Adım [2350/3939] | Anlık Loss: 0.2954
# Epoch [2] | Adım [2400/3939] | Anlık Loss: 0.4966
# Epoch [2] | Adım [2450/3939] | Anlık Loss: 0.3368
# Epoch [2] | Adım [2500/3939] | Anlık Loss: 0.3242
# Epoch [2] | Adım [2550/3939] | Anlık Loss: 0.6779
# Epoch [2] | Adım [2600/3939] | Anlık Loss: 0.1358
# Epoch [2] | Adım [2650/3939] | Anlık Loss: 0.0260
# Epoch [2] | Adım [2700/3939] | Anlık Loss: 0.2608
# Epoch [2] | Adım [2750/3939] | Anlık Loss: 0.5381
# Epoch [2] | Adım [2800/3939] | Anlık Loss: 0.2761
# Epoch [2] | Adım [2850/3939] | Anlık Loss: 0.0817
# Epoch [2] | Adım [2900/3939] | Anlık Loss: 0.2214
# Epoch [2] | Adım [2950/3939] | Anlık Loss: 0.0372
# Epoch [2] | Adım [3000/3939] | Anlık Loss: 0.4957
# Epoch [2] | Adım [3050/3939] | Anlık Loss: 0.0939
# Epoch [2] | Adım [3100/3939] | Anlık Loss: 0.1522
# Epoch [2] | Adım [3150/3939] | Anlık Loss: 0.0696
# Epoch [2] | Adım [3200/3939] | Anlık Loss: 0.0327
# Epoch [2] | Adım [3250/3939] | Anlık Loss: 0.6799
# Epoch [2] | Adım [3300/3939] | Anlık Loss: 0.1537
# Epoch [2] | Adım [3350/3939] | Anlık Loss: 0.0177
# Epoch [2] | Adım [3400/3939] | Anlık Loss: 0.1438
# Epoch [2] | Adım [3450/3939] | Anlık Loss: 0.6179
# Epoch [2] | Adım [3500/3939] | Anlık Loss: 0.0451
# Epoch [2] | Adım [3550/3939] | Anlık Loss: 0.1949
# Epoch [2] | Adım [3600/3939] | Anlık Loss: 0.5493
# Epoch [2] | Adım [3650/3939] | Anlık Loss: 0.1395
# Epoch [2] | Adım [3700/3939] | Anlık Loss: 0.3408
# Epoch [2] | Adım [3750/3939] | Anlık Loss: 0.6200
# Epoch [2] | Adım [3800/3939] | Anlık Loss: 0.1686
# Epoch [2] | Adım [3850/3939] | Anlık Loss: 0.0220
# Epoch [2] | Adım [3900/3939] | Anlık Loss: 0.0386
# Epoch 2 Bitti (470.7 sn) | Train Acc: %92.81 | Loss: 0.2310
# Doğrulama (Validation) yapılıyor...
# VAL ACC: %95.00
# ------------------------------------------------------------
# Epoch [3] | Adım [50/3939] | Anlık Loss: 0.3691
# Epoch [3] | Adım [100/3939] | Anlık Loss: 0.1628
# Epoch [3] | Adım [150/3939] | Anlık Loss: 0.0989
# Epoch [3] | Adım [200/3939] | Anlık Loss: 0.2228
# Epoch [3] | Adım [250/3939] | Anlık Loss: 0.0118
# Epoch [3] | Adım [300/3939] | Anlık Loss: 0.0694
# Epoch [3] | Adım [350/3939] | Anlık Loss: 0.0703
# Epoch [3] | Adım [400/3939] | Anlık Loss: 0.0315
# Epoch [3] | Adım [450/3939] | Anlık Loss: 0.1631
# Epoch [3] | Adım [500/3939] | Anlık Loss: 0.4533
# Epoch [3] | Adım [550/3939] | Anlık Loss: 0.4467
# Epoch [3] | Adım [600/3939] | Anlık Loss: 0.1981
# Epoch [3] | Adım [650/3939] | Anlık Loss: 0.3455
# Epoch [3] | Adım [700/3939] | Anlık Loss: 0.2622
# Epoch [3] | Adım [750/3939] | Anlık Loss: 0.0101
# Epoch [3] | Adım [800/3939] | Anlık Loss: 0.1026
# Epoch [3] | Adım [850/3939] | Anlık Loss: 0.3655
# Epoch [3] | Adım [900/3939] | Anlık Loss: 0.0892
# Epoch [3] | Adım [950/3939] | Anlık Loss: 0.0172
# Epoch [3] | Adım [1000/3939] | Anlık Loss: 0.0439
# Epoch [3] | Adım [1050/3939] | Anlık Loss: 0.0620
# Epoch [3] | Adım [1100/3939] | Anlık Loss: 0.0653
# Epoch [3] | Adım [1150/3939] | Anlık Loss: 0.1676
# Epoch [3] | Adım [1200/3939] | Anlık Loss: 0.1878
# Epoch [3] | Adım [1250/3939] | Anlık Loss: 0.4637
# Epoch [3] | Adım [1300/3939] | Anlık Loss: 0.1388
# Epoch [3] | Adım [1350/3939] | Anlık Loss: 0.0049
# Epoch [3] | Adım [1400/3939] | Anlık Loss: 0.1021
# Epoch [3] | Adım [1450/3939] | Anlık Loss: 0.0415
# Epoch [3] | Adım [1500/3939] | Anlık Loss: 0.0396
# Epoch [3] | Adım [1550/3939] | Anlık Loss: 0.0550
# Epoch [3] | Adım [1600/3939] | Anlık Loss: 0.2071
# Epoch [3] | Adım [1650/3939] | Anlık Loss: 0.1849
# Epoch [3] | Adım [1700/3939] | Anlık Loss: 0.5874
# Epoch [3] | Adım [1750/3939] | Anlık Loss: 0.0153
# Epoch [3] | Adım [1800/3939] | Anlık Loss: 0.1926
# Epoch [3] | Adım [1850/3939] | Anlık Loss: 0.2032
# Epoch [3] | Adım [1900/3939] | Anlık Loss: 0.1584
# Epoch [3] | Adım [1950/3939] | Anlık Loss: 0.1181
# Epoch [3] | Adım [2000/3939] | Anlık Loss: 0.0091
# Epoch [3] | Adım [2050/3939] | Anlık Loss: 0.9628
# Epoch [3] | Adım [2100/3939] | Anlık Loss: 0.3172
# Epoch [3] | Adım [2150/3939] | Anlık Loss: 0.5656
# Epoch [3] | Adım [2200/3939] | Anlık Loss: 0.1982
# Epoch [3] | Adım [2250/3939] | Anlık Loss: 0.2404
# Epoch [3] | Adım [2300/3939] | Anlık Loss: 0.0135
# Epoch [3] | Adım [2350/3939] | Anlık Loss: 0.3531
# Epoch [3] | Adım [2400/3939] | Anlık Loss: 0.0304
# Epoch [3] | Adım [2450/3939] | Anlık Loss: 0.1973
# Epoch [3] | Adım [2500/3939] | Anlık Loss: 0.3432
# Epoch [3] | Adım [2550/3939] | Anlık Loss: 0.3560
# Epoch [3] | Adım [2600/3939] | Anlık Loss: 0.0906
# Epoch [3] | Adım [2650/3939] | Anlık Loss: 0.0668
# Epoch [3] | Adım [2700/3939] | Anlık Loss: 0.0251
# Epoch [3] | Adım [2750/3939] | Anlık Loss: 0.2394
# Epoch [3] | Adım [2800/3939] | Anlık Loss: 0.3503
# Epoch [3] | Adım [2850/3939] | Anlık Loss: 0.0489
# Epoch [3] | Adım [2900/3939] | Anlık Loss: 0.2909
# Epoch [3] | Adım [2950/3939] | Anlık Loss: 0.0117
# Epoch [3] | Adım [3000/3939] | Anlık Loss: 0.0268
# Epoch [3] | Adım [3050/3939] | Anlık Loss: 0.0753
# Epoch [3] | Adım [3100/3939] | Anlık Loss: 0.1377
# Epoch [3] | Adım [3150/3939] | Anlık Loss: 0.0525
# Epoch [3] | Adım [3200/3939] | Anlık Loss: 0.0271
# Epoch [3] | Adım [3250/3939] | Anlık Loss: 0.1365
# Epoch [3] | Adım [3300/3939] | Anlık Loss: 0.0750
# Epoch [3] | Adım [3350/3939] | Anlık Loss: 0.1871
# Epoch [3] | Adım [3400/3939] | Anlık Loss: 0.0676
# Epoch [3] | Adım [3450/3939] | Anlık Loss: 0.0757
# Epoch [3] | Adım [3500/3939] | Anlık Loss: 0.0307
# Epoch [3] | Adım [3550/3939] | Anlık Loss: 0.3210
# Epoch [3] | Adım [3600/3939] | Anlık Loss: 0.0530
# Epoch [3] | Adım [3650/3939] | Anlık Loss: 0.0250
# Epoch [3] | Adım [3700/3939] | Anlık Loss: 0.8267
# Epoch [3] | Adım [3750/3939] | Anlık Loss: 0.3294
# Epoch [3] | Adım [3800/3939] | Anlık Loss: 0.0437
# Epoch [3] | Adım [3850/3939] | Anlık Loss: 0.4329
# Epoch [3] | Adım [3900/3939] | Anlık Loss: 0.0189
# Epoch 3 Bitti (469.7 sn) | Train Acc: %94.47 | Loss: 0.1753
# Doğrulama (Validation) yapılıyor...
# VAL ACC: %96.12
# ------------------------------------------------------------
# Epoch [4] | Adım [50/3939] | Anlık Loss: 0.0060
# Epoch [4] | Adım [100/3939] | Anlık Loss: 0.2019
# Epoch [4] | Adım [150/3939] | Anlık Loss: 0.0353
# Epoch [4] | Adım [200/3939] | Anlık Loss: 0.0236
# Epoch [4] | Adım [250/3939] | Anlık Loss: 0.0071
# Epoch [4] | Adım [300/3939] | Anlık Loss: 0.2115
# Epoch [4] | Adım [350/3939] | Anlık Loss: 0.0342
# Epoch [4] | Adım [400/3939] | Anlık Loss: 0.0129
# Epoch [4] | Adım [450/3939] | Anlık Loss: 0.5839
# Epoch [4] | Adım [500/3939] | Anlık Loss: 0.0040
# Epoch [4] | Adım [550/3939] | Anlık Loss: 0.2853
# Epoch [4] | Adım [600/3939] | Anlık Loss: 0.0693
# Epoch [4] | Adım [650/3939] | Anlık Loss: 0.4553
# Epoch [4] | Adım [700/3939] | Anlık Loss: 0.1401
# Epoch [4] | Adım [750/3939] | Anlık Loss: 0.0497
# Epoch [4] | Adım [800/3939] | Anlık Loss: 0.0561
# Epoch [4] | Adım [850/3939] | Anlık Loss: 0.0196
# Epoch [4] | Adım [900/3939] | Anlık Loss: 0.0578
# Epoch [4] | Adım [950/3939] | Anlık Loss: 0.0209
# Epoch [4] | Adım [1000/3939] | Anlık Loss: 0.2494
# Epoch [4] | Adım [1050/3939] | Anlık Loss: 0.0360
# Epoch [4] | Adım [1100/3939] | Anlık Loss: 0.0479
# Epoch [4] | Adım [1150/3939] | Anlık Loss: 0.3327
# Epoch [4] | Adım [1200/3939] | Anlık Loss: 0.2020
# Epoch [4] | Adım [1250/3939] | Anlık Loss: 0.2497
# Epoch [4] | Adım [1300/3939] | Anlık Loss: 0.0762
# Epoch [4] | Adım [1350/3939] | Anlık Loss: 0.0229
# Epoch [4] | Adım [1400/3939] | Anlık Loss: 0.0654
# Epoch [4] | Adım [1450/3939] | Anlık Loss: 0.1550
# Epoch [4] | Adım [1500/3939] | Anlık Loss: 0.0521
# Epoch [4] | Adım [1550/3939] | Anlık Loss: 0.2322
# Epoch [4] | Adım [1600/3939] | Anlık Loss: 0.0207
# Epoch [4] | Adım [1650/3939] | Anlık Loss: 0.2185
# Epoch [4] | Adım [1700/3939] | Anlık Loss: 0.3983
# Epoch [4] | Adım [1750/3939] | Anlık Loss: 0.5609
# Epoch [4] | Adım [1800/3939] | Anlık Loss: 0.0999
# Epoch [4] | Adım [1850/3939] | Anlık Loss: 0.2660
# Epoch [4] | Adım [1900/3939] | Anlık Loss: 0.4250
# Epoch [4] | Adım [1950/3939] | Anlık Loss: 0.4417
# Epoch [4] | Adım [2000/3939] | Anlık Loss: 0.0579
# Epoch [4] | Adım [2050/3939] | Anlık Loss: 0.0253
# Epoch [4] | Adım [2100/3939] | Anlık Loss: 0.1382
# Epoch [4] | Adım [2150/3939] | Anlık Loss: 0.1735
# Epoch [4] | Adım [2200/3939] | Anlık Loss: 0.0019
# Epoch [4] | Adım [2250/3939] | Anlık Loss: 0.2894
# Epoch [4] | Adım [2300/3939] | Anlık Loss: 0.2440
# Epoch [4] | Adım [2350/3939] | Anlık Loss: 0.1475
# Epoch [4] | Adım [2400/3939] | Anlık Loss: 0.1170
# Epoch [4] | Adım [2450/3939] | Anlık Loss: 0.1634
# Epoch [4] | Adım [2500/3939] | Anlık Loss: 0.3232
# Epoch [4] | Adım [2550/3939] | Anlık Loss: 0.0704
# Epoch [4] | Adım [2600/3939] | Anlık Loss: 0.0250
# Epoch [4] | Adım [2650/3939] | Anlık Loss: 0.2324
# Epoch [4] | Adım [2700/3939] | Anlık Loss: 0.0443
# Epoch [4] | Adım [2750/3939] | Anlık Loss: 0.4755
# Epoch [4] | Adım [2800/3939] | Anlık Loss: 0.0508
# Epoch [4] | Adım [2850/3939] | Anlık Loss: 0.2278
# Epoch [4] | Adım [2900/3939] | Anlık Loss: 0.0118
# Epoch [4] | Adım [2950/3939] | Anlık Loss: 0.0512
# Epoch [4] | Adım [3000/3939] | Anlık Loss: 0.3261
# Epoch [4] | Adım [3050/3939] | Anlık Loss: 0.1428
# Epoch [4] | Adım [3100/3939] | Anlık Loss: 0.2977
# Epoch [4] | Adım [3150/3939] | Anlık Loss: 0.4033
# Epoch [4] | Adım [3200/3939] | Anlık Loss: 0.1497
# Epoch [4] | Adım [3250/3939] | Anlık Loss: 0.2284
# Epoch [4] | Adım [3300/3939] | Anlık Loss: 0.2187
# Epoch [4] | Adım [3350/3939] | Anlık Loss: 0.0587
# Epoch [4] | Adım [3400/3939] | Anlık Loss: 0.0333
# Epoch [4] | Adım [3450/3939] | Anlık Loss: 0.0159
# Epoch [4] | Adım [3500/3939] | Anlık Loss: 0.0377
# Epoch [4] | Adım [3550/3939] | Anlık Loss: 0.1402
# Epoch [4] | Adım [3600/3939] | Anlık Loss: 0.0237
# Epoch [4] | Adım [3650/3939] | Anlık Loss: 0.0896
# Epoch [4] | Adım [3700/3939] | Anlık Loss: 0.1328
# Epoch [4] | Adım [3750/3939] | Anlık Loss: 0.3249
# Epoch [4] | Adım [3800/3939] | Anlık Loss: 0.0078
# Epoch [4] | Adım [3850/3939] | Anlık Loss: 0.2441
# Epoch [4] | Adım [3900/3939] | Anlık Loss: 0.0715
# Epoch 4 Bitti (461.7 sn) | Train Acc: %95.44 | Loss: 0.1428
# Doğrulama (Validation) yapılıyor...
# VAL ACC: %97.05
# ------------------------------------------------------------
# Epoch [5] | Adım [50/3939] | Anlık Loss: 0.0370
# Epoch [5] | Adım [100/3939] | Anlık Loss: 0.1638
# Epoch [5] | Adım [150/3939] | Anlık Loss: 0.2925
# Epoch [5] | Adım [200/3939] | Anlık Loss: 0.0828
# Epoch [5] | Adım [250/3939] | Anlık Loss: 0.0147
# Epoch [5] | Adım [300/3939] | Anlık Loss: 0.0432
# Epoch [5] | Adım [350/3939] | Anlık Loss: 0.1325
# Epoch [5] | Adım [400/3939] | Anlık Loss: 0.0424
# Epoch [5] | Adım [450/3939] | Anlık Loss: 0.0931
# Epoch [5] | Adım [500/3939] | Anlık Loss: 0.0614
# Epoch [5] | Adım [550/3939] | Anlık Loss: 0.1162
# Epoch [5] | Adım [600/3939] | Anlık Loss: 0.2455
# Epoch [5] | Adım [650/3939] | Anlık Loss: 0.0399
# Epoch [5] | Adım [700/3939] | Anlık Loss: 0.0050
# Epoch [5] | Adım [750/3939] | Anlık Loss: 0.0252
# Epoch [5] | Adım [800/3939] | Anlık Loss: 0.2037
# Epoch [5] | Adım [850/3939] | Anlık Loss: 0.1307
# Epoch [5] | Adım [900/3939] | Anlık Loss: 0.1142
# Epoch [5] | Adım [950/3939] | Anlık Loss: 0.1546
# Epoch [5] | Adım [1000/3939] | Anlık Loss: 0.0601
# Epoch [5] | Adım [1050/3939] | Anlık Loss: 0.0767
# Epoch [5] | Adım [1100/3939] | Anlık Loss: 0.0652
# Epoch [5] | Adım [1150/3939] | Anlık Loss: 0.0839
# Epoch [5] | Adım [1200/3939] | Anlık Loss: 0.0177
# Epoch [5] | Adım [1250/3939] | Anlık Loss: 0.0050
# Epoch [5] | Adım [1300/3939] | Anlık Loss: 0.0164
# Epoch [5] | Adım [1350/3939] | Anlık Loss: 0.0815
# Epoch [5] | Adım [1400/3939] | Anlık Loss: 0.1472
# Epoch [5] | Adım [1450/3939] | Anlık Loss: 0.2028
# Epoch [5] | Adım [1500/3939] | Anlık Loss: 0.0468
# Epoch [5] | Adım [1550/3939] | Anlık Loss: 0.0420
# Epoch [5] | Adım [1600/3939] | Anlık Loss: 0.4047
# Epoch [5] | Adım [1650/3939] | Anlık Loss: 0.1091
# Epoch [5] | Adım [1700/3939] | Anlık Loss: 0.1302
# Epoch [5] | Adım [1750/3939] | Anlık Loss: 0.1528
# Epoch [5] | Adım [1800/3939] | Anlık Loss: 0.3493
# Epoch [5] | Adım [1850/3939] | Anlık Loss: 0.0642
# Epoch [5] | Adım [1900/3939] | Anlık Loss: 0.5417
# Epoch [5] | Adım [1950/3939] | Anlık Loss: 0.0114
# Epoch [5] | Adım [2000/3939] | Anlık Loss: 0.1242
# Epoch [5] | Adım [2050/3939] | Anlık Loss: 0.0260
# Epoch [5] | Adım [2100/3939] | Anlık Loss: 0.0435
# Epoch [5] | Adım [2150/3939] | Anlık Loss: 0.9217
# Epoch [5] | Adım [2200/3939] | Anlık Loss: 0.0481
# Epoch [5] | Adım [2250/3939] | Anlık Loss: 0.1129
# Epoch [5] | Adım [2300/3939] | Anlık Loss: 0.0111
# Epoch [5] | Adım [2350/3939] | Anlık Loss: 0.3595
# Epoch [5] | Adım [2400/3939] | Anlık Loss: 0.1330
# Epoch [5] | Adım [2450/3939] | Anlık Loss: 0.0176
# Epoch [5] | Adım [2500/3939] | Anlık Loss: 0.0758
# Epoch [5] | Adım [2550/3939] | Anlık Loss: 0.0388
# Epoch [5] | Adım [2600/3939] | Anlık Loss: 0.0141
# Epoch [5] | Adım [2650/3939] | Anlık Loss: 0.0944
# Epoch [5] | Adım [2700/3939] | Anlık Loss: 0.0364
# Epoch [5] | Adım [2750/3939] | Anlık Loss: 0.0036
# Epoch [5] | Adım [2800/3939] | Anlık Loss: 0.0313
# Epoch [5] | Adım [2850/3939] | Anlık Loss: 0.1058
# Epoch [5] | Adım [2900/3939] | Anlık Loss: 0.0071
# Epoch [5] | Adım [2950/3939] | Anlık Loss: 0.0034
# Epoch [5] | Adım [3000/3939] | Anlık Loss: 0.0274
# Epoch [5] | Adım [3050/3939] | Anlık Loss: 0.0730
# Epoch [5] | Adım [3100/3939] | Anlık Loss: 0.2575
# Epoch [5] | Adım [3150/3939] | Anlık Loss: 0.1356
# Epoch [5] | Adım [3200/3939] | Anlık Loss: 0.3439
# Epoch [5] | Adım [3250/3939] | Anlık Loss: 0.0186
# Epoch [5] | Adım [3300/3939] | Anlık Loss: 0.0163
# Epoch [5] | Adım [3350/3939] | Anlık Loss: 0.3727
# Epoch [5] | Adım [3400/3939] | Anlık Loss: 0.4334
# Epoch [5] | Adım [3450/3939] | Anlık Loss: 0.0131
# Epoch [5] | Adım [3500/3939] | Anlık Loss: 0.1943
# Epoch [5] | Adım [3550/3939] | Anlık Loss: 0.0197
# Epoch [5] | Adım [3600/3939] | Anlık Loss: 0.0524
# Epoch [5] | Adım [3650/3939] | Anlık Loss: 0.0594
# Epoch [5] | Adım [3700/3939] | Anlık Loss: 0.0400
# Epoch [5] | Adım [3750/3939] | Anlık Loss: 0.0210
# Epoch [5] | Adım [3800/3939] | Anlık Loss: 0.0982
# Epoch [5] | Adım [3850/3939] | Anlık Loss: 0.2548
# Epoch [5] | Adım [3900/3939] | Anlık Loss: 0.1430
# Epoch 5 Bitti (456.8 sn) | Train Acc: %96.24 | Loss: 0.1166
# Doğrulama (Validation) yapılıyor...
# VAL ACC: %96.92
# ------------------------------------------------------------
# Epoch [6] | Adım [50/3939] | Anlık Loss: 0.0295
# Epoch [6] | Adım [100/3939] | Anlık Loss: 0.1020
# Epoch [6] | Adım [150/3939] | Anlık Loss: 0.0069
# Epoch [6] | Adım [200/3939] | Anlık Loss: 0.0441
# Epoch [6] | Adım [250/3939] | Anlık Loss: 0.0708
# Epoch [6] | Adım [300/3939] | Anlık Loss: 0.0491
# Epoch [6] | Adım [350/3939] | Anlık Loss: 0.0074
# Epoch [6] | Adım [400/3939] | Anlık Loss: 0.0398
# Epoch [6] | Adım [450/3939] | Anlık Loss: 0.3011
# Epoch [6] | Adım [500/3939] | Anlık Loss: 0.0024
# Epoch [6] | Adım [550/3939] | Anlık Loss: 0.0007
# Epoch [6] | Adım [600/3939] | Anlık Loss: 0.0226
# Epoch [6] | Adım [650/3939] | Anlık Loss: 0.0931
# Epoch [6] | Adım [700/3939] | Anlık Loss: 0.3689
# Epoch [6] | Adım [750/3939] | Anlık Loss: 0.0097
# Epoch [6] | Adım [800/3939] | Anlık Loss: 0.2029
# Epoch [6] | Adım [850/3939] | Anlık Loss: 0.1725
# Epoch [6] | Adım [900/3939] | Anlık Loss: 0.0177
# Epoch [6] | Adım [950/3939] | Anlık Loss: 0.0061
# Epoch [6] | Adım [1000/3939] | Anlık Loss: 0.0733
# Epoch [6] | Adım [1050/3939] | Anlık Loss: 0.1372
# Epoch [6] | Adım [1100/3939] | Anlık Loss: 0.0336
# Epoch [6] | Adım [1150/3939] | Anlık Loss: 0.0885
# Epoch [6] | Adım [1200/3939] | Anlık Loss: 0.0124
# Epoch [6] | Adım [1250/3939] | Anlık Loss: 0.7246
# Epoch [6] | Adım [1300/3939] | Anlık Loss: 0.2259
# Epoch [6] | Adım [1350/3939] | Anlık Loss: 0.0036
# Epoch [6] | Adım [1400/3939] | Anlık Loss: 0.1643
# Epoch [6] | Adım [1450/3939] | Anlık Loss: 0.0033
# Epoch [6] | Adım [1500/3939] | Anlık Loss: 0.0102
# Epoch [6] | Adım [1550/3939] | Anlık Loss: 0.1391
# Epoch [6] | Adım [1600/3939] | Anlık Loss: 0.0207
# Epoch [6] | Adım [1650/3939] | Anlık Loss: 0.0665
# Epoch [6] | Adım [1700/3939] | Anlık Loss: 0.0280
# Epoch [6] | Adım [1750/3939] | Anlık Loss: 0.0182
# Epoch [6] | Adım [1800/3939] | Anlık Loss: 0.0102
# Epoch [6] | Adım [1850/3939] | Anlık Loss: 0.3276
# Epoch [6] | Adım [1900/3939] | Anlık Loss: 0.0406
# Epoch [6] | Adım [1950/3939] | Anlık Loss: 0.0356
# Epoch [6] | Adım [2000/3939] | Anlık Loss: 0.0156
# Epoch [6] | Adım [2050/3939] | Anlık Loss: 0.0497
# Epoch [6] | Adım [2100/3939] | Anlık Loss: 0.1579
# Epoch [6] | Adım [2150/3939] | Anlık Loss: 0.3299
# Epoch [6] | Adım [2200/3939] | Anlık Loss: 0.0457
# Epoch [6] | Adım [2250/3939] | Anlık Loss: 0.0473
# Epoch [6] | Adım [2300/3939] | Anlık Loss: 0.0565
# Epoch [6] | Adım [2350/3939] | Anlık Loss: 0.0423
# Epoch [6] | Adım [2400/3939] | Anlık Loss: 0.2038
# Epoch [6] | Adım [2450/3939] | Anlık Loss: 0.0430
# Epoch [6] | Adım [2500/3939] | Anlık Loss: 0.0797
# Epoch [6] | Adım [2550/3939] | Anlık Loss: 0.2434
# Epoch [6] | Adım [2600/3939] | Anlık Loss: 0.0644
# Epoch [6] | Adım [2650/3939] | Anlık Loss: 0.5909
# Epoch [6] | Adım [2700/3939] | Anlık Loss: 0.1076
# Epoch [6] | Adım [2750/3939] | Anlık Loss: 0.1119
# Epoch [6] | Adım [2800/3939] | Anlık Loss: 0.0243
# Epoch [6] | Adım [2850/3939] | Anlık Loss: 0.0063
# Epoch [6] | Adım [2900/3939] | Anlık Loss: 0.0241
# Epoch [6] | Adım [2950/3939] | Anlık Loss: 0.0192
# Epoch [6] | Adım [3000/3939] | Anlık Loss: 0.1515
# Epoch [6] | Adım [3050/3939] | Anlık Loss: 0.0710
# Epoch [6] | Adım [3100/3939] | Anlık Loss: 0.0723
# Epoch [6] | Adım [3150/3939] | Anlık Loss: 0.0288
# Epoch [6] | Adım [3200/3939] | Anlık Loss: 0.1494
# Epoch [6] | Adım [3250/3939] | Anlık Loss: 0.4000
# Epoch [6] | Adım [3300/3939] | Anlık Loss: 0.4183
# Epoch [6] | Adım [3350/3939] | Anlık Loss: 0.0498
# Epoch [6] | Adım [3400/3939] | Anlık Loss: 0.0725
# Epoch [6] | Adım [3450/3939] | Anlık Loss: 0.0126
# Epoch [6] | Adım [3500/3939] | Anlık Loss: 0.0793
# Epoch [6] | Adım [3550/3939] | Anlık Loss: 0.0195
# Epoch [6] | Adım [3600/3939] | Anlık Loss: 0.2392
# Epoch [6] | Adım [3650/3939] | Anlık Loss: 0.0082
# Epoch [6] | Adım [3700/3939] | Anlık Loss: 0.0133
# Epoch [6] | Adım [3750/3939] | Anlık Loss: 0.4105
# Epoch [6] | Adım [3800/3939] | Anlık Loss: 0.0325
# Epoch [6] | Adım [3850/3939] | Anlık Loss: 0.2109
# Epoch [6] | Adım [3900/3939] | Anlık Loss: 0.1641
# Epoch 6 Bitti (456.0 sn) | Train Acc: %96.59 | Loss: 0.1050
# Doğrulama (Validation) yapılıyor...
# VAL ACC: %97.28
# ------------------------------------------------------------
# Epoch [7] | Adım [50/3939] | Anlık Loss: 0.0275
# Epoch [7] | Adım [100/3939] | Anlık Loss: 0.2373
# Epoch [7] | Adım [150/3939] | Anlık Loss: 0.1614
# Epoch [7] | Adım [200/3939] | Anlık Loss: 0.0746
# Epoch [7] | Adım [250/3939] | Anlık Loss: 0.0191
# Epoch [7] | Adım [300/3939] | Anlık Loss: 0.0175
# Epoch [7] | Adım [350/3939] | Anlık Loss: 0.0148
# Epoch [7] | Adım [400/3939] | Anlık Loss: 0.0531
# Epoch [7] | Adım [450/3939] | Anlık Loss: 0.0644
# Epoch [7] | Adım [500/3939] | Anlık Loss: 0.2014
# Epoch [7] | Adım [550/3939] | Anlık Loss: 0.0230
# Epoch [7] | Adım [600/3939] | Anlık Loss: 0.0237
# Epoch [7] | Adım [650/3939] | Anlık Loss: 0.0095
# Epoch [7] | Adım [700/3939] | Anlık Loss: 0.2152
# Epoch [7] | Adım [750/3939] | Anlık Loss: 0.0610
# Epoch [7] | Adım [800/3939] | Anlık Loss: 0.0054
# Epoch [7] | Adım [850/3939] | Anlık Loss: 0.0015
# Epoch [7] | Adım [900/3939] | Anlık Loss: 0.3214
# Epoch [7] | Adım [950/3939] | Anlık Loss: 0.0095
# Epoch [7] | Adım [1000/3939] | Anlık Loss: 0.0201
# Epoch [7] | Adım [1050/3939] | Anlık Loss: 0.0823
# Epoch [7] | Adım [1100/3939] | Anlık Loss: 0.0328
# Epoch [7] | Adım [1150/3939] | Anlık Loss: 0.0215
# Epoch [7] | Adım [1200/3939] | Anlık Loss: 0.0131
# Epoch [7] | Adım [1250/3939] | Anlık Loss: 0.1464
# Epoch [7] | Adım [1300/3939] | Anlık Loss: 0.0822
# Epoch [7] | Adım [1350/3939] | Anlık Loss: 0.0261
# Epoch [7] | Adım [1400/3939] | Anlık Loss: 0.0843
# Epoch [7] | Adım [1450/3939] | Anlık Loss: 0.0054
# Epoch [7] | Adım [1500/3939] | Anlık Loss: 0.1863
# Epoch [7] | Adım [1550/3939] | Anlık Loss: 0.0120
# Epoch [7] | Adım [1600/3939] | Anlık Loss: 0.0358
# Epoch [7] | Adım [1650/3939] | Anlık Loss: 0.0125
# Epoch [7] | Adım [1700/3939] | Anlık Loss: 0.1031
# Epoch [7] | Adım [1750/3939] | Anlık Loss: 0.0047
# Epoch [7] | Adım [1800/3939] | Anlık Loss: 0.0256
# Epoch [7] | Adım [1850/3939] | Anlık Loss: 0.0707
# Epoch [7] | Adım [1900/3939] | Anlık Loss: 0.0113
# Epoch [7] | Adım [1950/3939] | Anlık Loss: 0.1582
# Epoch [7] | Adım [2000/3939] | Anlık Loss: 0.0676
# Epoch [7] | Adım [2050/3939] | Anlık Loss: 0.1332
# Epoch [7] | Adım [2100/3939] | Anlık Loss: 0.0219
# Epoch [7] | Adım [2150/3939] | Anlık Loss: 0.1157
# Epoch [7] | Adım [2200/3939] | Anlık Loss: 0.0450
# Epoch [7] | Adım [2250/3939] | Anlık Loss: 0.0876
# Epoch [7] | Adım [2300/3939] | Anlık Loss: 0.0361
# Epoch [7] | Adım [2350/3939] | Anlık Loss: 0.0614
# Epoch [7] | Adım [2400/3939] | Anlık Loss: 0.0205
# Epoch [7] | Adım [2450/3939] | Anlık Loss: 0.0228
# Epoch [7] | Adım [2500/3939] | Anlık Loss: 0.0136
# Epoch [7] | Adım [2550/3939] | Anlık Loss: 0.1719
# Epoch [7] | Adım [2600/3939] | Anlık Loss: 0.0541
# Epoch [7] | Adım [2650/3939] | Anlık Loss: 0.2532
# Epoch [7] | Adım [2700/3939] | Anlık Loss: 0.0335
# Epoch [7] | Adım [2750/3939] | Anlık Loss: 0.0051
# Epoch [7] | Adım [2800/3939] | Anlık Loss: 0.0058
# Epoch [7] | Adım [2850/3939] | Anlık Loss: 0.0034
# Epoch [7] | Adım [2900/3939] | Anlık Loss: 0.0021
# Epoch [7] | Adım [2950/3939] | Anlık Loss: 0.1401
# Epoch [7] | Adım [3000/3939] | Anlık Loss: 0.0261
# Epoch [7] | Adım [3050/3939] | Anlık Loss: 0.0388
# Epoch [7] | Adım [3100/3939] | Anlık Loss: 0.0316
# Epoch [7] | Adım [3150/3939] | Anlık Loss: 0.1963
# Epoch [7] | Adım [3200/3939] | Anlık Loss: 0.3312
# Epoch [7] | Adım [3250/3939] | Anlık Loss: 0.0149
# Epoch [7] | Adım [3300/3939] | Anlık Loss: 0.0048
# Epoch [7] | Adım [3350/3939] | Anlık Loss: 0.0160
# Epoch [7] | Adım [3400/3939] | Anlık Loss: 0.4144
# Epoch [7] | Adım [3450/3939] | Anlık Loss: 0.0126
# Epoch [7] | Adım [3500/3939] | Anlık Loss: 0.2675
# Epoch [7] | Adım [3550/3939] | Anlık Loss: 0.1110
# Epoch [7] | Adım [3600/3939] | Anlık Loss: 0.0199
# Epoch [7] | Adım [3650/3939] | Anlık Loss: 0.0423
# Epoch [7] | Adım [3700/3939] | Anlık Loss: 0.0077
# Epoch [7] | Adım [3750/3939] | Anlık Loss: 0.0393
# Epoch [7] | Adım [3800/3939] | Anlık Loss: 0.0590
# Epoch [7] | Adım [3850/3939] | Anlık Loss: 0.0094
# Epoch [7] | Adım [3900/3939] | Anlık Loss: 0.0004
# Epoch 7 Bitti (454.9 sn) | Train Acc: %97.08 | Loss: 0.0926
# Doğrulama (Validation) yapılıyor...
# VAL ACC: %96.93
# ------------------------------------------------------------
# Epoch [8] | Adım [50/3939] | Anlık Loss: 0.0589
# Epoch [8] | Adım [100/3939] | Anlık Loss: 0.0074
# Epoch [8] | Adım [150/3939] | Anlık Loss: 0.1042
# Epoch [8] | Adım [200/3939] | Anlık Loss: 0.0105
# Epoch [8] | Adım [250/3939] | Anlık Loss: 0.0459
# Epoch [8] | Adım [300/3939] | Anlık Loss: 0.2667
# Epoch [8] | Adım [350/3939] | Anlık Loss: 0.1070
# Epoch [8] | Adım [400/3939] | Anlık Loss: 0.0158
# Epoch [8] | Adım [450/3939] | Anlık Loss: 0.0148
# Epoch [8] | Adım [500/3939] | Anlık Loss: 0.0404
# Epoch [8] | Adım [550/3939] | Anlık Loss: 0.3289
# Epoch [8] | Adım [600/3939] | Anlık Loss: 0.0408
# Epoch [8] | Adım [650/3939] | Anlık Loss: 0.0500
# Epoch [8] | Adım [700/3939] | Anlık Loss: 0.0107
# Epoch [8] | Adım [750/3939] | Anlık Loss: 0.0584
# Epoch [8] | Adım [800/3939] | Anlık Loss: 0.0017
# Epoch [8] | Adım [850/3939] | Anlık Loss: 0.0098
# Epoch [8] | Adım [900/3939] | Anlık Loss: 0.0013
# Epoch [8] | Adım [950/3939] | Anlık Loss: 0.3336
# Epoch [8] | Adım [1000/3939] | Anlık Loss: 0.0128
# Epoch [8] | Adım [1050/3939] | Anlık Loss: 0.0929
# Epoch [8] | Adım [1100/3939] | Anlık Loss: 0.0279
# Epoch [8] | Adım [1150/3939] | Anlık Loss: 0.1004
# Epoch [8] | Adım [1200/3939] | Anlık Loss: 0.0140
# Epoch [8] | Adım [1250/3939] | Anlık Loss: 0.0045
# Epoch [8] | Adım [1300/3939] | Anlık Loss: 0.0990
# Epoch [8] | Adım [1350/3939] | Anlık Loss: 0.0201
# Epoch [8] | Adım [1400/3939] | Anlık Loss: 0.0081
# Epoch [8] | Adım [1450/3939] | Anlık Loss: 0.0010
# Epoch [8] | Adım [1500/3939] | Anlık Loss: 0.0097
# Epoch [8] | Adım [1550/3939] | Anlık Loss: 0.3168
# Epoch [8] | Adım [1600/3939] | Anlık Loss: 0.4714
# Epoch [8] | Adım [1650/3939] | Anlık Loss: 0.0087
# Epoch [8] | Adım [1700/3939] | Anlık Loss: 0.1716
# Epoch [8] | Adım [1750/3939] | Anlık Loss: 0.0008
# Epoch [8] | Adım [1800/3939] | Anlık Loss: 0.0612
# Epoch [8] | Adım [1850/3939] | Anlık Loss: 0.0416
# Epoch [8] | Adım [1900/3939] | Anlık Loss: 0.4776
# Epoch [8] | Adım [1950/3939] | Anlık Loss: 0.1599
# Epoch [8] | Adım [2000/3939] | Anlık Loss: 0.0020
# Epoch [8] | Adım [2050/3939] | Anlık Loss: 0.2343
# Epoch [8] | Adım [2100/3939] | Anlık Loss: 0.0117
# Epoch [8] | Adım [2150/3939] | Anlık Loss: 0.1449
# Epoch [8] | Adım [2200/3939] | Anlık Loss: 0.1063
# Epoch [8] | Adım [2250/3939] | Anlık Loss: 0.0202
# Epoch [8] | Adım [2300/3939] | Anlık Loss: 0.1694
# Epoch [8] | Adım [2350/3939] | Anlık Loss: 0.1365
# Epoch [8] | Adım [2400/3939] | Anlık Loss: 0.1934
# Epoch [8] | Adım [2450/3939] | Anlık Loss: 0.0257
# Epoch [8] | Adım [2500/3939] | Anlık Loss: 0.0023
# Epoch [8] | Adım [2550/3939] | Anlık Loss: 0.0094
# Epoch [8] | Adım [2600/3939] | Anlık Loss: 0.0032
# Epoch [8] | Adım [2650/3939] | Anlık Loss: 0.5948
# Epoch [8] | Adım [2700/3939] | Anlık Loss: 0.0829
# Epoch [8] | Adım [2750/3939] | Anlık Loss: 0.1412
# Epoch [8] | Adım [2800/3939] | Anlık Loss: 0.0004
# Epoch [8] | Adım [2850/3939] | Anlık Loss: 0.0269
# Epoch [8] | Adım [2900/3939] | Anlık Loss: 0.0441
# Epoch [8] | Adım [2950/3939] | Anlık Loss: 0.4120
# Epoch [8] | Adım [3000/3939] | Anlık Loss: 0.0057
# Epoch [8] | Adım [3050/3939] | Anlık Loss: 0.2806
# Epoch [8] | Adım [3100/3939] | Anlık Loss: 0.2797
# Epoch [8] | Adım [3150/3939] | Anlık Loss: 0.0390
# Epoch [8] | Adım [3200/3939] | Anlık Loss: 0.0204
# Epoch [8] | Adım [3250/3939] | Anlık Loss: 0.1451
# Epoch [8] | Adım [3300/3939] | Anlık Loss: 0.0551
# Epoch [8] | Adım [3350/3939] | Anlık Loss: 0.0570
# Epoch [8] | Adım [3400/3939] | Anlık Loss: 0.0452
# Epoch [8] | Adım [3450/3939] | Anlık Loss: 0.0443
# Epoch [8] | Adım [3500/3939] | Anlık Loss: 0.0267
# Epoch [8] | Adım [3550/3939] | Anlık Loss: 0.0008
# Epoch [8] | Adım [3600/3939] | Anlık Loss: 0.0341
# Epoch [8] | Adım [3650/3939] | Anlık Loss: 0.0042
# Epoch [8] | Adım [3700/3939] | Anlık Loss: 0.1256
# Epoch [8] | Adım [3750/3939] | Anlık Loss: 0.0107
# Epoch [8] | Adım [3800/3939] | Anlık Loss: 0.0707
# Epoch [8] | Adım [3850/3939] | Anlık Loss: 0.0029
# Epoch [8] | Adım [3900/3939] | Anlık Loss: 0.0330
# Epoch 8 Bitti (453.2 sn) | Train Acc: %97.27 | Loss: 0.0836
# Doğrulama (Validation) yapılıyor...
# VAL ACC: %97.30
# ------------------------------------------------------------
# Epoch [9] | Adım [50/3939] | Anlık Loss: 0.0383
# Epoch [9] | Adım [100/3939] | Anlık Loss: 0.2926
# Epoch [9] | Adım [150/3939] | Anlık Loss: 0.0450
# Epoch [9] | Adım [200/3939] | Anlık Loss: 0.2344
# Epoch [9] | Adım [250/3939] | Anlık Loss: 0.0075
# Epoch [9] | Adım [300/3939] | Anlık Loss: 0.0702
# Epoch [9] | Adım [350/3939] | Anlık Loss: 0.0452
# Epoch [9] | Adım [400/3939] | Anlık Loss: 0.1242
# Epoch [9] | Adım [450/3939] | Anlık Loss: 0.0616
# Epoch [9] | Adım [500/3939] | Anlık Loss: 0.0563
# Epoch [9] | Adım [550/3939] | Anlık Loss: 0.0587
# Epoch [9] | Adım [600/3939] | Anlık Loss: 0.0151
# Epoch [9] | Adım [650/3939] | Anlık Loss: 0.0652
# Epoch [9] | Adım [700/3939] | Anlık Loss: 0.0182
# Epoch [9] | Adım [750/3939] | Anlık Loss: 0.5974
# Epoch [9] | Adım [800/3939] | Anlık Loss: 0.0204
# Epoch [9] | Adım [850/3939] | Anlık Loss: 0.2695
# Epoch [9] | Adım [900/3939] | Anlık Loss: 0.1682
# Epoch [9] | Adım [950/3939] | Anlık Loss: 0.0014
# Epoch [9] | Adım [1000/3939] | Anlık Loss: 0.0067
# Epoch [9] | Adım [1050/3939] | Anlık Loss: 0.0091
# Epoch [9] | Adım [1100/3939] | Anlık Loss: 0.0582
# Epoch [9] | Adım [1150/3939] | Anlık Loss: 0.0195
# Epoch [9] | Adım [1200/3939] | Anlık Loss: 0.0167
# Epoch [9] | Adım [1250/3939] | Anlık Loss: 0.2166
# Epoch [9] | Adım [1300/3939] | Anlık Loss: 0.1357
# Epoch [9] | Adım [1350/3939] | Anlık Loss: 0.0048
# Epoch [9] | Adım [1400/3939] | Anlık Loss: 0.0398
# Epoch [9] | Adım [1450/3939] | Anlık Loss: 0.0113
# Epoch [9] | Adım [1500/3939] | Anlık Loss: 0.0496
# Epoch [9] | Adım [1550/3939] | Anlık Loss: 0.0438
# Epoch [9] | Adım [1600/3939] | Anlık Loss: 0.1602
# Epoch [9] | Adım [1650/3939] | Anlık Loss: 0.0072
# Epoch [9] | Adım [1700/3939] | Anlık Loss: 0.0122
# Epoch [9] | Adım [1750/3939] | Anlık Loss: 0.0746
# Epoch [9] | Adım [1800/3939] | Anlık Loss: 0.0210
# Epoch [9] | Adım [1850/3939] | Anlık Loss: 0.0076
# Epoch [9] | Adım [1900/3939] | Anlık Loss: 0.3420
# Epoch [9] | Adım [1950/3939] | Anlık Loss: 0.0385
# Epoch [9] | Adım [2000/3939] | Anlık Loss: 0.0328
# Epoch [9] | Adım [2050/3939] | Anlık Loss: 0.0876
# Epoch [9] | Adım [2100/3939] | Anlık Loss: 0.1632
# Epoch [9] | Adım [2150/3939] | Anlık Loss: 0.2694
# Epoch [9] | Adım [2200/3939] | Anlık Loss: 0.0323
# Epoch [9] | Adım [2250/3939] | Anlık Loss: 0.0067
# Epoch [9] | Adım [2300/3939] | Anlık Loss: 0.0078
# Epoch [9] | Adım [2350/3939] | Anlık Loss: 0.0014
# Epoch [9] | Adım [2400/3939] | Anlık Loss: 0.1090
# Epoch [9] | Adım [2450/3939] | Anlık Loss: 0.0178
# Epoch [9] | Adım [2500/3939] | Anlık Loss: 0.0366
# Epoch [9] | Adım [2550/3939] | Anlık Loss: 0.2179
# Epoch [9] | Adım [2600/3939] | Anlık Loss: 0.3584
# Epoch [9] | Adım [2650/3939] | Anlık Loss: 0.0642
# Epoch [9] | Adım [2700/3939] | Anlık Loss: 0.1005
# Epoch [9] | Adım [2750/3939] | Anlık Loss: 0.0163
# Epoch [9] | Adım [2800/3939] | Anlık Loss: 0.0091
# Epoch [9] | Adım [2850/3939] | Anlık Loss: 0.0343
# Epoch [9] | Adım [2900/3939] | Anlık Loss: 0.0382
# Epoch [9] | Adım [2950/3939] | Anlık Loss: 0.0274
# Epoch [9] | Adım [3000/3939] | Anlık Loss: 0.1654
# Epoch [9] | Adım [3050/3939] | Anlık Loss: 0.2062
# Epoch [9] | Adım [3100/3939] | Anlık Loss: 0.0064
# Epoch [9] | Adım [3150/3939] | Anlık Loss: 0.0847
# Epoch [9] | Adım [3200/3939] | Anlık Loss: 0.0548
# Epoch [9] | Adım [3250/3939] | Anlık Loss: 0.0611
# Epoch [9] | Adım [3300/3939] | Anlık Loss: 0.3200
# Epoch [9] | Adım [3350/3939] | Anlık Loss: 0.0524
# Epoch [9] | Adım [3400/3939] | Anlık Loss: 0.0019
# Epoch [9] | Adım [3450/3939] | Anlık Loss: 0.0890
# Epoch [9] | Adım [3500/3939] | Anlık Loss: 0.0067
# Epoch [9] | Adım [3550/3939] | Anlık Loss: 0.0500
# Epoch [9] | Adım [3600/3939] | Anlık Loss: 0.0111
# Epoch [9] | Adım [3650/3939] | Anlık Loss: 0.1647
# Epoch [9] | Adım [3700/3939] | Anlık Loss: 0.0774
# Epoch [9] | Adım [3750/3939] | Anlık Loss: 0.3436
# Epoch [9] | Adım [3800/3939] | Anlık Loss: 0.2123
# Epoch [9] | Adım [3850/3939] | Anlık Loss: 0.0501
# Epoch [9] | Adım [3900/3939] | Anlık Loss: 0.1447
# Epoch 9 Bitti (455.1 sn) | Train Acc: %97.49 | Loss: 0.0780
# Doğrulama (Validation) yapılıyor...
# VAL ACC: %97.14
# ------------------------------------------------------------
# Epoch [10] | Adım [50/3939] | Anlık Loss: 0.1504
# Epoch [10] | Adım [100/3939] | Anlık Loss: 0.0414
# Epoch [10] | Adım [150/3939] | Anlık Loss: 0.0169
# Epoch [10] | Adım [200/3939] | Anlık Loss: 0.0440
# Epoch [10] | Adım [250/3939] | Anlık Loss: 0.0060
# Epoch [10] | Adım [300/3939] | Anlık Loss: 0.0697
# Epoch [10] | Adım [350/3939] | Anlık Loss: 0.0018
# Epoch [10] | Adım [400/3939] | Anlık Loss: 0.0009
# Epoch [10] | Adım [450/3939] | Anlık Loss: 0.0879
# Epoch [10] | Adım [500/3939] | Anlık Loss: 0.0059
# Epoch [10] | Adım [550/3939] | Anlık Loss: 0.0741
# Epoch [10] | Adım [600/3939] | Anlık Loss: 0.3410
# Epoch [10] | Adım [650/3939] | Anlık Loss: 0.0373
# Epoch [10] | Adım [700/3939] | Anlık Loss: 0.0003
# Epoch [10] | Adım [750/3939] | Anlık Loss: 0.0014
# Epoch [10] | Adım [800/3939] | Anlık Loss: 0.0100
# Epoch [10] | Adım [850/3939] | Anlık Loss: 0.0527
# Epoch [10] | Adım [900/3939] | Anlık Loss: 0.1100
# Epoch [10] | Adım [950/3939] | Anlık Loss: 0.5750
# Epoch [10] | Adım [1000/3939] | Anlık Loss: 0.0116
# Epoch [10] | Adım [1050/3939] | Anlık Loss: 0.0334
# Epoch [10] | Adım [1100/3939] | Anlık Loss: 0.0033
# Epoch [10] | Adım [1150/3939] | Anlık Loss: 0.0082
# Epoch [10] | Adım [1200/3939] | Anlık Loss: 0.0077
# Epoch [10] | Adım [1250/3939] | Anlık Loss: 0.0003
# Epoch [10] | Adım [1300/3939] | Anlık Loss: 0.0367
# Epoch [10] | Adım [1350/3939] | Anlık Loss: 0.0082
# Epoch [10] | Adım [1400/3939] | Anlık Loss: 0.0133
# Epoch [10] | Adım [1450/3939] | Anlık Loss: 0.0427
# Epoch [10] | Adım [1500/3939] | Anlık Loss: 0.0022
# Epoch [10] | Adım [1550/3939] | Anlık Loss: 0.0087
# Epoch [10] | Adım [1600/3939] | Anlık Loss: 0.0325
# Epoch [10] | Adım [1650/3939] | Anlık Loss: 0.0077
# Epoch [10] | Adım [1700/3939] | Anlık Loss: 0.0021
# Epoch [10] | Adım [1750/3939] | Anlık Loss: 0.0119
# Epoch [10] | Adım [1800/3939] | Anlık Loss: 0.3827
# Epoch [10] | Adım [1850/3939] | Anlık Loss: 0.1847
# Epoch [10] | Adım [1900/3939] | Anlık Loss: 0.0581
# Epoch [10] | Adım [1950/3939] | Anlık Loss: 0.0280
# Epoch [10] | Adım [2000/3939] | Anlık Loss: 0.0216
# Epoch [10] | Adım [2050/3939] | Anlık Loss: 0.0867
# Epoch [10] | Adım [2100/3939] | Anlık Loss: 0.1830
# Epoch [10] | Adım [2150/3939] | Anlık Loss: 0.0006
# Epoch [10] | Adım [2200/3939] | Anlık Loss: 0.0994
# Epoch [10] | Adım [2250/3939] | Anlık Loss: 0.0595
# Epoch [10] | Adım [2300/3939] | Anlık Loss: 0.0019
# Epoch [10] | Adım [2350/3939] | Anlık Loss: 0.5323
# Epoch [10] | Adım [2400/3939] | Anlık Loss: 0.0004
# Epoch [10] | Adım [2450/3939] | Anlık Loss: 0.3637
# Epoch [10] | Adım [2500/3939] | Anlık Loss: 0.2222
# Epoch [10] | Adım [2550/3939] | Anlık Loss: 0.0589
# Epoch [10] | Adım [2600/3939] | Anlık Loss: 0.0252
# Epoch [10] | Adım [2650/3939] | Anlık Loss: 0.1588
# Epoch [10] | Adım [2700/3939] | Anlık Loss: 0.0413
# Epoch [10] | Adım [2750/3939] | Anlık Loss: 0.0271
# Epoch [10] | Adım [2800/3939] | Anlık Loss: 0.0912
# Epoch [10] | Adım [2850/3939] | Anlık Loss: 0.0137
# Epoch [10] | Adım [2900/3939] | Anlık Loss: 0.2158
# Epoch [10] | Adım [2950/3939] | Anlık Loss: 0.0286
# Epoch [10] | Adım [3000/3939] | Anlık Loss: 0.1754
# Epoch [10] | Adım [3050/3939] | Anlık Loss: 0.3499
# Epoch [10] | Adım [3100/3939] | Anlık Loss: 0.1439
# Epoch [10] | Adım [3150/3939] | Anlık Loss: 0.0043
# Epoch [10] | Adım [3200/3939] | Anlık Loss: 0.0505
# Epoch [10] | Adım [3250/3939] | Anlık Loss: 0.0164
# Epoch [10] | Adım [3300/3939] | Anlık Loss: 0.1892
# Epoch [10] | Adım [3350/3939] | Anlık Loss: 0.0001
# Epoch [10] | Adım [3400/3939] | Anlık Loss: 0.0855
# Epoch [10] | Adım [3450/3939] | Anlık Loss: 0.0156
# Epoch [10] | Adım [3500/3939] | Anlık Loss: 0.0798
# Epoch [10] | Adım [3550/3939] | Anlık Loss: 0.0192
# Epoch [10] | Adım [3600/3939] | Anlık Loss: 0.0065
# Epoch [10] | Adım [3650/3939] | Anlık Loss: 0.0040
# Epoch [10] | Adım [3700/3939] | Anlık Loss: 0.0090
# Epoch [10] | Adım [3750/3939] | Anlık Loss: 0.1642
# Epoch [10] | Adım [3800/3939] | Anlık Loss: 0.0669
# Epoch [10] | Adım [3850/3939] | Anlık Loss: 0.0089
# Epoch [10] | Adım [3900/3939] | Anlık Loss: 0.0140
# Epoch 10 Bitti (454.6 sn) | Train Acc: %97.82 | Loss: 0.0685
# Doğrulama (Validation) yapılıyor...
# VAL ACC: %97.94
# ------------------------------------------------------------
# Epoch [11] | Adım [50/3939] | Anlık Loss: 0.0146
# Epoch [11] | Adım [100/3939] | Anlık Loss: 0.0240
# Epoch [11] | Adım [150/3939] | Anlık Loss: 0.0847
# Epoch [11] | Adım [200/3939] | Anlık Loss: 0.1432
# Epoch [11] | Adım [250/3939] | Anlık Loss: 0.0144
# Epoch [11] | Adım [300/3939] | Anlık Loss: 0.0179
# Epoch [11] | Adım [350/3939] | Anlık Loss: 0.0117
# Epoch [11] | Adım [400/3939] | Anlık Loss: 0.0349
# Epoch [11] | Adım [450/3939] | Anlık Loss: 0.0030
# Epoch [11] | Adım [500/3939] | Anlık Loss: 0.0130
# Epoch [11] | Adım [550/3939] | Anlık Loss: 0.0253
# Epoch [11] | Adım [600/3939] | Anlık Loss: 0.0221
# Epoch [11] | Adım [650/3939] | Anlık Loss: 0.2820
# Epoch [11] | Adım [700/3939] | Anlık Loss: 0.0108
# Epoch [11] | Adım [750/3939] | Anlık Loss: 0.0084
# Epoch [11] | Adım [800/3939] | Anlık Loss: 0.0898
# Epoch [11] | Adım [850/3939] | Anlık Loss: 0.0019
# Epoch [11] | Adım [900/3939] | Anlık Loss: 0.0113
# Epoch [11] | Adım [950/3939] | Anlık Loss: 0.0091
# Epoch [11] | Adım [1000/3939] | Anlık Loss: 0.0617
# Epoch [11] | Adım [1050/3939] | Anlık Loss: 0.0650
# Epoch [11] | Adım [1100/3939] | Anlık Loss: 0.0077
# Epoch [11] | Adım [1150/3939] | Anlık Loss: 0.0586
# Epoch [11] | Adım [1200/3939] | Anlık Loss: 0.0013
# Epoch [11] | Adım [1250/3939] | Anlık Loss: 0.0006
# Epoch [11] | Adım [1300/3939] | Anlık Loss: 0.0008
# Epoch [11] | Adım [1350/3939] | Anlık Loss: 0.0066
# Epoch [11] | Adım [1400/3939] | Anlık Loss: 0.1394
# Epoch [11] | Adım [1450/3939] | Anlık Loss: 0.0260
# Epoch [11] | Adım [1500/3939] | Anlık Loss: 0.0055
# Epoch [11] | Adım [1550/3939] | Anlık Loss: 0.0333
# Epoch [11] | Adım [1600/3939] | Anlık Loss: 0.0368
# Epoch [11] | Adım [1650/3939] | Anlık Loss: 0.0064
# Epoch [11] | Adım [1700/3939] | Anlık Loss: 0.0016
# Epoch [11] | Adım [1750/3939] | Anlık Loss: 0.0049
# Epoch [11] | Adım [1800/3939] | Anlık Loss: 0.1155
# Epoch [11] | Adım [1850/3939] | Anlık Loss: 0.0142
# Epoch [11] | Adım [1900/3939] | Anlık Loss: 0.0068
# Epoch [11] | Adım [1950/3939] | Anlık Loss: 0.0376
# Epoch [11] | Adım [2000/3939] | Anlık Loss: 0.0657
# Epoch [11] | Adım [2050/3939] | Anlık Loss: 0.0051
# Epoch [11] | Adım [2100/3939] | Anlık Loss: 0.0060
# Epoch [11] | Adım [2150/3939] | Anlık Loss: 0.1563
# Epoch [11] | Adım [2200/3939] | Anlık Loss: 0.1310
# Epoch [11] | Adım [2250/3939] | Anlık Loss: 0.0198
# Epoch [11] | Adım [2300/3939] | Anlık Loss: 0.0051
# Epoch [11] | Adım [2350/3939] | Anlık Loss: 0.1516
# Epoch [11] | Adım [2400/3939] | Anlık Loss: 0.0662
# Epoch [11] | Adım [2450/3939] | Anlık Loss: 0.0131
# Epoch [11] | Adım [2500/3939] | Anlık Loss: 0.0018
# Epoch [11] | Adım [2550/3939] | Anlık Loss: 0.8570
# Epoch [11] | Adım [2600/3939] | Anlık Loss: 0.1694
# Epoch [11] | Adım [2650/3939] | Anlık Loss: 0.1150
# Epoch [11] | Adım [2700/3939] | Anlık Loss: 0.0073
# Epoch [11] | Adım [2750/3939] | Anlık Loss: 0.0227
# Epoch [11] | Adım [2800/3939] | Anlık Loss: 0.0515
# Epoch [11] | Adım [2850/3939] | Anlık Loss: 0.0333
# Epoch [11] | Adım [2900/3939] | Anlık Loss: 0.0267
# Epoch [11] | Adım [2950/3939] | Anlık Loss: 0.0327
# Epoch [11] | Adım [3000/3939] | Anlık Loss: 0.1427
# Epoch [11] | Adım [3050/3939] | Anlık Loss: 0.1673
# Epoch [11] | Adım [3100/3939] | Anlık Loss: 0.2158
# Epoch [11] | Adım [3150/3939] | Anlık Loss: 0.0348
# Epoch [11] | Adım [3200/3939] | Anlık Loss: 0.0031
# Epoch [11] | Adım [3250/3939] | Anlık Loss: 0.0630
# Epoch [11] | Adım [3300/3939] | Anlık Loss: 0.0146
# Epoch [11] | Adım [3350/3939] | Anlık Loss: 0.0721
# Epoch [11] | Adım [3400/3939] | Anlık Loss: 0.0304
# Epoch [11] | Adım [3450/3939] | Anlık Loss: 0.1346
# Epoch [11] | Adım [3500/3939] | Anlık Loss: 0.0172
# Epoch [11] | Adım [3550/3939] | Anlık Loss: 0.0010
# Epoch [11] | Adım [3600/3939] | Anlık Loss: 0.0062
# Epoch [11] | Adım [3650/3939] | Anlık Loss: 0.0380
# Epoch [11] | Adım [3700/3939] | Anlık Loss: 0.0228
# Epoch [11] | Adım [3750/3939] | Anlık Loss: 0.0049
# Epoch [11] | Adım [3800/3939] | Anlık Loss: 0.0009
# Epoch [11] | Adım [3850/3939] | Anlık Loss: 0.0697
# Epoch [11] | Adım [3900/3939] | Anlık Loss: 0.0312
# Epoch 11 Bitti (454.7 sn) | Train Acc: %97.84 | Loss: 0.0674
# Doğrulama (Validation) yapılıyor...
# VAL ACC: %97.71
# ------------------------------------------------------------
# Epoch [12] | Adım [50/3939] | Anlık Loss: 0.0043
# Epoch [12] | Adım [100/3939] | Anlık Loss: 0.0053
# Epoch [12] | Adım [150/3939] | Anlık Loss: 0.0790
# Epoch [12] | Adım [200/3939] | Anlık Loss: 0.0201
# Epoch [12] | Adım [250/3939] | Anlık Loss: 0.0104
# Epoch [12] | Adım [300/3939] | Anlık Loss: 0.0043
# Epoch [12] | Adım [350/3939] | Anlık Loss: 0.0322
# Epoch [12] | Adım [400/3939] | Anlık Loss: 0.0651
# Epoch [12] | Adım [450/3939] | Anlık Loss: 0.1033
# Epoch [12] | Adım [500/3939] | Anlık Loss: 0.1023
# Epoch [12] | Adım [550/3939] | Anlık Loss: 0.0013
# Epoch [12] | Adım [600/3939] | Anlık Loss: 0.1245
# Epoch [12] | Adım [650/3939] | Anlık Loss: 0.0189
# Epoch [12] | Adım [700/3939] | Anlık Loss: 0.0003
# Epoch [12] | Adım [750/3939] | Anlık Loss: 0.1167
# Epoch [12] | Adım [800/3939] | Anlık Loss: 0.0002
# Epoch [12] | Adım [850/3939] | Anlık Loss: 0.5870
# Epoch [12] | Adım [900/3939] | Anlık Loss: 0.0150
# Epoch [12] | Adım [950/3939] | Anlık Loss: 0.1928
# Epoch [12] | Adım [1000/3939] | Anlık Loss: 0.0138
# Epoch [12] | Adım [1050/3939] | Anlık Loss: 0.0368
# Epoch [12] | Adım [1100/3939] | Anlık Loss: 0.0354
# Epoch [12] | Adım [1150/3939] | Anlık Loss: 0.0088
# Epoch [12] | Adım [1200/3939] | Anlık Loss: 0.0004
# Epoch [12] | Adım [1250/3939] | Anlık Loss: 0.0330
# Epoch [12] | Adım [1300/3939] | Anlık Loss: 0.0687
# Epoch [12] | Adım [1350/3939] | Anlık Loss: 0.0064
# Epoch [12] | Adım [1400/3939] | Anlık Loss: 0.0041
# Epoch [12] | Adım [1450/3939] | Anlık Loss: 0.1175
# Epoch [12] | Adım [1500/3939] | Anlık Loss: 0.0024
# Epoch [12] | Adım [1550/3939] | Anlık Loss: 0.0421
# Epoch [12] | Adım [1600/3939] | Anlık Loss: 0.0056
# Epoch [12] | Adım [1650/3939] | Anlık Loss: 0.0009
# Epoch [12] | Adım [1700/3939] | Anlık Loss: 0.0086
# Epoch [12] | Adım [1750/3939] | Anlık Loss: 0.0050
# Epoch [12] | Adım [1800/3939] | Anlık Loss: 0.0030
# Epoch [12] | Adım [1850/3939] | Anlık Loss: 0.1214
# Epoch [12] | Adım [1900/3939] | Anlık Loss: 0.0316
# Epoch [12] | Adım [1950/3939] | Anlık Loss: 0.0199
# Epoch [12] | Adım [2000/3939] | Anlık Loss: 0.0433
# Epoch [12] | Adım [2050/3939] | Anlık Loss: 0.0019
# Epoch [12] | Adım [2100/3939] | Anlık Loss: 0.0242
# Epoch [12] | Adım [2150/3939] | Anlık Loss: 0.0330
# Epoch [12] | Adım [2200/3939] | Anlık Loss: 0.2343
# Epoch [12] | Adım [2250/3939] | Anlık Loss: 0.0056
# Epoch [12] | Adım [2300/3939] | Anlık Loss: 0.0018
# Epoch [12] | Adım [2350/3939] | Anlık Loss: 0.1882
# Epoch [12] | Adım [2400/3939] | Anlık Loss: 0.0317
# Epoch [12] | Adım [2450/3939] | Anlık Loss: 0.0763
# Epoch [12] | Adım [2500/3939] | Anlık Loss: 0.0886
# Epoch [12] | Adım [2550/3939] | Anlık Loss: 0.4867
# Epoch [12] | Adım [2600/3939] | Anlık Loss: 0.0347
# Epoch [12] | Adım [2650/3939] | Anlık Loss: 0.0533
# Epoch [12] | Adım [2700/3939] | Anlık Loss: 0.0037
# Epoch [12] | Adım [2750/3939] | Anlık Loss: 0.6255
# Epoch [12] | Adım [2800/3939] | Anlık Loss: 0.5529
# Epoch [12] | Adım [2850/3939] | Anlık Loss: 0.0022
# Epoch [12] | Adım [2900/3939] | Anlık Loss: 0.1071
# Epoch [12] | Adım [2950/3939] | Anlık Loss: 0.0971
# Epoch [12] | Adım [3000/3939] | Anlık Loss: 0.0069
# Epoch [12] | Adım [3050/3939] | Anlık Loss: 0.2205
# Epoch [12] | Adım [3100/3939] | Anlık Loss: 0.0017
# Epoch [12] | Adım [3150/3939] | Anlık Loss: 0.0008
# Epoch [12] | Adım [3200/3939] | Anlık Loss: 0.0391
# Epoch [12] | Adım [3250/3939] | Anlık Loss: 0.0025
# Epoch [12] | Adım [3300/3939] | Anlık Loss: 0.0462
# Epoch [12] | Adım [3350/3939] | Anlık Loss: 0.0085
# Epoch [12] | Adım [3400/3939] | Anlık Loss: 0.3137
# Epoch [12] | Adım [3450/3939] | Anlık Loss: 0.1287
# Epoch [12] | Adım [3500/3939] | Anlık Loss: 0.1224
# Epoch [12] | Adım [3550/3939] | Anlık Loss: 0.0158
# Epoch [12] | Adım [3600/3939] | Anlık Loss: 0.0619
# Epoch [12] | Adım [3650/3939] | Anlık Loss: 0.0033
# Epoch [12] | Adım [3700/3939] | Anlık Loss: 0.0111
# Epoch [12] | Adım [3750/3939] | Anlık Loss: 0.0182
# Epoch [12] | Adım [3800/3939] | Anlık Loss: 0.0030
# Epoch [12] | Adım [3850/3939] | Anlık Loss: 0.0288
# Epoch [12] | Adım [3900/3939] | Anlık Loss: 0.0012
# Epoch 12 Bitti (458.9 sn) | Train Acc: %98.09 | Loss: 0.0587
# Doğrulama (Validation) yapılıyor...
# VAL ACC: %97.89
# ------------------------------------------------------------
# Epoch [13] | Adım [50/3939] | Anlık Loss: 0.0275
# Epoch [13] | Adım [100/3939] | Anlık Loss: 0.0049
# Epoch [13] | Adım [150/3939] | Anlık Loss: 0.1036
# Epoch [13] | Adım [200/3939] | Anlık Loss: 0.0013
# Epoch [13] | Adım [250/3939] | Anlık Loss: 0.0226
# Epoch [13] | Adım [300/3939] | Anlık Loss: 0.0268
# Epoch [13] | Adım [350/3939] | Anlık Loss: 0.1149
# Epoch [13] | Adım [400/3939] | Anlık Loss: 0.0166
# Epoch [13] | Adım [450/3939] | Anlık Loss: 0.0405
# Epoch [13] | Adım [500/3939] | Anlık Loss: 0.1341
# Epoch [13] | Adım [550/3939] | Anlık Loss: 0.2136
# Epoch [13] | Adım [600/3939] | Anlık Loss: 0.0007
# Epoch [13] | Adım [650/3939] | Anlık Loss: 0.0036
# Epoch [13] | Adım [700/3939] | Anlık Loss: 0.0005
# Epoch [13] | Adım [750/3939] | Anlık Loss: 0.0368
# Epoch [13] | Adım [800/3939] | Anlık Loss: 0.0013
# Epoch [13] | Adım [850/3939] | Anlık Loss: 0.0012
# Epoch [13] | Adım [900/3939] | Anlık Loss: 0.0054
# Epoch [13] | Adım [950/3939] | Anlık Loss: 0.0135
# Epoch [13] | Adım [1000/3939] | Anlık Loss: 0.0608
# Epoch [13] | Adım [1050/3939] | Anlık Loss: 0.0004
# Epoch [13] | Adım [1100/3939] | Anlık Loss: 0.0010
# Epoch [13] | Adım [1150/3939] | Anlık Loss: 0.1143
# Epoch [13] | Adım [1200/3939] | Anlık Loss: 0.0149
# Epoch [13] | Adım [1250/3939] | Anlık Loss: 0.0347
# Epoch [13] | Adım [1300/3939] | Anlık Loss: 0.0088
# Epoch [13] | Adım [1350/3939] | Anlık Loss: 0.0341
# Epoch [13] | Adım [1400/3939] | Anlık Loss: 0.0706
# Epoch [13] | Adım [1450/3939] | Anlık Loss: 0.0064
# Epoch [13] | Adım [1500/3939] | Anlık Loss: 0.0449
# Epoch [13] | Adım [1550/3939] | Anlık Loss: 0.0016
# Epoch [13] | Adım [1600/3939] | Anlık Loss: 0.0418
# Epoch [13] | Adım [1650/3939] | Anlık Loss: 0.0025
# Epoch [13] | Adım [1700/3939] | Anlık Loss: 0.0001
# Epoch [13] | Adım [1750/3939] | Anlık Loss: 0.0019
# Epoch [13] | Adım [1800/3939] | Anlık Loss: 0.0030
# Epoch [13] | Adım [1850/3939] | Anlık Loss: 0.0023
# Epoch [13] | Adım [1900/3939] | Anlık Loss: 0.0004
# Epoch [13] | Adım [1950/3939] | Anlık Loss: 0.0031
# Epoch [13] | Adım [2000/3939] | Anlık Loss: 0.0051
# Epoch [13] | Adım [2050/3939] | Anlık Loss: 0.1239
# Epoch [13] | Adım [2100/3939] | Anlık Loss: 0.0397
# Epoch [13] | Adım [2150/3939] | Anlık Loss: 0.1695
# Epoch [13] | Adım [2200/3939] | Anlık Loss: 0.0009
# Epoch [13] | Adım [2250/3939] | Anlık Loss: 0.0003
# Epoch [13] | Adım [2300/3939] | Anlık Loss: 0.2098
# Epoch [13] | Adım [2350/3939] | Anlık Loss: 0.2913
# Epoch [13] | Adım [2400/3939] | Anlık Loss: 0.1032
# Epoch [13] | Adım [2450/3939] | Anlık Loss: 0.0547
# Epoch [13] | Adım [2500/3939] | Anlık Loss: 0.1820
# Epoch [13] | Adım [2550/3939] | Anlık Loss: 0.0425
# Epoch [13] | Adım [2600/3939] | Anlık Loss: 0.0298
# Epoch [13] | Adım [2650/3939] | Anlık Loss: 0.0803
# Epoch [13] | Adım [2700/3939] | Anlık Loss: 0.1714
# Epoch [13] | Adım [2750/3939] | Anlık Loss: 0.0013
# Epoch [13] | Adım [2800/3939] | Anlık Loss: 0.0762
# Epoch [13] | Adım [2850/3939] | Anlık Loss: 0.0020
# Epoch [13] | Adım [2900/3939] | Anlık Loss: 0.0109
# Epoch [13] | Adım [2950/3939] | Anlık Loss: 0.0007
# Epoch [13] | Adım [3000/3939] | Anlık Loss: 0.0968
# Epoch [13] | Adım [3050/3939] | Anlık Loss: 0.0050
# Epoch [13] | Adım [3100/3939] | Anlık Loss: 0.1075
# Epoch [13] | Adım [3150/3939] | Anlık Loss: 0.0308
# Epoch [13] | Adım [3200/3939] | Anlık Loss: 0.0190
# Epoch [13] | Adım [3250/3939] | Anlık Loss: 0.1298
# Epoch [13] | Adım [3300/3939] | Anlık Loss: 0.0848
# Epoch [13] | Adım [3350/3939] | Anlık Loss: 0.2857
# Epoch [13] | Adım [3400/3939] | Anlık Loss: 0.1374
# Epoch [13] | Adım [3450/3939] | Anlık Loss: 0.0474
# Epoch [13] | Adım [3500/3939] | Anlık Loss: 0.3432
# Epoch [13] | Adım [3550/3939] | Anlık Loss: 0.2922
# Epoch [13] | Adım [3600/3939] | Anlık Loss: 0.0021
# Epoch [13] | Adım [3650/3939] | Anlık Loss: 0.0063
# Epoch [13] | Adım [3700/3939] | Anlık Loss: 0.0007
# Epoch [13] | Adım [3750/3939] | Anlık Loss: 0.0041
# Epoch [13] | Adım [3800/3939] | Anlık Loss: 0.0090
# Epoch [13] | Adım [3850/3939] | Anlık Loss: 0.0260
# Epoch [13] | Adım [3900/3939] | Anlık Loss: 0.3241
# Epoch 13 Bitti (457.1 sn) | Train Acc: %98.05 | Loss: 0.0599
# Doğrulama (Validation) yapılıyor...
# VAL ACC: %98.01
# ------------------------------------------------------------
# Epoch [14] | Adım [50/3939] | Anlık Loss: 0.1293
# Epoch [14] | Adım [100/3939] | Anlık Loss: 0.1094
# Epoch [14] | Adım [150/3939] | Anlık Loss: 0.0136
# Epoch [14] | Adım [200/3939] | Anlık Loss: 0.2962
# Epoch [14] | Adım [250/3939] | Anlık Loss: 0.0030
# Epoch [14] | Adım [300/3939] | Anlık Loss: 0.0233
# Epoch [14] | Adım [350/3939] | Anlık Loss: 0.0043
# Epoch [14] | Adım [400/3939] | Anlık Loss: 0.0034
# Epoch [14] | Adım [450/3939] | Anlık Loss: 0.0076
# Epoch [14] | Adım [500/3939] | Anlık Loss: 0.0081
# Epoch [14] | Adım [550/3939] | Anlık Loss: 0.0016
# Epoch [14] | Adım [600/3939] | Anlık Loss: 0.0837
# Epoch [14] | Adım [650/3939] | Anlık Loss: 0.0805
# Epoch [14] | Adım [700/3939] | Anlık Loss: 0.0305
# Epoch [14] | Adım [750/3939] | Anlık Loss: 0.1705
# Epoch [14] | Adım [800/3939] | Anlık Loss: 0.0398
# Epoch [14] | Adım [850/3939] | Anlık Loss: 0.0007
# Epoch [14] | Adım [900/3939] | Anlık Loss: 0.1557
# Epoch [14] | Adım [950/3939] | Anlık Loss: 0.0711
# Epoch [14] | Adım [1000/3939] | Anlık Loss: 0.0012
# Epoch [14] | Adım [1050/3939] | Anlık Loss: 0.0120
# Epoch [14] | Adım [1100/3939] | Anlık Loss: 0.0005
# Epoch [14] | Adım [1150/3939] | Anlık Loss: 0.0038
# Epoch [14] | Adım [1200/3939] | Anlık Loss: 0.0038
# Epoch [14] | Adım [1250/3939] | Anlık Loss: 0.1785
# Epoch [14] | Adım [1300/3939] | Anlık Loss: 0.0004
# Epoch [14] | Adım [1350/3939] | Anlık Loss: 0.0039
# Epoch [14] | Adım [1400/3939] | Anlık Loss: 0.0043
# Epoch [14] | Adım [1450/3939] | Anlık Loss: 0.0018
# Epoch [14] | Adım [1500/3939] | Anlık Loss: 0.0215
# Epoch [14] | Adım [1550/3939] | Anlık Loss: 0.0098
# Epoch [14] | Adım [1600/3939] | Anlık Loss: 0.0213
# Epoch [14] | Adım [1650/3939] | Anlık Loss: 0.0183
# Epoch [14] | Adım [1700/3939] | Anlık Loss: 0.1033
# Epoch [14] | Adım [1750/3939] | Anlık Loss: 0.0273
# Epoch [14] | Adım [1800/3939] | Anlık Loss: 0.0222
# Epoch [14] | Adım [1850/3939] | Anlık Loss: 0.0011
# Epoch [14] | Adım [1900/3939] | Anlık Loss: 0.0038
# Epoch [14] | Adım [1950/3939] | Anlık Loss: 0.0211
# Epoch [14] | Adım [2000/3939] | Anlık Loss: 0.0623
# Epoch [14] | Adım [2050/3939] | Anlık Loss: 0.0001
# Epoch [14] | Adım [2100/3939] | Anlık Loss: 0.1658
# Epoch [14] | Adım [2150/3939] | Anlık Loss: 0.0460
# Epoch [14] | Adım [2200/3939] | Anlık Loss: 0.2934
# Epoch [14] | Adım [2250/3939] | Anlık Loss: 0.0044
# Epoch [14] | Adım [2300/3939] | Anlık Loss: 0.0042
# Epoch [14] | Adım [2350/3939] | Anlık Loss: 0.0034
# Epoch [14] | Adım [2400/3939] | Anlık Loss: 0.0121
# Epoch [14] | Adım [2450/3939] | Anlık Loss: 0.3359
# Epoch [14] | Adım [2500/3939] | Anlık Loss: 0.0004
# Epoch [14] | Adım [2550/3939] | Anlık Loss: 0.0036
# Epoch [14] | Adım [2600/3939] | Anlık Loss: 0.0085
# Epoch [14] | Adım [2650/3939] | Anlık Loss: 0.0014
# Epoch [14] | Adım [2700/3939] | Anlık Loss: 0.1233
# Epoch [14] | Adım [2750/3939] | Anlık Loss: 0.0029
# Epoch [14] | Adım [2800/3939] | Anlık Loss: 0.0008
# Epoch [14] | Adım [2850/3939] | Anlık Loss: 0.0011
# Epoch [14] | Adım [2900/3939] | Anlık Loss: 0.0168
# Epoch [14] | Adım [2950/3939] | Anlık Loss: 0.1297
# Epoch [14] | Adım [3000/3939] | Anlık Loss: 0.2166
# Epoch [14] | Adım [3050/3939] | Anlık Loss: 0.0933
# Epoch [14] | Adım [3100/3939] | Anlık Loss: 0.1135
# Epoch [14] | Adım [3150/3939] | Anlık Loss: 0.0227
# Epoch [14] | Adım [3200/3939] | Anlık Loss: 0.0033
# Epoch [14] | Adım [3250/3939] | Anlık Loss: 0.0012
# Epoch [14] | Adım [3300/3939] | Anlık Loss: 0.0032
# Epoch [14] | Adım [3350/3939] | Anlık Loss: 0.1281
# Epoch [14] | Adım [3400/3939] | Anlık Loss: 0.0044
# Epoch [14] | Adım [3450/3939] | Anlık Loss: 0.0052
# Epoch [14] | Adım [3500/3939] | Anlık Loss: 0.0124
# Epoch [14] | Adım [3550/3939] | Anlık Loss: 0.0327
# Epoch [14] | Adım [3600/3939] | Anlık Loss: 0.1247
# Epoch [14] | Adım [3650/3939] | Anlık Loss: 0.0002
# Epoch [14] | Adım [3700/3939] | Anlık Loss: 0.2499
# Epoch [14] | Adım [3750/3939] | Anlık Loss: 0.0010
# Epoch [14] | Adım [3800/3939] | Anlık Loss: 0.0005
# Epoch [14] | Adım [3850/3939] | Anlık Loss: 0.0748
# Epoch [14] | Adım [3900/3939] | Anlık Loss: 0.0054
# Epoch 14 Bitti (456.4 sn) | Train Acc: %98.27 | Loss: 0.0531
# Doğrulama (Validation) yapılıyor...
# VAL ACC: %97.86
# ------------------------------------------------------------
# Epoch [15] | Adım [50/3939] | Anlık Loss: 0.0298
# Epoch [15] | Adım [100/3939] | Anlık Loss: 0.0013
# Epoch [15] | Adım [150/3939] | Anlık Loss: 0.0004
# Epoch [15] | Adım [200/3939] | Anlık Loss: 0.3332
# Epoch [15] | Adım [250/3939] | Anlık Loss: 0.0015
# Epoch [15] | Adım [300/3939] | Anlık Loss: 0.0034
# Epoch [15] | Adım [350/3939] | Anlık Loss: 0.0752
# Epoch [15] | Adım [400/3939] | Anlık Loss: 0.0404
# Epoch [15] | Adım [450/3939] | Anlık Loss: 0.0021
# Epoch [15] | Adım [500/3939] | Anlık Loss: 0.0113
# Epoch [15] | Adım [550/3939] | Anlık Loss: 0.0054
# Epoch [15] | Adım [600/3939] | Anlık Loss: 0.2995
# Epoch [15] | Adım [650/3939] | Anlık Loss: 0.1851
# Epoch [15] | Adım [700/3939] | Anlık Loss: 0.0096
# Epoch [15] | Adım [750/3939] | Anlık Loss: 0.0102
# Epoch [15] | Adım [800/3939] | Anlık Loss: 0.0058
# Epoch [15] | Adım [850/3939] | Anlık Loss: 0.0007
# Epoch [15] | Adım [900/3939] | Anlık Loss: 0.0089
# Epoch [15] | Adım [950/3939] | Anlık Loss: 0.0006
# Epoch [15] | Adım [1000/3939] | Anlık Loss: 0.0017
# Epoch [15] | Adım [1050/3939] | Anlık Loss: 0.3339
# Epoch [15] | Adım [1100/3939] | Anlık Loss: 0.2183
# Epoch [15] | Adım [1150/3939] | Anlık Loss: 0.0098
# Epoch [15] | Adım [1200/3939] | Anlık Loss: 0.0051
# Epoch [15] | Adım [1250/3939] | Anlık Loss: 0.1607
# Epoch [15] | Adım [1300/3939] | Anlık Loss: 0.0023
# Epoch [15] | Adım [1350/3939] | Anlık Loss: 0.2778
# Epoch [15] | Adım [1400/3939] | Anlık Loss: 0.0047
# Epoch [15] | Adım [1450/3939] | Anlık Loss: 0.7360
# Epoch [15] | Adım [1500/3939] | Anlık Loss: 0.0046
# Epoch [15] | Adım [1550/3939] | Anlık Loss: 0.0238
# Epoch [15] | Adım [1600/3939] | Anlık Loss: 0.1118
# Epoch [15] | Adım [1650/3939] | Anlık Loss: 0.0021
# Epoch [15] | Adım [1700/3939] | Anlık Loss: 0.0143
# Epoch [15] | Adım [1750/3939] | Anlık Loss: 0.0278
# Epoch [15] | Adım [1800/3939] | Anlık Loss: 0.0081
# Epoch [15] | Adım [1850/3939] | Anlık Loss: 0.0086
# Epoch [15] | Adım [1900/3939] | Anlık Loss: 0.0472
# Epoch [15] | Adım [1950/3939] | Anlık Loss: 0.0617
# Epoch [15] | Adım [2000/3939] | Anlık Loss: 0.0717
# Epoch [15] | Adım [2050/3939] | Anlık Loss: 0.0281
# Epoch [15] | Adım [2100/3939] | Anlık Loss: 0.0128
# Epoch [15] | Adım [2150/3939] | Anlık Loss: 0.0043
# Epoch [15] | Adım [2200/3939] | Anlık Loss: 0.0483
# Epoch [15] | Adım [2250/3939] | Anlık Loss: 0.0962
# Epoch [15] | Adım [2300/3939] | Anlık Loss: 0.0003
# Epoch [15] | Adım [2350/3939] | Anlık Loss: 0.0041
# Epoch [15] | Adım [2400/3939] | Anlık Loss: 0.0144
# Epoch [15] | Adım [2450/3939] | Anlık Loss: 0.0910
# Epoch [15] | Adım [2500/3939] | Anlık Loss: 0.0025
# Epoch [15] | Adım [2550/3939] | Anlık Loss: 0.0048
# Epoch [15] | Adım [2600/3939] | Anlık Loss: 0.0004
# Epoch [15] | Adım [2650/3939] | Anlık Loss: 0.0825
# Epoch [15] | Adım [2700/3939] | Anlık Loss: 0.0163
# Epoch [15] | Adım [2750/3939] | Anlık Loss: 0.0044
# Epoch [15] | Adım [2800/3939] | Anlık Loss: 0.1028
# Epoch [15] | Adım [2850/3939] | Anlık Loss: 0.0925
# Epoch [15] | Adım [2900/3939] | Anlık Loss: 0.0003
# Epoch [15] | Adım [2950/3939] | Anlık Loss: 0.0045
# Epoch [15] | Adım [3000/3939] | Anlık Loss: 0.0338
# Epoch [15] | Adım [3050/3939] | Anlık Loss: 0.0018
# Epoch [15] | Adım [3100/3939] | Anlık Loss: 0.0081
# Epoch [15] | Adım [3150/3939] | Anlık Loss: 0.0006
# Epoch [15] | Adım [3200/3939] | Anlık Loss: 0.1468
# Epoch [15] | Adım [3250/3939] | Anlık Loss: 0.0336
# Epoch [15] | Adım [3300/3939] | Anlık Loss: 0.0054
# Epoch [15] | Adım [3350/3939] | Anlık Loss: 0.0936
# Epoch [15] | Adım [3400/3939] | Anlık Loss: 0.0311
# Epoch [15] | Adım [3450/3939] | Anlık Loss: 0.0025
# Epoch [15] | Adım [3500/3939] | Anlık Loss: 0.0063
# Epoch [15] | Adım [3550/3939] | Anlık Loss: 0.0274
# Epoch [15] | Adım [3600/3939] | Anlık Loss: 0.0060
# Epoch [15] | Adım [3650/3939] | Anlık Loss: 0.0697
# Epoch [15] | Adım [3700/3939] | Anlık Loss: 0.0025
# Epoch [15] | Adım [3750/3939] | Anlık Loss: 0.0385
# Epoch [15] | Adım [3800/3939] | Anlık Loss: 0.0013
# Epoch [15] | Adım [3850/3939] | Anlık Loss: 0.0682
# Epoch [15] | Adım [3900/3939] | Anlık Loss: 0.0034
# Epoch 15 Bitti (455.7 sn) | Train Acc: %98.44 | Loss: 0.0486
# Doğrulama (Validation) yapılıyor...
# VAL ACC: %98.08
# ------------------------------------------------------------
# Model Kaydedildi.

# %%
import os
import pandas as pd
import torch
import torch.nn as nn
# DirectML kütüphanesini ekliyoruz
import torch_directml
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms, models # models eklendi
from PIL import Image
import random
from sklearn.metrics import f1_score, accuracy_score, classification_report

CSV_DOSYASI = "C:/Users/samsu/Downloads/proje/archive/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/egitim_icin_hazir.csv"
ANA_KLASOR = r"C:/Users/samsu/Downloads/proje/archive/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train"
MODEL_PATH = "amd_model_finalv2.pth" 
BATCH_SIZE = 16 
RESIM_BOYUTU = 128

# Cihazı DirectML olarak ayarlıyoruz
device = torch_directml.device()
print(f"Test işlemi için kullanılan cihaz: {device}")

class TankVeriSeti(Dataset):
    def __init__(self, csv_file, root_dir, transform=None):
        self.veriler = pd.read_csv(csv_file)
        self.root_dir = root_dir
        self.transform = transform
        self.sinif_isimleri = sorted(self.veriler['class'].unique())
        self.sinif_sozlugu = {isim: i for i, isim in enumerate(self.sinif_isimleri)}

    def __len__(self): return len(self.veriler)

    def __getitem__(self, idx):
        try:
            dosya_adi = str(self.veriler.iloc[idx, 0])
            sinif_ismi = str(self.veriler.iloc[idx, 1])
            if "?" in dosya_adi: dosya_adi = dosya_adi.split('?')[0]
            
            yollar = [os.path.join(self.root_dir, sinif_ismi, dosya_adi),
                      os.path.join(self.root_dir, dosya_adi),
                      os.path.join(self.root_dir, sinif_ismi, dosya_adi[:-4] + ".jpg")]
            
            hedef_yol = None
            for yol in yollar:
                if os.path.exists(yol):
                    hedef_yol = yol
                    break
            
            if hedef_yol is None: raise FileNotFoundError()

            image = Image.open(hedef_yol).convert("RGB")
            label = self.sinif_sozlugu[sinif_ismi]
            if self.transform: image = self.transform(image)
            return image, label
        except:
            yeni_idx = random.randint(0, len(self.veriler) - 1)
            return self.__getitem__(yeni_idx)

# SafCNN sınıfı kaldırıldı, hazır model kullanılacak.

if __name__ == '__main__':
    print("Test Verileri Hazırlanıyor...")
    
    transform = transforms.Compose([
        transforms.Resize((RESIM_BOYUTU, RESIM_BOYUTU)),
        transforms.ToTensor(),
        transforms.Normalize((0.5,), (0.5,))
    ])

    dataset = TankVeriSeti(csv_file=CSV_DOSYASI, root_dir=ANA_KLASOR, transform=transform)
    
    train_size = int(0.8 * len(dataset))
    val_size = len(dataset) - train_size
    _, val_dataset = random_split(dataset, [train_size, val_size])
    
    test_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
    
    print(f"Test Edilecek Görüntü Sayısı: {len(val_dataset)}")
    
    num_classes = len(dataset.sinif_isimleri)
    
    # --- MODEL GÜNCELLEMESİ: ShuffleNet V2 ---
    # Model yapısını eğitimdekiyle birebir aynı kuruyoruz
    model = models.shufflenet_v2_x1_0(weights='DEFAULT')
    num_ftrs = model.fc.in_features
    model.fc = nn.Linear(num_ftrs, num_classes)
    
    model = model.to(device)
    # ------------------------------------------

    if os.path.exists(MODEL_PATH):
        print(f"Model yükleniyor: {MODEL_PATH}")
        # Modeli DirectML cihazına (device) yüklüyoruz
        model.load_state_dict(torch.load(MODEL_PATH, map_location=device))
        model.eval() 
    else:
        print(f"HATA: '{MODEL_PATH}' bulunamadı! Dosya adını kontrol et.")
        exit()

    print("\nTEST BAŞLIYOR... (Lütfen bekleyin)")
    
    all_preds = []
    all_labels = []
    
    with torch.no_grad():
        for i, (images, labels) in enumerate(test_loader):
            # Verileri GPU'ya (DirectML) taşıyoruz
            images, labels = images.to(device), labels.to(device)
            
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            
            # GPU tensorlarını Numpy'a çevirmeden önce CPU'ya almalıyız (.cpu())
            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            
            if (i+1) % 50 == 0:
                print(f"   İşlenen paket: {i+1}...")

    acc = accuracy_score(all_labels, all_preds)
    f1_weighted = f1_score(all_labels, all_preds, average='weighted')
    f1_macro = f1_score(all_labels, all_preds, average='macro')
    
    print("\n" + "="*50)
    print("MODEL PERFORMANS RAPORU")
    print("="*50)
    print(f"Genel Doğruluk (Accuracy): %{acc*100:.2f}")
    print(f"Genel F1 Skoru (Weighted): {f1_weighted:.4f}")
    print(f"Genel F1 Skoru (Macro)   : {f1_macro:.4f}")
    print("-" * 50)
    
    print("\nHASTALIK BAZLI DETAYLI RAPOR:")
    print(classification_report(all_labels, all_preds, target_names=dataset.sinif_isimleri))
# Out:
# Test işlemi için kullanılan cihaz: privateuseone:0
# Test Verileri Hazırlanıyor...
# Test Edilecek Görüntü Sayısı: 15753
# Model yükleniyor: amd_model_finalv2.pth
#
# TEST BAŞLIYOR... (Lütfen bekleyin)
#    İşlenen paket: 50...
#    İşlenen paket: 100...
#    İşlenen paket: 150...
#    İşlenen paket: 200...
#    İşlenen paket: 250...
#    İşlenen paket: 300...
#    İşlenen paket: 350...
#    İşlenen paket: 400...
#    İşlenen paket: 450...
#    İşlenen paket: 500...
#    İşlenen paket: 550...
#    İşlenen paket: 600...
#    İşlenen paket: 650...
#    İşlenen paket: 700...
#    İşlenen paket: 750...
#    İşlenen paket: 800...
#    İşlenen paket: 850...
#    İşlenen paket: 900...
#    İşlenen paket: 950...
#
# ==================================================
# MODEL PERFORMANS RAPORU
# ==================================================
# Genel Doğruluk (Accuracy): %99.18
# Genel F1 Skoru (Weighted): 0.9918
# Genel F1 Skoru (Macro)   : 0.9883
# --------------------------------------------------
#
# HASTALIK BAZLI DETAYLI RAPOR:
#                                             precision    recall  f1-score   support
#
#                            Apple Scab Leaf       1.00      0.84      0.91        25
#                            Apple Scab leaf       1.00      1.00      1.00       436
#                                 Apple leaf       1.00      0.99      0.99       428
#                            Apple rust leaf       1.00      0.99      0.99       379
#                          Apple___Black_rot       1.00      1.00      1.00       387
#                           Bell_pepper leaf       1.00      0.99      0.99       439
#                      Bell_pepper leaf spot       1.00      0.99      1.00       435
#                             Blueberry leaf       1.00      1.00      1.00       533
#                                Cherry leaf       1.00      1.00      1.00       409
#   Cherry_(including_sour)___Powdery_mildew       1.00      1.00      1.00       325
#                        Corn Gray leaf spot       0.96      0.99      0.97       349
#                           Corn leaf blight       0.97      0.97      0.97       458
#                             Corn rust leaf       0.99      0.99      0.99       396
#                     Corn_(maize)___healthy       0.99      1.00      1.00       359
#                                 Grape leaf       1.00      1.00      1.00       336
#               Grape___Esca_(Black_Measles)       1.00      0.99      1.00       378
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot)       1.00      1.00      1.00       335
#   Orange___Haunglongbing_(Citrus_greening)       1.00      1.00      1.00       410
#                                 Peach leaf       0.99      1.00      1.00       486
#                     Peach___Bacterial_spot       1.00      1.00      1.00       371
#                                Potato leaf       1.00      1.00      1.00       395
#                   Potato leaf early blight       0.99      0.97      0.98       419
#                    Potato leaf late blight       0.99      0.99      0.99       432
#                              Rasberry leaf       1.00      1.00      1.00       393
#                             Raspberry leaf       0.95      0.99      0.97        93
#                              Soyabean leaf       1.00      0.98      0.99        63
#                               Soybean leaf       1.00      1.00      1.00       438
#                 Squash Powdery mildew leaf       0.99      1.00      1.00       433
#                            Strawberry leaf       0.99      1.00      0.99       450
#                   Strawberry___Leaf_scorch       1.00      1.00      1.00       387
#                   Tomato Early blight leaf       0.97      0.99      0.98       418
#                  Tomato Septoria leaf spot       0.91      0.94      0.93        72
#                  Tomato Septroia leaf spot       0.99      1.00      1.00       333
#                                Tomato leaf       1.00      0.98      0.99       455
#                 Tomato leaf bacterial spot       0.99      0.98      0.98       374
#                    Tomato leaf late blight       0.98      0.98      0.98       409
#                   Tomato leaf mosaic virus       1.00      0.98      0.99       422
#                   Tomato leaf yellow virus       0.99      1.00      0.99       557
#                           Tomato mold leaf       1.00      0.99      0.99       421
#       Tomato two spotted spider mites leaf       0.99      0.99      0.99       331
#                       Tomato___Target_Spot       0.98      0.99      0.98       360
#                                 grape leaf       0.97      1.00      0.99        33
#                       grape leaf black rot       0.99      0.99      0.99       391
#
#                                   accuracy                           0.99     15753
#                                  macro avg       0.99      0.99      0.99     15753
#                               weighted avg       0.99      0.99      0.99     15753

# %%
import matplotlib.pyplot as plt

USER_INFO = "Nevzat Eren TUĞ ( Shufflenet V2 )"

epochs = list(range(1, 16))
val_losses = [0.5239,0.2310,0.1753,0.1428,0.1166,0.1050,0.0926,0.0836,0.0780,0.0685,0.0674, 0.0587, 0.0599, 0.0531, 0.0486]
accuracies =  [93.63, 95.00, 96.12, 97.05, 96.92, 97.28, 96.93, 97.30, 97.14, 97.94, 97.71, 97.89, 98.01, 97.86, 98.08]

plt.figure(figsize=(15, 6))

plt.subplot(1, 2, 1)
plt.plot(epochs, val_losses, 'r-o', label='Doğrulama Kaybı (Validation)')

plt.title(f'{USER_INFO}\nEğitim ve Doğrulama Kayıp Eğrileri', fontsize=14)

plt.xlabel('Epoch Sayısı')
plt.ylabel('Kayıp Değeri (Loss)')
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs, accuracies, 'g-s', linewidth=2, label='Doğrulama Başarısı (Accuracy)')

plt.title(f'{USER_INFO}\nModel Doğruluk Oranı', fontsize=14)

plt.xlabel('Epoch Sayısı')
plt.ylabel('Doğruluk (%)')
plt.yticks(range(90, 100, 1))
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

USER_INFO = "Nevzat Eren TUĞ"

epochs = list(range(1, 16))

# --- EFFICIENTNET B0 VERİLERİ ---
eff_losses = [0.4841, 0.2361, 0.1738, 0.1365, 0.1181, 0.1017, 0.0863, 0.0806, 0.0728, 0.0673, 0.0629, 0.0573, 0.0549, 0.0508, 0.0493]
eff_accs =   [93.65, 95.99, 95.80, 97.10, 96.59, 97.17, 97.13, 97.26, 97.82, 98.30, 98.13, 97.66, 98.31, 98.08, 98.16]

# --- SHUFFLENET V2 VERİLERİ ---
shuf_losses = [0.5239, 0.2310, 0.1753, 0.1428, 0.1166, 0.1050, 0.0926, 0.0836, 0.0780, 0.0685, 0.0674, 0.0587, 0.0599, 0.0531, 0.0486]
shuf_accs =   [93.63, 95.00, 96.12, 97.05, 96.92, 97.28, 96.93, 97.30, 97.14, 97.94, 97.71, 97.89, 98.01, 97.86, 98.08]

plt.figure(figsize=(16, 7))

# -----------------------------
# 1. GRAFİK: LOSS KARŞILAŞTIRMA
# -----------------------------
plt.subplot(1, 2, 1)

# EfficientNet: 'bo' -> Blue, Circle (Mavi Yuvarlak)
plt.plot(epochs, eff_losses, 'bo-', linewidth=2, label='EfficientNet B0 Loss')

# ShuffleNet: 'rs' -> Red, Square (Kırmızı Kare) + Kesik Çizgi
# Düzeltme: 'r-s' yerine 'rs' yazıldı, böylece linestyle ile çakışma kalktı.
plt.plot(epochs, shuf_losses, 'rs', linewidth=2, linestyle='--', label='ShuffleNet V2 Loss')

plt.title(f'{USER_INFO}\nModel Karşılaştırması: Kayıp (Loss)', fontsize=14)
plt.xlabel('Epoch Sayısı')
plt.ylabel('Kayıp Değeri (Loss)')
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()

# -----------------------------
# 2. GRAFİK: ACCURACY KARŞILAŞTIRMA
# -----------------------------
plt.subplot(1, 2, 2)

# EfficientNet
plt.plot(epochs, eff_accs, 'bo-', linewidth=2, label='EfficientNet B0 Acc')

# ShuffleNet
# Düzeltme: Burada da 'r-s' yerine 'rs' kullanıldı.
plt.plot(epochs, shuf_accs, 'rs', linewidth=2, linestyle='--', label='ShuffleNet V2 Acc')

plt.title(f'{USER_INFO}\nModel Karşılaştırması: Doğruluk (Accuracy)', fontsize=14)
plt.xlabel('Epoch Sayısı')
plt.ylabel('Doğruluk (%)')

plt.ylim(90, 100) 
plt.yticks(range(90, 101, 1))

plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()

plt.tight_layout()
plt.show()
